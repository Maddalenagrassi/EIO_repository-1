# %%
#BLP - RANDOM COEFFICIENT LOGIT

#POINT 2.1 

import pandas as pd
import numpy as np 

#Loading and cleaning the data
import os
path = '/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes'
if os.path.exists(path):
    print("Path exists!")
else:
    print("Path does not exist.")
loc = '/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/'


#filo loc = '/Users/filippomajocchi/Desktop/Empirical IO/PSs/EIO_PS/EIO_repository/Computational/Python_codes/'
#veri loc = '/Users/veronicaermini/Documents/ESS/2_1_Empirical IO and Market Design/PS/EIO_repository/Computational/Python_codes/'   
#cami
#leo
#madda = '/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/'

class data():        
        
#Data location
    loc1= loc + "data.csv"
    loc2= loc + "demogr.csv"
    loc3= loc + "demogr_means.csv"
    loc4= loc + "demogr_year_region_id.csv"
    loc5= loc + "demogr_iqr.csv"
    loc6= loc + "demogr_std.csv"

#Load the data
    data = pd.read_csv(loc1, sep=',', names= list(range(1,189)), encoding='cp1252')
    demogr =  pd.read_csv(loc2, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_means = pd.read_csv(loc3, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_year_region_id = pd.read_csv(loc4, sep=',', names= list(range(1,3)), encoding='cp1252')
    demogr_iqr= pd.read_csv(loc5, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_std= pd.read_csv(loc6, sep=',', names= list(range(1,1001)), encoding='cp1252')

#Column names
    names =  ['id_colid_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_region_end','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','price_col','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','top_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','id_col','id_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','op_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','iv_start_col','iv_end_col','bid_col','gamma_col','true_weight_col','nat_weight_col','groupA_col','group_region_col','group_bid_test_col','ms_lischoosers_col','tot_lis_col','tot_lis_choosers_col','market_sizes_col','ms_lis_col','indicator_bench_col','contract_id_col','benefit_type_col','plan_name_col','lis_col'] 
    x1_names = ['id_colid_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_region_end','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','top_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','id_col','id_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','op_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col'] 
    x2_names = ['price_col']
    D_names = list(range(1,1001))
    IV_names = ['iv_start_col','iv_end_col','bid_col','gamma_col','true_weight_col','nat_weight_col','groupA_col','group_region_col','group_bid_test_col','ms_lischoosers_col','tot_lis_col','tot_lis_choosers_col','market_sizes_col','ms_lis_col','indicator_bench_col','contract_id_col','benefit_type_col','plan_name_col','lis_col']


    id_col=1 #id market plan
    id_market_col=2 #id market
    ms_col=3 #market shares
    dummy_firm_start=4 #first column of firm id's dummies
    dummy_firm_end=79 #last column of firm id's dummies
    dummy_year_start=80 #first column of year's dummies
    dummy_year_end=85 #last column of year's dummies
    dummy_region_start=86 #first column of region's dummies
    dummy_region_end=119 #last column of region's dummies
    dummy_firmname_start=120 #first column of firm name 
    dummy_firmname_end=140 #last column of firm name
    dummy_macroregion_start=141 #first column of firm name 
    dummy_macroregion_end=143 #last column of firm name
    price_col=144
    deductible_col=price_col+1
    n_medications_col=price_col+2 #col 146 - try adding this to x1
    drug_frf_col=price_col+3
    d_cov_gap_col=price_col+4
    d_enhance_col=price_col+5
    top_drug_col=price_col+6
    in_area_flag_col=price_col+7
    vintage_col=price_col+8
    tier_12_col=price_col+9
    d_below_lagged_col=price_col+10
    ms_lis_firm_col=price_col+11
    ms_lis_firm_lagged_col=price_col+12

#LIST OF IV'S
    iv_start_col=price_col+13
    iv_end_col=iv_start_col+12
    bid_col=iv_start_col+15
    gamma_col=iv_start_col+16
    true_weight_col=iv_start_col+17
    nat_weight_col=iv_start_col+18
    groupA_col=iv_start_col+19
    group_region_col=iv_start_col+20
    group_bid_test_col=iv_start_col+21
    ms_lischoosers_col=iv_start_col+22
    tot_lis_col=iv_start_col+23
    tot_lis_choosers_col=iv_start_col+24
    market_sizes_col=iv_start_col+25
    ms_lis_col=iv_start_col+26
    indicator_bench_col=iv_start_col+27 
    contract_id_col=iv_start_col+28
    benefit_type_col=iv_start_col+29
    plan_name_col=iv_start_col+30
    lis_col=iv_start_col+31
    
#Cleaning

#Drop missing IV, dates, and no-pharmacy plans

#Missing IV
    data.loc[:,iv_start_col+3] = data.loc[:,iv_start_col+3].fillna(value=0)
    data.loc[:,iv_start_col+4]=data.loc[:,iv_start_col+4].fillna(value=0)
    data.loc[:,iv_start_col+5]=data.loc[:,iv_start_col+5].fillna(value=0)
    data.loc[:,iv_start_col+6]=data.loc[:,iv_start_col+6].fillna(value=0)
    data.loc[:,iv_start_col+11]=data.loc[:,iv_start_col+11].fillna(value=0)
    
#Drop dates
    index = (data.loc[:,1] < 11000000) & (data.loc[:,1]>7000000)
    data = data.loc[index,:]
    
#Drop plans with no pharmacy? check column 151 is this one
    index = (data.loc[:,in_area_flag_col]!= 0) & (data.loc[:,in_area_flag_col]<10000)
    data = data.loc[index,:]

#Re-scaling
    scale=100
    ns=500
    data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
    data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
    data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
    data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
    data.loc[:,in_area_flag_col]=data.loc[:,in_area_flag_col].div(1000)

    demogr.loc[:,1:500]=demogr.loc[:,1:500].div(1000)
    demogr_means.loc[:,1:ns] = demogr_means.loc[:,1:ns].div(1000)

#IV - matrix    
    IV= data[list(range(iv_start_col,iv_end_col+1)) + [deductible_col, d_cov_gap_col, d_enhance_col, tier_12_col, top_drug_col, in_area_flag_col ,vintage_col]+list(range(dummy_macroregion_start,dummy_macroregion_end))+list(range(dummy_year_start+1,dummy_year_end-2))+[dummy_firmname_start, dummy_firmname_start+10, dummy_firmname_start+13, dummy_firmname_start+16, dummy_firmname_end]]
    #these columns give non singuality: 6-10
    IV = IV.iloc[:,0:6].join(IV.iloc[:,11:29])
    
    
#Cleaning missing IV
    index = (np.sum(IV.T.isna()) == 0)
    data = data.loc[index,:]   
    IV = IV.loc[index,:] 
    
 #Reindexing IV 
    IV.index = pd.RangeIndex(len(IV.index))
    IV.columns= pd.RangeIndex(len(IV.columns))
        
         
#x1, x2
    constant=pd.Series(np.ones(np.shape(data[1])),index=data.index,name='constant') #add constant
    x11=data[[price_col, deductible_col, drug_frf_col, d_cov_gap_col, d_enhance_col, tier_12_col, top_drug_col, in_area_flag_col, vintage_col]+list(range(dummy_macroregion_start,dummy_macroregion_end))+list(range(dummy_year_start+1,dummy_year_end-2))+[dummy_firmname_start,dummy_firmname_start+10,dummy_firmname_start+13,dummy_firmname_start+15,dummy_firmname_start+16,dummy_firmname_end]]
   
    x1 = x11.join(constant)
    col=x1.columns.tolist()
    col= col[-1:] + col[:-1]
    x1=x1[col]
    
    
    x2 = data.loc[:,price_col].values.reshape(len(x1),1) 

#Cleaning x1: delete dummies that are always 0 (companies that never offer a plan in 2006) 
    index= np.sum(x1)
    x1 = x1.loc[:,index!=0]

#Reindexing
    x1.index = pd.RangeIndex(len(x1.index))#reindex x1
    x1.columns= pd.RangeIndex(len(x1.columns))

#Indices
    id = data.loc[:,id_col] #id of each observation
    id_demo = data.loc[:,id_market_col].unique() #  number of markets 


#The vector below relates each observation to the market it is in / both for data and demographics
    
    cdid=list()
    cdindex=[-1]
    cdid_demogr=list()    

    for i in range(len(id_demo)):
        nbrand_market = np.sum(data.loc[:,id_market_col] == id_demo[i])
        cdid.extend(i*np.ones(nbrand_market)) 
        cdindex.append(cdindex[-1]+nbrand_market) 
        #create the cdid for the demographics
        index_market = data.loc[data[id_market_col]==id_demo[i]].index
        i_index_region= data.loc[index_market[0],dummy_region_start:dummy_region_end]==(1/scale) 
        index_region = np.where(i_index_region)[0] +1 # +1 since id_region [1,34]
        i_index_year= data.loc[index_market[0],dummy_year_start:dummy_year_end] == (1/scale)
        index_year = np.where(i_index_year)[0] + 2005 
        index_demogr = demogr_year_region_id.loc[demogr_year_region_id[1] == index_year[0]].index.intersection(demogr_year_region_id.loc[demogr_year_region_id[2] == index_region[0]].index)

        if np.isnan(index_demogr.values)== 1:
            print(['Demographics not found for region ' + np.array2string(index_region) + ' and year ' + np.array2string(index_year)])
        else:
            cdid_demogr.extend(index_demogr.values*np.ones(nbrand_market,int))## [0,135]
        
    cdindex=cdindex[1:137]
    cdindex=np.asarray(cdindex,dtype=int)

#Create instruments based on demographics
    mean_income= demogr_means.loc[cdid_demogr,1]
    mean_diffall= demogr_means.loc[cdid_demogr,ns+1] 
    std_income = demogr_std.loc[cdid_demogr,1]
    iqr_income=demogr_iqr.loc[cdid_demogr,1] 
    iqr_diffall=demogr_iqr.loc[cdid_demogr,ns+1]#

    IV1 = pd.DataFrame(np.concatenate([np.array([IV.loc[:,13]])*np.array([mean_income]), np.array([IV.loc[:,13]])*np.array([mean_diffall]), np.array([IV.loc[:,13]])*np.array([iqr_income]), np.array([IV.loc[:,13]])*np.array([iqr_diffall])],axis=0).T, index=IV.index, columns=[24,25,26,27])
    IV=IV.merge(IV1, right_index=True, left_index=True) #Try to run without these IV


#Other variables
    K1 = x1.shape[1] #number of product characteristics
    K2 = x2.shape[1] #
    s_jt=data.loc[:,ms_col]
    s_jt= np.reshape(s_jt.values, (np.shape(s_jt)[0],1))#observed market share for product j at time t
    nmkt = len(id_demo)
    r='/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/v.csv'
    v=pd.read_csv(r,sep=',',names= list(range(1000)))

    #v = pd.DataFrame(np.random.randn(nmkt,demogr.shape[1]))


   
    def summary(self):
        print('the number of characteristics in X1 is: '+str(data.x1.shape[1]))
        print('the number of characteristics in X2 is: '+str(data.x2.shape[1]))
        print('Object cdid dimensions: ' +str(np.shape(data.cdid)) )
        print('The dimensions of object cdindex are      ' + str(np.shape(data.cdindex)))
        print('The number of instruments for the price is ' +  str(np.shape(data.IV)[1]))
        print('The dimensions of object IV are ' + str(np.shape(data.IV)))
        print('size id_demo: '+ str(np.shape(data.id_demo)) )
        print("size of cdid is " + str(np.shape((data.cdid))))
        print("size of cdindex is "+ str(np.shape((data.cdindex))))
        print("size of cdid_demogr is "+ str(np.shape((data.cdid_demogr))))



data.summary(data)

# =============================================================================
# BLP Algorithm
#
#It is based on Nevo(2001) matlab code, Prof. Decarolis matlab version, and Daria Pus code.  
#
#note that it uses a Nelder-Mead algorithm to minimize objective function,as in the original; it is a simplex algo, i.e. with no derivatives
#
# OUTPUTS:
# 
# csv file with:
# theta1: vector of estimated parameters for the indiriect utility function, length: # of plans's characteristics 
# theta2: matrix of estimated interaction with demographicsparameters for
#         the indiriect utility function, # rows: of plans's characteristics
#        interacted, # columns: # of demographics
# se: matrix of standard errors
#
# histogram:
#   alfa_i_reshaped: estimated distribution of the price coefficient
#                 (interacted with the demographics)
# =============================================================================

#from scipy.optimize import fmin
from scipy.optimize import minimize
import matplotlib.pyplot as plt    
import time
#import optimize2 as opt # import modified optimize.minimize_nelder-mead ; alternatively change line 569 from 'and' to 'or' on original optimize.py

    
class BLP:
    
    def __init__ (self,data,theta2w,mtol,niter): #define data instances
         
        self.niter = niter 
        self.mtol=mtol
        self.theta2w=theta2w 
        self.x1 = data.x1
        self.x2 = data.x2 
        self.s_jt = data.s_jt
        self.v = data.v
        self.cdindex = data.cdindex #consider asarray
        self.cdid = data.cdid
        self.cdid_demogr=data.cdid_demogr
        self.vfull = data.v.loc[self.cdid_demogr,:] 
        dfull = data.demogr.loc[self.cdid_demogr,:]
        dfull.columns= pd.RangeIndex(len(dfull.columns))
        dfull.index = pd.RangeIndex(len(dfull.index))
        self.dfull = dfull
        self.demogr= data.demogr
        self.IV = data.IV
        self.K1 = self.x1.shape[1]
        self.K2 = self.x2.shape[1]
        self.ns = data.ns          # number of simulated "indviduals" per market 
        self.D = int(self.dfull.shape[1]/self.ns)       # number of demographic variables
        self.T = np.asarray(self.cdindex).shape[0]      # number of markets = (# of cities)*(# of quarters)  
        self.TJ = self.x1.shape[0]      #number of observations
        self.J = int(self.TJ/self.T) #average number of observation per market
        
      
        
        self.invA = np.linalg.inv(self.IV.T@self.IV)
        
        
        #mid2 = np.mat(self.x1.T)*np.mat(self.IV)*self.invA*np.mat(self.IV.T)*np.mat(self.x1)
        #invmid2=np.linalg.inv(mid2)
        
        #Calculating s0 -outside good shares
        temp= self.s_jt.cumsum()
        sum1 = temp[self.cdindex] 
        sum1[1:np.shape(sum1)[0]] = np.diff(sum1) 
        outshr = (1 - sum1[np.asarray(self.cdid,dtype=int)]) 
        outshr= np.abs(outshr)
        outshr=np.reshape(outshr,(np.shape(outshr)[0],1))       

        #Find initial guess of coefficients by running simple logit regression
        y=np.log(self.s_jt)-np.log(outshr)
        mid = self.x1.T@self.IV@self.invA@self.IV.T
        t = np.linalg.inv(mid@self.x1)@mid@y 
        
        #Mean utility - initial
        self.mvalold = self.x1@(t) 
        self.mvalold = np.exp(self.mvalold).values.reshape(np.shape(self.mvalold)[0],1)
        self.oldt2 = np.zeros(np.shape(self.theta2w)) #initial old2
        self.gmmvalold = 0
        self.gmmdiff = 1
        self.gmmresid = np.ones((6024,1)) #@@@@@@ initialization
   
    #Transforms inputed guess of theta2w into an ndarray type
    def init_theta(self,theta2w):
        theta2w=theta2w.reshape(self.K2,1+self.D) # #rows: # x2 variables
        self.theti, self.thetj = list(np.where(theta2w != 0))#columns: #demographic variables + 1 (constant)
        self.theta2 = theta2w[np.where(theta2w != 0)]
        return self.theta2
     
        
    #Mean utility function
    def mufunc(self,theta2w): 
        mu = np.zeros((self.TJ, self.ns))
        for i in range(self.ns):
            v_i = np.array(self.vfull.loc[:, np.arange(i, self.K2*self.ns, self.ns)])
            d_i = np.array(self.dfull.loc[:, np.arange(i, self.D*self.ns, self.ns)]) 
            temp = d_i @ theta2w[:, 1:(self.D+1)].T
            mu[:, i]=(np.multiply(self.x2, v_i) @ theta2w[:, 0]) + np.multiply(self.x2, temp) @ np.ones((self.K2))

        return mu
        
    def ind_sh(self,expmu): 
        eg = np.multiply(expmu, np.kron(np.ones((1, self.ns)), self.mvalold)) 
        temp = np.cumsum(eg, 0)
        sum1 = temp[self.cdindex, :]
        sum2 = sum1
        sum2[1:sum2.shape[0], :] = np.diff(sum1.T).T
        denom1 = 1. / (1. + sum2)
        denom = denom1[np.asarray(self.cdid,dtype=int), :]
        
        return np.multiply(eg, denom)

    def mktsh(self,expmu):
        #compute the market share for each product
        temp = self.ind_sh(expmu).T
        f = (sum(temp) / float(self.ns)).T
        f = f.reshape(self.x1.shape[0],1)
        return f
        
        
    def meanval(self,theta2):
        #phased tolerance to speed up computation
#        if self.gmmdiff < 1e-15:
#            self.mtol = 1e-15
#        elif self.gmmdiff < 1e-3:
#            self.mtol = 1e-4
#        else:
#            self.mtol = 1e-2
        
        if np.ndarray.max(np.absolute(theta2-self.oldt2)) < 0.01: 
            tol = self.mtol
            flag=0
        else:
            tol = self.mtol #when theta2 (output of minimize) is still larger than 0.01, flag=1 => pass it to theta old2, that will be used in next iteration
            flag = 1
        norm = 1
        avgnorm = 1
        i = 0
        theta2w = np.zeros((self.K2,self.D+1)) 
        for ind in range(len(self.theti)): 
            theta2w[self.theti[ind], self.thetj[ind]] = theta2[ind] 
        expmu=np.exp(self.mufunc(theta2w))
       
        while (norm > self.mtol) & (i<self.niter): 
           
            pred_s_jt = self.mktsh(expmu) 
            self.mval = np.multiply(self.mvalold,self.s_jt) / pred_s_jt 
            t = np.abs(self.mval - self.mvalold)
            norm = np.max(t)
            avgnorm = np.mean(t)
            self.mvalold = self.mval
            i += 1
           
            if (norm > self.mtol) & (i > self.niter-1):
                print('Max number of ' + str(niter) + 'iterations reached')
    
        print(['# of iterations for delta convergence: ' , i])
	
        if (flag == 1) & (sum(np.isnan(self.mval)))==0: 
            self.mvalold = self.mval
            self.oldt2 = theta2
        return np.log(self.mval)
 
 
    #Calculates the jacobian
    def jacob(self,theta2): 
        cdindex=np.asarray(self.cdindex,dtype=int)
        theta2w = np.zeros((self.K2, self.D+1))
        for ind in range(len(self.theti)):
            theta2w[self.theti[ind], self.thetj[ind]] = self.theta2[ind] #build theta2w (from array to ndarray) to plug in ind_sh
        expmu=np.exp(self.mufunc(theta2w)) 
        shares = self.ind_sh(expmu)
        f1 = np.zeros((np.asarray(self.cdid).shape[0] ,self.K2 * (self.D + 1)))
        # calculate derivative of shares with respect to the first column of theta2w (variable that are not interacted with demogr var, sigmas)
        for i in range(self.K2):
            xv = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)),self.v.loc[self.cdid, self.ns*i:self.ns * (i+1)-1])
            temp = np.cumsum(np.multiply(xv, shares), 0).values
            sum1 = temp[cdindex, :]
            sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
            f1[:,i] = np.mean((np.multiply(shares, xv - sum1[np.asarray(self.cdid,dtype=int),:])),1) #mean over columns
           
        for j in range(self.D):
            d = self.demogr.loc[self.cdid,self.ns*(j)+1:self.ns*(j+1)] 
            temp1 = np.zeros((np.asarray(self.cdid).shape[0],self.K2))
            for i in range(self.K2):
                xd = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)), d)
                temp = np.cumsum(np.multiply(xd, shares), 0).values
                sum1 = temp[cdindex, :]
                sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
                temp1[:, i] = np.mean((np.multiply(shares, xd-sum1[np.asarray(self.cdid,dtype=int), :])), 1)
            f1[:,self.K2 * (j + 1):self.K2 * (j + 2)] = temp1 

        self.rel = self.theti + self.thetj * (max(self.theti)+1) 
        f = np.zeros((np.shape(self.cdid)[0],self.rel.shape[0]))
        n = 0
        
        for i in range(np.shape(self.cdindex)[0]):
            temp = shares[n:(self.cdindex[i] + 1), :]
            H1 = temp @ temp.T
            H = (np.diag(np.array(sum(temp.T)).flatten())-H1) / self.ns
            f[n:(cdindex[i]+1),:] = np.linalg.inv(H) @ f1[n:(cdindex[i] + 1),self.rel]
            n = cdindex[i] + 1
        return f
       
    #Compute GMM objective function       
    def gmmobj(self,theta2):
        print(theta2)
        delta = self.meanval(theta2)
        self.theta2=theta2
        # the following deals with cases where the min algorithm drifts into region where the objective is not defined
        if max(np.isnan(delta)) == 1: 
            f = np.ndarray((1,1),buffer=np.array([1e+10,1e+10])) 
        else:
            temp1 = self.x1.T @ self.IV
            temp2 = delta.T@self.IV
            self.theta1 = np.linalg.inv(temp1@self.invA@temp1.T)@temp1@self.invA@temp2.T
            self.gmmresid = delta - self.x1@self.theta1
            temp1 = self.gmmresid.T@(self.IV) 
            f = temp1@self.invA@temp1.T
            f=f.values
            if np.shape(f) > (1,1):
                temp = self.jacob(theta2).T 
                df = 2*temp@self.IV@self.invA@self.IV.T@self.gmmresid 
        print('fval:', f[0,0]) #value of the gmm objective function
        
        #to be used in meanval to phase tolerance based on gmm value
        self.gmmvalnew = f[0,0]
        self.gmmdiff = np.abs(self.gmmvalold - self.gmmvalnew)
        self.gmmvalold = self.gmmvalnew
        
        return (f[0,0])
       
               

    #Calculates the gradient of the objective function based on jacobian
    def gradobj(self,theta2):
        temp = self.jacob(theta2).T 
        df = 2*temp@self.IV@self.invA@self.IV.T@self.gmmresid 
        df=df.values ##@@
        print('this is the gradient '+str(df))
    
        return df
    
  
    #WARNING!!!!!!!! In some versions of scipy there can be a problem with xatol in optimize.minimize_neldermead. IF so, change optimize.py codeline 569: replace 'and' to 'or'OR use modified script optimize2.py 
    
     
    #Maximizes the objective function
    def iterate_optimization(self,opt_func, param_vec,jac,options ): 
        res = minimize(opt_func, param_vec,method='nelder-mead',options=options) 
        ##res = opt._minimize_neldermead(opt_func, param_vec,disp=True,maxiter=100,fatol=0.0001,xatol=0.0001)
        #res = minimize(opt_func, param_vec, method='BFGS', bounds=None, callback=None, options=options)
    
        return res
            
    
    #Calculates the variance-covariance matrix of the estimates
    
    def varcov(self,theta2): 
        Z = self.IV.shape[1]
        temp = self.jacob(theta2)                                              
        a = np.concatenate((self.x1.values, temp), 1).T @ self.IV.values
        IVres = np.multiply(self.IV.values,self.gmmresid.values @ np.ones((1, Z)))
        b = IVres.T@(IVres)
        if np.linalg.det(a @ np.asarray(self.invA) @ a.T)!= 0:
            inv_aAa = np.linalg.inv(a @ np.asarray(self.invA) @ a.T)
        else:
            print('Error: singular matrix in covariate function ; forced result') #if jacobian has row of zeros
            inv_aAa = np.linalg.lstsq(a @ np.asarray(self.invA) @ a.T)
        f = inv_aAa @ a @ np.asarray(self.invA) @ b @ np.asarray(self.invA) @ a.T @ inv_aAa   
        return f    


    #Computes estimates of the coefficients and its standard errors; outputs a histogram and a csv file with estimates
    def results(self,theta2):
        self.theta1=self.theta1.values
        var = self.varcov(self.theta2)
        se = np.sqrt(var.diagonal())
        t = se.shape[0] - self.theta2.shape[0]
        
        print('Object vcov dimensions: ' + str(np.shape(var)) )
        print('Object se dimensions: ' + str(np.shape(se)))
        
        print('Object theta2w dimensions:     ' + str(np.shape(self.theta2)))
        print('Object t dimensions:     ' + str(np.shape(t)))
        

#Histogram of the coefficients
        alfa_i=[]
        alfa_i2=[]
        for i in range(0,self.T): 
            data_market=np.reshape(self.demogr.loc[i,0:self.ns*self.D].values,(self.ns,self.D))
            v_market=np.reshape(self.v.loc[i,0:self.ns-1].values,(self.ns,1)) # caution: v is created to have 1000 columns
            alfa_i2.extend(np.add(data_market@(self.theta2[1:3]).T, self.theta2[0]*v_market[:,0])) 
            alfa_i.extend(data_market@(self.theta2[1:3].T))
        #alfa_i=(self.theta1[1]+alfa_i2)/100 
        alfa_i=(self.theta1[1]+alfa_i2)/100
        h=plt.figure()
        plt.hist(alfa_i,bins=25,range=(np.min(alfa_i),np.max(alfa_i)))
        plt.grid(axis='y', alpha=0.75)
        plt.xlabel('Value')
        plt.ylabel('Frequency')
        plt.title('Distribution of the price coefficient -2007')
        h.savefig('elasticities.png')
        #compute the elasticities
        #reshape the alfas
        alfa_i_reshaped=np.reshape(alfa_i,(self.ns,len(self.cdindex))).T #changed from cdindex (136) to cdid (6024) to match matlab size
        alfa_i_reshaped=alfa_i_reshaped[np.asarray(self.cdid,dtype=int),:]
        
        #convert theta2 into ndarray to plug in ind_sh
        theta = np.zeros((self.K2, self.D+1))
        for ind in range(len(self.theti)):
            theta[self.theti[ind], self.thetj[ind]] = self.theta2[ind] 
       #######
        expmu=np.exp(self.mufunc(theta))
        f = self.ind_sh(expmu)
        mval=(self.x1@self.theta1)
     
        #from ind_sh function: here mvalold = gmmresid +mval
        eg = np.multiply(np.exp(self.mufunc(theta)), np.kron(np.ones((1, self.ns)), (mval+self.gmmresid))) 
        temp = np.cumsum(eg, 0)
        sum1 = temp[self.cdindex, :]
        sum2 = sum1
        sum2[1:sum2.shape[0], :] = np.diff(sum1.T).T
        denom1 = 1. / (1. + sum2)
        denom = denom1[np.asarray(self.cdid,dtype=int), :]
        f22= np.multiply(eg, denom)
        ######
        f2 = np.sum(f22.T,0)/self.ns
        f2 = f2.T
        error=self.s_jt-f2     

        #table with parameters + export to csv file
        
        self.theta1_results= pd.DataFrame({'Theta1':self.theta1.reshape(self.K1,),'Std.Error_theta1': se[0:-self.theta2.shape[0]]},columns=(['Theta1','Std.Error_theta1'])) 
        self.theta2_results= pd.DataFrame({'Theta2':self.theta2.reshape(self.theta2.shape[0],), 'Std.Error_theta2':se[-self.theta2.shape[0]:]},columns=(['Theta2','Std.Error_theta2']))
        self.theta1_results.to_csv(loc + "theta1.csv")
        self.theta2_results.to_csv(loc + "theta2.csv")
        
        return self.theta1_results, self.theta2_results, self.gmmvalnew
 
# =============================================================================
# Define parameters to input in the algorithm    
# =============================================================================


starttime = time.time()

#Maximum number of iterations for convergence of mval-mvalold contraction
niter = 2500

#Initial guess for coefficients
theta2w = np.array([0.50,-0.5,0.5])
#theta2w = np.array([0.20,-0.01,0.01,-0.5,0.05,0.05])

#Maximum tolerance 
mtol= 1e-5 

#Set optimization options
options={'disp': None,'maxiter': 100,'xatol':0.0001,'fatol':0.0001}

#Get output
blp = BLP(data,theta2w,mtol,niter)
init_theta = blp.init_theta(theta2w) 
res = blp.iterate_optimization(opt_func=blp.gmmobj,param_vec=init_theta,jac=blp.gradobj,options=options) 
theta1_results, theta2_results, gmmvalnew = blp.results(res.x)

endtime=time.time()
run = endtime-starttime
print('running time: ' + str(endtime-starttime))
a=time.time()

#Create a table with the results
results_table = pd.DataFrame({
    'Theta1': theta1_results['Theta1'],
    'Std.Error_theta1': theta1_results['Std.Error_theta1'],
    'Theta2': theta2_results['Theta2'],
    'Std.Error_theta2': theta2_results['Std.Error_theta2'],
    'Objective Value': [gmmvalnew] * len(theta1_results)
})

# Save results_table to a file
results_table.to_csv('results_table1.csv', index=False)

print(results_table)
# Out:
# Path exists!
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   2.65 0.   ... 0.   3.1  0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[54.85 54.85 54.85 ... 31.42 38.84 38.84]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 9.59  9.59  9.59 ...  9.85 10.57 10.57]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.   0.   ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.   0.01 ... 0.   0.   0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.93 0.93 0.93 ... 0.99 0.99 0.99]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.05 0.04 0.04]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.72 0.72 0.72 ... 0.86 0.89 0.89]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:121: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:121: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:121: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:121: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:122: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.   0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:123: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2056313499.py:124: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.506 0.506 0.506 ... 0.108 0.12  0.12 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,in_area_flag_col]=data.loc[:,in_area_flag_col].div(1000)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# the number of characteristics in X1 is: 19
# the number of characteristics in X2 is: 1
# Object cdid dimensions: (6024,)
# The dimensions of object cdindex are      (136,)
# The number of instruments for the price is 28
# The dimensions of object IV are (6024, 28)
# size id_demo: (136,)
# size of cdid is (6024,)
# size of cdindex is (136,)
# size of cdid_demogr is (6024,)
# [ 0.5 -0.5  0.5]
# ['# of iterations for delta convergence: ', 75]
# fval: 9017.960092348687
# [ 0.525 -0.5    0.5  ]
# ['# of iterations for delta convergence: ', 4]
# fval: 9017.967474148845
# [ 0.5   -0.525  0.5  ]
# ['# of iterations for delta convergence: ', 45]
# fval: 9881.082620442336
# [ 0.5   -0.5    0.525]
# ['# of iterations for delta convergence: ', 45]
# fval: 9033.780645357032
# [ 0.51666667 -0.475       0.51666667]
# ['# of iterations for delta convergence: ', 43]
# fval: 8208.433895321885
# [ 0.525 -0.45   0.525]
# ['# of iterations for delta convergence: ', 43]
# fval: 7436.787792888781
# [ 0.53333333 -0.46666667  0.49166667]
# ['# of iterations for delta convergence: ', 41]
# fval: 7929.465732120618
# [ 0.51388889 -0.44444444  0.51111111]
# ['# of iterations for delta convergence: ', 42]
# fval: 7262.028734534751
# [ 0.50833333 -0.41666667  0.51666667]
# ['# of iterations for delta convergence: ', 43]
# fval: 6464.8156054842275
# [ 0.54444444 -0.38888889  0.52222222]
# ['# of iterations for delta convergence: ', 42]
# fval: 5721.576298488023
# [ 0.56666667 -0.33333333  0.53333333]
# ['# of iterations for delta convergence: ', 45]
# fval: 4400.056786470133
# [ 0.53333333 -0.33333333  0.55833333]
# ['# of iterations for delta convergence: ', 24]
# fval: 4416.414536383848
# [ 0.54722222 -0.27222222  0.54722222]
# ['# of iterations for delta convergence: ', 42]
# fval: 3202.9711177769473
# [ 0.55833333 -0.18333333  0.55833333]
# ['# of iterations for delta convergence: ', 39]
# fval: 1929.3721015913989
# [ 0.59722222 -0.15        0.58333333]
# ['# of iterations for delta convergence: ', 32]
# fval: 1609.2737239526587
# [ 0.64166667 -0.01666667  0.61666667]
# ['# of iterations for delta convergence: ', 28]
# fval: 964.4017449039343
# [ 0.64444444 -0.02222222  0.58055556]
# ['# of iterations for delta convergence: ', 16]
# fval: 948.3064002703451
# [0.7        0.13333333 0.59166667]
# ['# of iterations for delta convergence: ', 81]
# fval: 14209.190605509146
# [0.66296296 0.18518519 0.63703704]
# ['# of iterations for delta convergence: ', 55]
# fval: 33001.53604841324
# [ 0.59074074 -0.2037037   0.55925926]
# ['# of iterations for delta convergence: ', 49]
# fval: 2174.5309839349907
# [0.63888889 0.05555556 0.61111111]
# ['# of iterations for delta convergence: ', 34]
# fval: 1194.127653960699
# [0.725      0.19444444 0.64722222]
# ['# of iterations for delta convergence: ', 67]
# fval: 42177.57812833867
# [ 0.6        -0.08888889  0.58055556]
# ['# of iterations for delta convergence: ', 39]
# fval: 1174.5695091979326
# [ 0.61851852 -0.14074074  0.57407407]
# ['# of iterations for delta convergence: ', 33]
# fval: 1521.030829024569
# [0.6337963  0.00648148 0.60185185]
# ['# of iterations for delta convergence: ', 27]
# fval: 929.2483962658986
# [0.67993827 0.06728395 0.61882716]
# ['# of iterations for delta convergence: ', 50]
# fval: 1418.6929341438022
# [ 0.61998457 -0.04984568  0.59012346]
# ['# of iterations for delta convergence: ', 32]
# fval: 1021.5310627205807
# [0.6599537  0.02824074 0.60925926]
# ['# of iterations for delta convergence: ', 23]
# fval: 965.1897652340234
# [0.64996142 0.00871914 0.60447531]
# ['# of iterations for delta convergence: ', 16]
# fval: 930.8431413913913
# [0.64380144 0.0119856  0.57458848]
# ['# of iterations for delta convergence: ', 15]
# fval: 911.9015925982904
# [0.64486883 0.02631173 0.55354938]
# ['# of iterations for delta convergence: ', 15]
# fval: 923.3353496945771
# [0.64059499 0.04034636 0.60672154]
# ['# of iterations for delta convergence: ', 23]
# fval: 1034.9643202659204
# [ 0.64348208 -0.00658008  0.58709705]
# ['# of iterations for delta convergence: ', 17]
# fval: 929.5282678115602
# [ 0.63075846 -0.00079447  0.57121628]
# ['# of iterations for delta convergence: ', 15]
# fval: 913.0283895742385
# [0.62875538 0.01836182 0.57800735]
# ['# of iterations for delta convergence: ', 14]
# fval: 920.3279966923179
# [0.63508056 0.01322048 0.54735622]
# ['# of iterations for delta convergence: ', 15]
# fval: 895.6084170922034
# [0.63572269 0.01658998 0.52010841]
# ['# of iterations for delta convergence: ', 14]
# fval: 882.6562183385992
# [6.44766343e-01 1.58925215e-04 5.32601420e-01]
# ['# of iterations for delta convergence: ', 14]
# fval: 888.1528276511099
# [0.65210186 0.0199508  0.51364926]
# ['# of iterations for delta convergence: ', 14]
# fval: 883.6209401003358
# [0.64459249 0.01248088 0.46965091]
# ['# of iterations for delta convergence: ', 15]
# fval: 851.6031753158679
# [0.64498801 0.01272852 0.41718213]
# ['# of iterations for delta convergence: ', 15]
# fval: 826.5593214561919
# [0.64377536 0.03268728 0.43469177]
# ['# of iterations for delta convergence: ', 20]
# fval: 896.4610173845273
# [0.6445186  0.00829101 0.50812401]
# ['# of iterations for delta convergence: ', 16]
# fval: 870.8142856736984
# [0.63138434 0.00512221 0.44996044]
# ['# of iterations for delta convergence: ', 15]
# fval: 840.3811150544643
# [0.64487127 0.00083784 0.39673598]
# ['# of iterations for delta convergence: ', 14]
# fval: 817.811630710434
# [ 0.64944557 -0.00703823  0.33504976]
# ['# of iterations for delta convergence: ', 14]
# fval: 799.4814470250734
# [ 0.63936001 -0.00108268  0.29333754]
# ['# of iterations for delta convergence: ', 13]
# fval: 781.8424569324675
# [ 0.63678072 -0.00576953  0.18594431]
# ['# of iterations for delta convergence: ', 13]
# fval: 760.2715744109245
# [ 0.65609186 -0.00517503  0.17549036]
# ['# of iterations for delta convergence: ', 8]
# fval: 758.3989442020627
# [ 0.66844562 -0.01032365  0.03825533]
# ['# of iterations for delta convergence: ', 12]
# fval: 749.0024430125546
# [ 0.65812659 -0.02814946 -0.04434919]
# ['# of iterations for delta convergence: ', 13]
# fval: 762.9628884409306
# [ 0.65945639 -0.02245687 -0.21514946]
# ['# of iterations for delta convergence: ', 11]
# fval: 769.4191491961896
# [ 0.65695368 -0.01860221 -0.07759966]
# ['# of iterations for delta convergence: ', 11]
# fval: 754.407340803305
# [0.64999342 0.0050192  0.14208251]
# ['# of iterations for delta convergence: ', 11]
# fval: 751.6776167521391
# [ 0.68014776 -0.01016824 -0.11745219]
# ['# of iterations for delta convergence: ', 11]
# fval: 751.6503387325898
# [0.67543751 0.00828708 0.11952343]
# ['# of iterations for delta convergence: ', 10]
# fval: 747.9794846629568
# [0.68467943 0.02173172 0.21808497]
# ['# of iterations for delta convergence: ', 15]
# fval: 781.8414440850587
# [ 0.6993605  -0.01315575 -0.11519814]
# ['# of iterations for delta convergence: ', 14]
# fval: 752.9856428737389
# [6.62335189e-01 4.75462149e-04 7.77623518e-02]
# ['# of iterations for delta convergence: ', 10]
# fval: 747.3969609795706
# [0.65733112 0.0091275  0.27447959]
# ['# of iterations for delta convergence: ', 14]
# fval: 774.6967269195922
# [ 0.6744436  -0.00534431 -0.01946924]
# ['# of iterations for delta convergence: ', 14]
# fval: 746.2657670618293
# [0.67303192 0.01260247 0.08028903]
# ['# of iterations for delta convergence: ', 10]
# fval: 746.3001793994226
# [ 0.66443629 -0.00313132 -0.02713534]
# ['# of iterations for delta convergence: ', 10]
# fval: 745.8981696245937
# [ 0.65893568 -0.00884052 -0.10046472]
# ['# of iterations for delta convergence: ', 9]
# fval: 749.9675696054917
# [ 0.67893935  0.00227577 -0.05530605]
# ['# of iterations for delta convergence: ', 8]
# fval: 747.122767258152
# [ 0.67478831  0.00182569 -0.02203895]
# ['# of iterations for delta convergence: ', 7]
# fval: 746.0338153819083
# [ 0.66941355 -0.01703577 -0.12605138]
# ['# of iterations for delta convergence: ', 12]
# fval: 756.0310409003862
# [0.67212732 0.00519291 0.02870393]
# ['# of iterations for delta convergence: ', 11]
# fval: 745.4573199962693
# [0.66645768 0.00793583 0.00582234]
# ['# of iterations for delta convergence: ', 7]
# fval: 744.00223956306
# [0.66246473 0.01457589 0.01846813]
# ['# of iterations for delta convergence: ', 11]
# fval: 748.7141324650655
# [0.66055922 0.00483925 0.02696624]
# ['# of iterations for delta convergence: ', 10]
# fval: 745.5618431012141
# [0.66832653 0.01510999 0.06813033]
# ['# of iterations for delta convergence: ', 12]
# fval: 749.7008997757265
# [ 0.66540885  0.001429   -0.00331892]
# ['# of iterations for delta convergence: ', 10]
# fval: 745.7188822521374
# [0.66735397 0.01054966 0.04431392]
# ['# of iterations for delta convergence: ', 9]
# fval: 744.011913324177
# [0.67673343 0.01094634 0.02559388]
# ['# of iterations for delta convergence: ', 6]
# fval: 744.2172717212613
# [0.66823606 0.01442831 0.02178283]
# ['# of iterations for delta convergence: ', 9]
# fval: 748.4064764865905
# [0.67115451 0.00750176 0.02697365]
# ['# of iterations for delta convergence: ', 9]
# fval: 744.112686254559
# [0.65991068 0.00637849 0.02581272]
# ['# of iterations for delta convergence: ', 6]
# fval: 744.6549354155311
# [0.67252774 0.00980438 0.02564859]
# ['# of iterations for delta convergence: ', 8]
# fval: 743.7676662822931
# [0.66640509 0.01135815 0.02354958]
# ['# of iterations for delta convergence: ', 7]
# fval: 744.435670408346
# [0.66996715 0.00846586 0.02611763]
# ['# of iterations for delta convergence: ', 8]
# fval: 743.7779311681734
# [ 0.67194775  0.00692105 -0.00592154]
# ['# of iterations for delta convergence: ', 6]
# fval: 744.5748902225158
# [0.66850242 0.00964251 0.03175505]
# ['# of iterations for delta convergence: ', 8]
# fval: 743.7184613783668
# [0.67420719 0.01067267 0.04985852]
# ['# of iterations for delta convergence: ', 7]
# fval: 744.1715823318751
# [0.66839506 0.00862004 0.01683138]
# ['# of iterations for delta convergence: ', 8]
# fval: 743.7616670147366
# [0.66964966 0.01024542 0.02337238]
# ['# of iterations for delta convergence: ', 7]
# fval: 743.8754740974034
# [0.66988778 0.00891075 0.02543132]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.7073018507259
# [0.6653291  0.00831115 0.02369658]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.7849781979329
# [0.67072808 0.00943107 0.02516059]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.7128475815908
# [0.67101712 0.01003618 0.03806659]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.8290911493258
# [0.66905058 0.00897407 0.02214018]
# ['# of iterations for delta convergence: ', 7]
# fval: 743.7046276764034
# [0.67127521 0.00856809 0.01673301]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.785411757332
# [0.66919561 0.0093739  0.02799954]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.6975101737537
# [0.6680279  0.00874141 0.02522011]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.7171805491136
# [0.67005303 0.00925866 0.02517547]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.7016473872945
# [0.66897837 0.00949367 0.02477881]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.7079112923872
# [0.66966043 0.00905648 0.02526819]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.697093965489
# [0.67022214 0.00948529 0.03015529]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.7127020124791
# [0.66934347 0.00910188 0.02414396]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.6941299138626
# [0.66874664 0.00909618 0.02643233]
# ['# of iterations for delta convergence: ', 2]
# fval: 743.6941264484831
# [0.66809344 0.00901495 0.02706076]
# ['# of iterations for delta convergence: ', 3]
# fval: 743.6907883901645
# [0.66886928 0.00874163 0.0229824 ]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.7232260071343
# [0.66911403 0.00921584 0.02674526]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.6946819437308
# [0.6680402  0.00916529 0.02669845]
# ['# of iterations for delta convergence: ', 3]
# fval: 743.6840633440403
# [0.66723008 0.0092197  0.02741359]
# ['# of iterations for delta convergence: ', 3]
# fval: 743.6820596612837
# [0.66733063 0.00900851 0.02566695]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.685148616415
# [0.6657593  0.00906023 0.02928357]
# ['# of iterations for delta convergence: ', 3]
# fval: 743.6834750727389
# [0.66545323 0.00917734 0.02784864]
# ['# of iterations for delta convergence: ', 3]
# fval: 743.6730974402967
# [0.66413313 0.00925854 0.02824258]
# ['# of iterations for delta convergence: ', 3]
# fval: 743.6653370433123
# [0.66408438 0.00935046 0.03095954]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.6721614388081
# [0.66453909 0.00949224 0.02846024]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.6759665872166
# [0.66127432 0.00951447 0.03102799]
# ['# of iterations for delta convergence: ', 3]
# fval: 743.6627393389002
# [0.65829644 0.00966186 0.0328352 ]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.6655560742951
# [0.66178879 0.00925674 0.03169317]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.6565481703827
# [0.66041364 0.00913899 0.03330964]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.6609193288496
# [0.66071312 0.00933604 0.02968295]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.6478827375294
# [0.65902749 0.00932882 0.02904466]
# ['# of iterations for delta convergence: ', 2]
# fval: 743.6327512087815
# [0.6572606  0.00947481 0.03293463]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.6457332275958
# [0.6574436  0.00919245 0.03142032]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.6324611962292
# [0.65552824 0.00903144 0.03161648]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.6305818829644
# [0.65275542 0.00929998 0.03070401]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.6064013272842
# [0.64823874 0.00932159 0.03020943]
# ['# of iterations for delta convergence: ', 3]
# fval: 743.5755024779642
# [0.65126904 0.00897976 0.02764574]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.5996327172516
# [0.64432986 0.00889303 0.03060311]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.5791623480517
# [0.64036353 0.00909815 0.02735571]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.5340839016968
# [0.63278118 0.00913151 0.02522533]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.4896269184601
# [0.63229748 0.009251   0.02971283]
# ['# of iterations for delta convergence: ', 4]
# fval: 743.4932390307105
# [0.63121507 0.00957637 0.02616195]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.4985723781674
# [0.61595707 0.00931766 0.02385731]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.4033958850605
# [0.59981623 0.00931569 0.02068125]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.3319941614864
# [0.61204819 0.0088891  0.02425099]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.4014569038683
# [0.59746626 0.00897319 0.01705888]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.3475079435266
# [0.57343928 0.00898715 0.01610208]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.2382624937093
# [0.54376833 0.00891497 0.01154046]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.1492986913404
# [0.54865236 0.0092468  0.00860274]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.2060958144431
# [0.53069169 0.00934511 0.01015742]
# ['# of iterations for delta convergence: ', 5]
# fval: 743.1055726244857
# [0.49730441 0.00953107 0.0067067 ]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.0318621863457
# [ 0.4600005   0.0091462  -0.00278132]
# ['# of iterations for delta convergence: ', 6]
# fval: 743.0433997022096
# [0.45206314 0.00914802 0.00170782]
# ['# of iterations for delta convergence: ', 4]
# fval: 742.9227209240923
# [ 0.40376853  0.00909863 -0.00173964]
# ['# of iterations for delta convergence: ', 7]
# fval: 742.8335619798739
# [ 0.36361396  0.0096023  -0.0100833 ]
# ['# of iterations for delta convergence: ', 6]
# fval: 742.9624749188314
# [ 0.3831241   0.00967513 -0.00062951]
# ['# of iterations for delta convergence: ', 5]
# fval: 742.7915728885436
# [0.3446859  0.0099396  0.00044639]
# ['# of iterations for delta convergence: ', 6]
# fval: 742.7103076945565
# [ 0.24407451  0.00956262 -0.01429106]
# ['# of iterations for delta convergence: ', 8]
# fval: 742.8195974470539
# [ 0.298072    0.00946493 -0.00030623]
# ['# of iterations for delta convergence: ', 7]
# fval: 742.5481631852551
# [0.26530102 0.00939625 0.0045823 ]
# ['# of iterations for delta convergence: ', 6]
# fval: 742.394831906962
# [ 0.16560576  0.01016701 -0.00443527]
# ['# of iterations for delta convergence: ', 8]
# fval: 742.5724909210867
# [0.27298727 0.01010595 0.01468667]
# ['# of iterations for delta convergence: ', 8]
# fval: 742.3646569095705
# [0.28744366 0.01037762 0.02917554]
# ['# of iterations for delta convergence: ', 6]
# fval: 742.3935124609949
# [0.12457681 0.00983988 0.00944274]
# ['# of iterations for delta convergence: ', 9]
# fval: 742.2284707306945
# [0.01452226 0.00979002 0.01394091]
# ['# of iterations for delta convergence: ', 8]
# fval: 742.2232524883315
# [0.20293461 0.00936113 0.02657519]
# ['# of iterations for delta convergence: ', 9]
# fval: 742.1698416447749
# [0.22159903 0.00895819 0.04208043]
# ['# of iterations for delta convergence: ', 6]
# fval: 742.392112981227
# [0.06166174 0.01010849 0.03221955]
# ['# of iterations for delta convergence: ', 9]
# fval: 742.2021335399572
# [-0.0869082   0.00940047  0.03380376]
# ['# of iterations for delta convergence: ', 9]
# fval: 742.4404468334054
# [0.18301341 0.00992958 0.01946594]
# ['# of iterations for delta convergence: ', 10]
# fval: 742.1816914990354
# [0.28388424 0.00980945 0.03823288]
# ['# of iterations for delta convergence: ', 8]
# fval: 742.3412333090866
# [0.08186276 0.00979488 0.0200139 ]
# ['# of iterations for delta convergence: ', 9]
# fval: 742.1440713556088
# [0.25021211 0.00928191 0.01181714]
# ['# of iterations for delta convergence: ', 9]
# fval: 742.2804587251417
# [0.10879933 0.00990184 0.02711895]
# ['# of iterations for delta convergence: ', 8]
# fval: 742.1421329057209
# [0.07938439 0.00944232 0.02967275]
# ['# of iterations for delta convergence: ', 6]
# fval: 742.1587971580518
# [-0.02290362  0.01006489  0.02462854]
# ['# of iterations for delta convergence: ', 8]
# fval: 742.2575392659927
# [0.14647505 0.00953707 0.02608853]
# ['# of iterations for delta convergence: ', 9]
# fval: 742.1318291568302
# [0.1453737  0.01004688 0.0191415 ]
# ['# of iterations for delta convergence: ', 5]
# fval: 742.1810473997386
# [0.09588172 0.00959346 0.02703994]
# ['# of iterations for delta convergence: ', 7]
# fval: 742.1337778210966
# [0.15224131 0.00956004 0.03348438]
# ['# of iterations for delta convergence: ', 7]
# fval: 742.1700547950754
# [0.0994574  0.00973617 0.02338152]
# ['# of iterations for delta convergence: ', 7]
# fval: 742.1299672442595
# [0.11907678 0.00934262 0.02388771]
# ['# of iterations for delta convergence: ', 5]
# fval: 742.135026408055
# [0.11650742 0.00948243 0.02469552]
# ['# of iterations for delta convergence: ', 4]
# fval: 742.1307190041708
# Object vcov dimensions: (22, 22)
# Object se dimensions: (22,)
# Object theta2w dimensions:     (3,)
# Object t dimensions:     ()
# running time: 88.48851704597473
#         Theta1  Std.Error_theta1    Theta2  Std.Error_theta2  Objective Value
# 0    -0.045354          2.284553  0.116507          3.244887       742.130719
# 1   -12.097471          1.682059  0.009482          0.008207       742.130719
# 2    -0.693128          0.051573  0.024696          1.431213       742.130719
# 3     1.632300          0.238278       NaN               NaN       742.130719
# 4   250.878096         31.907638       NaN               NaN       742.130719
# 5     0.892099          8.617509       NaN               NaN       742.130719
# 6     0.994933          0.645566       NaN               NaN       742.130719
# 7   -21.032786          3.969159       NaN               NaN       742.130719
# 8    -0.137076          0.023108       NaN               NaN       742.130719
# 9    69.466046          4.037482       NaN               NaN       742.130719
# 10   86.208219         10.907337       NaN               NaN       742.130719
# 11  120.229526         13.732040       NaN               NaN       742.130719
# 12  -96.050721         40.916950       NaN               NaN       742.130719
# 13  -21.088946         12.089535       NaN               NaN       742.130719
# 14  190.637972         14.183619       NaN               NaN       742.130719
# 15  144.597837         24.027048       NaN               NaN       742.130719
# 16  -62.719202         15.615292       NaN               NaN       742.130719
# 17  -79.258531         14.672290       NaN               NaN       742.130719
# 18   20.515717         11.495280       NaN               NaN       742.130719

# %%
#POINT 2.2: We now try to add one more observable characteristic, that is “n_medications_col”.

#Loading and cleaning the data

loc = '/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/'

#filo loc = '/Users/filippomajocchi/Desktop/Empirical IO/PSs/EIO_PS/EIO_repository/Computational/Python_codes/'
#veri loc = '/Users/veronicaermini/Documents/ESS/2_1_Empirical IO and Market Design/PS/EIO_repository/Computational/Python_codes/'   
#cami
#leo
#madda loc ='/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes'

class data():        
        
#Data location
    loc1= loc + "data.csv"
    loc2= loc + "demogr.csv"
    loc3= loc + "demogr_means.csv"
    loc4= loc + "demogr_year_region_id.csv"
    loc5= loc + "demogr_iqr.csv"
    loc6= loc + "demogr_std.csv"

#Load data
    data = pd.read_csv(loc1, sep=',', names= list(range(1,189)), encoding='cp1252')
    demogr =  pd.read_csv(loc2, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_means = pd.read_csv(loc3, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_year_region_id = pd.read_csv(loc4, sep=',', names= list(range(1,3)), encoding='cp1252')
    demogr_iqr= pd.read_csv(loc5, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_std= pd.read_csv(loc6, sep=',', names= list(range(1,1001)), encoding='cp1252')

#Column names
    names =  ['id_colid_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_region_end','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','price_col','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','top_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','id_col','id_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','op_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','iv_start_col','iv_end_col','bid_col','gamma_col','true_weight_col','nat_weight_col','groupA_col','group_region_col','group_bid_test_col','ms_lischoosers_col','tot_lis_col','tot_lis_choosers_col','market_sizes_col','ms_lis_col','indicator_bench_col','contract_id_col','benefit_type_col','plan_name_col','lis_col'] 
    x1_names = ['id_colid_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_region_end','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','top_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','id_col','id_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','op_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col'] 
    x2_names = ['price_col']
    D_names = list(range(1,1001))
    IV_names = ['iv_start_col','iv_end_col','bid_col','gamma_col','true_weight_col','nat_weight_col','groupA_col','group_region_col','group_bid_test_col','ms_lischoosers_col','tot_lis_col','tot_lis_choosers_col','market_sizes_col','ms_lis_col','indicator_bench_col','contract_id_col','benefit_type_col','plan_name_col','lis_col']


    id_col=1 #id market plan
    id_market_col=2 #id market
    ms_col=3 #market shares
    dummy_firm_start=4 #first column of firm id's dummies
    dummy_firm_end=79 #last column of firm id's dummies
    dummy_year_start=80 #first column of year's dummies
    dummy_year_end=85 #last column of year's dummies
    dummy_region_start=86 #first column of region's dummies
    dummy_region_end=119 #last column of region's dummies
    dummy_firmname_start=120 #first column of firm name 
    dummy_firmname_end=140 #last column of firm name
    dummy_macroregion_start=141 #first column of firm name 
    dummy_macroregion_end=143 #last column of firm name
    price_col=144
    deductible_col=price_col+1
    n_medications_col=price_col+2 #col 146 - try adding this to x1
    drug_frf_col=price_col+3
    d_cov_gap_col=price_col+4
    d_enhance_col=price_col+5
    top_drug_col=price_col+6
    in_area_flag_col=price_col+7
    vintage_col=price_col+8
    tier_12_col=price_col+9
    d_below_lagged_col=price_col+10
    ms_lis_firm_col=price_col+11
    ms_lis_firm_lagged_col=price_col+12

#LIST OF IV'S
    iv_start_col=price_col+13
    iv_end_col=iv_start_col+12
    bid_col=iv_start_col+15
    gamma_col=iv_start_col+16
    true_weight_col=iv_start_col+17
    nat_weight_col=iv_start_col+18
    groupA_col=iv_start_col+19
    group_region_col=iv_start_col+20
    group_bid_test_col=iv_start_col+21
    ms_lischoosers_col=iv_start_col+22
    tot_lis_col=iv_start_col+23
    tot_lis_choosers_col=iv_start_col+24
    market_sizes_col=iv_start_col+25
    ms_lis_col=iv_start_col+26
    indicator_bench_col=iv_start_col+27 
    contract_id_col=iv_start_col+28
    benefit_type_col=iv_start_col+29
    plan_name_col=iv_start_col+30
    lis_col=iv_start_col+31
    
#Cleaning

#Drop missing iv, dates, no-pharmacy plans

#Missing IV
    data.loc[:,iv_start_col+3] = data.loc[:,iv_start_col+3].fillna(value=0)
    data.loc[:,iv_start_col+4]=data.loc[:,iv_start_col+4].fillna(value=0)
    data.loc[:,iv_start_col+5]=data.loc[:,iv_start_col+5].fillna(value=0)
    data.loc[:,iv_start_col+6]=data.loc[:,iv_start_col+6].fillna(value=0)
    data.loc[:,iv_start_col+11]=data.loc[:,iv_start_col+11].fillna(value=0)
    
#Drop dates
    index = (data.loc[:,1] < 11000000) & (data.loc[:,1]>7000000)
    data = data.loc[index,:]
    
#Drop plans with no pharmacy? check column 151 is this one
    index = (data.loc[:,in_area_flag_col]!= 0) & (data.loc[:,in_area_flag_col]<10000)
    data = data.loc[index,:]

#Re-scaling
    scale=100
    ns=500
    data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
    data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
    data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
    data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
    data.loc[:,in_area_flag_col]=data.loc[:,in_area_flag_col].div(1000)

    demogr.loc[:,1:500]=demogr.loc[:,1:500].div(1000)
    demogr_means.loc[:,1:ns] = demogr_means.loc[:,1:ns].div(1000)

#IV - matrix    
    
    IV= data[list(range(iv_start_col,iv_end_col+1)) + [deductible_col, d_cov_gap_col, d_enhance_col, tier_12_col, top_drug_col, in_area_flag_col ,vintage_col]+list(range(dummy_macroregion_start,dummy_macroregion_end))+list(range(dummy_year_start+1,dummy_year_end-2))+[dummy_firmname_start, dummy_firmname_start+10, dummy_firmname_start+13, dummy_firmname_start+16, dummy_firmname_end]]
    #these columns give non singuality: 6-10
    IV = IV.iloc[:,0:6].join(IV.iloc[:,11:29])
    

#Cleaning missing IV
    index = (np.sum(IV.T.isna()) == 0)
    data = data.loc[index,:]   
    IV = IV.loc[index,:] 
    
 #Reindexing IV 
    IV.index = pd.RangeIndex(len(IV.index))
    IV.columns= pd.RangeIndex(len(IV.columns))
        
         
#x1, x2
    constant=pd.Series(np.ones(np.shape(data[1])),index=data.index,name='constant') #add constant
    x11=data[[price_col, deductible_col, drug_frf_col, d_cov_gap_col, d_enhance_col, tier_12_col, top_drug_col, in_area_flag_col, vintage_col,n_medications_col]+list(range(dummy_macroregion_start,dummy_macroregion_end))+list(range(dummy_year_start+1,dummy_year_end-2))+[dummy_firmname_start,dummy_firmname_start+10,dummy_firmname_start+13,dummy_firmname_start+15,dummy_firmname_start+16,dummy_firmname_end]]
 
    x1 = x11.join(constant)
    col=x1.columns.tolist()
    col= col[-1:] + col[:-1]
    x1=x1[col]
    
    
    x2 = data.loc[:,price_col].values.reshape(len(x1),1)

#Cleaning x1: delete dummies that are always 0 (companies that never offer a plan in 2006) 
    index= np.sum(x1)
    x1 = x1.loc[:,index!=0]

#Reindexing
    x1.index = pd.RangeIndex(len(x1.index))#reindex x1
    x1.columns= pd.RangeIndex(len(x1.columns))

#Indices
    id = data.loc[:,id_col] #id of each observation
    id_demo = data.loc[:,id_market_col].unique() #  number of markets 


#The  vector  below relates each observation to the market it is in / both for data and demographics
    
    cdid=list()
    cdindex=[-1]
    cdid_demogr=list()    

    for i in range(len(id_demo)):
        nbrand_market = np.sum(data.loc[:,id_market_col] == id_demo[i])
        cdid.extend(i*np.ones(nbrand_market)) 
        cdindex.append(cdindex[-1]+nbrand_market) 
        #create the cdid for the demographics
        index_market = data.loc[data[id_market_col]==id_demo[i]].index
        i_index_region= data.loc[index_market[0],dummy_region_start:dummy_region_end]==(1/scale) 
        index_region = np.where(i_index_region)[0] +1 # +1 since id_region [1,34]
        i_index_year= data.loc[index_market[0],dummy_year_start:dummy_year_end] == (1/scale)
        index_year = np.where(i_index_year)[0] + 2005 
        index_demogr = demogr_year_region_id.loc[demogr_year_region_id[1] == index_year[0]].index.intersection(demogr_year_region_id.loc[demogr_year_region_id[2] == index_region[0]].index)

        if np.isnan(index_demogr.values)== 1:
            print(['Demographics not found for region ' + np.array2string(index_region) + ' and year ' + np.array2string(index_year)])
        else:
            cdid_demogr.extend(index_demogr.values*np.ones(nbrand_market,int))## [0,135]
        
    cdindex=cdindex[1:137]
    cdindex=np.asarray(cdindex,dtype=int)

#Create instruments based on demographics
    mean_income= demogr_means.loc[cdid_demogr,1]
    mean_diffall= demogr_means.loc[cdid_demogr,ns+1] 
    std_income = demogr_std.loc[cdid_demogr,1]
    iqr_income=demogr_iqr.loc[cdid_demogr,1] 
    iqr_diffall=demogr_iqr.loc[cdid_demogr,ns+1]#

    IV1 = pd.DataFrame(np.concatenate([np.array([IV.loc[:,13]])*np.array([mean_income]), np.array([IV.loc[:,13]])*np.array([mean_diffall]), np.array([IV.loc[:,13]])*np.array([iqr_income]), np.array([IV.loc[:,13]])*np.array([iqr_diffall])],axis=0).T, index=IV.index, columns=[24,25,26,27])
    IV=IV.merge(IV1, right_index=True, left_index=True) #Try to run without these IV


#Other variables
    K1 = x1.shape[1] #number of product characteristics
    K2 = x2.shape[1] #
    s_jt=data.loc[:,ms_col]
    s_jt= np.reshape(s_jt.values, (np.shape(s_jt)[0],1))#observed market share for product j at time t
    nmkt = len(id_demo)
    r='/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/v.csv'
    v=pd.read_csv(r,sep=',',names= list(range(1000)))

    #v = pd.DataFrame(np.random.randn(nmkt,demogr.shape[1]))


   
    def summary(self):
        print('the number of characteristics in X1 is: '+str(data.x1.shape[1]))
        print('the number of characteristics in X2 is: '+str(data.x2.shape[1]))
        print('Object cdid dimensions: ' +str(np.shape(data.cdid)) )
        print('The dimensions of object cdindex are      ' + str(np.shape(data.cdindex)))
        print('The number of instruments for the price is ' +  str(np.shape(data.IV)[1]))
        print('The dimensions of object IV are ' + str(np.shape(data.IV)))
        print('size id_demo: '+ str(np.shape(data.id_demo)) )
        print("size of cdid is " + str(np.shape((data.cdid))))
        print("size of cdindex is "+ str(np.shape((data.cdindex))))
        print("size of cdid_demogr is "+ str(np.shape((data.cdid_demogr))))



data.summary(data)

# =============================================================================
#
# BLP Algorithm
#
# =============================================================================

#from scipy.optimize import fmin
from scipy.optimize import minimize
import matplotlib.pyplot as plt    
import time
#import optimize2 as opt # import modified optimize.minimize_nelder-mead ; alternatively change line 569 from 'and' to 'or' on original optimize.py

    
class BLP:
    
    def __init__ (self,data,theta2w,mtol,niter): #define data instances
         
        self.niter = niter 
        self.mtol=mtol
        self.theta2w=theta2w 
        self.x1 = data.x1
        self.x2 = data.x2 
        self.s_jt = data.s_jt
        self.v = data.v
        self.cdindex = data.cdindex #consider asarray
        self.cdid = data.cdid
        self.cdid_demogr=data.cdid_demogr
        self.vfull = data.v.loc[self.cdid_demogr,:] 
        dfull = data.demogr.loc[self.cdid_demogr,:]
        dfull.columns= pd.RangeIndex(len(dfull.columns))
        dfull.index = pd.RangeIndex(len(dfull.index))
        self.dfull = dfull
        self.demogr= data.demogr
        self.IV = data.IV
        self.K1 = self.x1.shape[1]
        self.K2 = self.x2.shape[1]
        self.ns = data.ns          # number of simulated "indviduals" per market 
        self.D = int(self.dfull.shape[1]/self.ns)       # number of demographic variables
        self.T = np.asarray(self.cdindex).shape[0]      # number of markets = (# of cities)*(# of quarters)  
        self.TJ = self.x1.shape[0]      #number of observations
        self.J = int(self.TJ/self.T) #average number of observation per market
        
      
        
        self.invA = np.linalg.inv(self.IV.T@self.IV)
        
        
        #mid2 = np.mat(self.x1.T)*np.mat(self.IV)*self.invA*np.mat(self.IV.T)*np.mat(self.x1)
        #invmid2=np.linalg.inv(mid2)
        
        #Calculating s0 -outside good shares
        temp= self.s_jt.cumsum()
        sum1 = temp[self.cdindex] 
        sum1[1:np.shape(sum1)[0]] = np.diff(sum1) 
        outshr = (1 - sum1[np.asarray(self.cdid,dtype=int)]) 
        outshr= np.abs(outshr)
        outshr=np.reshape(outshr,(np.shape(outshr)[0],1))       

        #Find initial guess of coefficients by running simple logit regression
        y=np.log(self.s_jt)-np.log(outshr)
        mid = self.x1.T@self.IV@self.invA@self.IV.T
        t = np.linalg.inv(mid@self.x1)@mid@y 
        
        #Mean utility - initial
        self.mvalold = self.x1@(t) 
        self.mvalold = np.exp(self.mvalold).values.reshape(np.shape(self.mvalold)[0],1)
        self.oldt2 = np.zeros(np.shape(self.theta2w)) #initial old2
        self.gmmvalold = 0
        self.gmmdiff = 1
        self.gmmresid = np.ones((6024,1)) #@@@@@@ initialization
   
    #Transforms inputed guess of theta2w into an ndarray type
    def init_theta(self,theta2w):
        theta2w=theta2w.reshape(1,1+self.D) # #rows: # x2 variables
        self.theti, self.thetj = list(np.where(theta2w != 0))#columns: #demographic variables + 1 (constant)
        self.theta2 = theta2w[np.where(theta2w != 0)]
        return self.theta2
     
        
    #Mean utility function
    def mufunc(self,theta2w): 
        mu = np.zeros((self.TJ, self.ns))
        for i in range(self.ns):
            v_i = np.array(self.vfull.loc[:, np.arange(i, self.K2*self.ns, self.ns)])
            d_i = np.array(self.dfull.loc[:, np.arange(i, self.D*self.ns, self.ns)]) 
            temp = d_i @ theta2w[:, 1:(self.D+1)].T
            mu[:, i]=(np.multiply(self.x2, v_i) @ theta2w[:, 0]) + np.multiply(self.x2, temp) @ np.ones((self.K2))

        return mu
        
    def ind_sh(self,expmu): 
        eg = np.multiply(expmu, np.kron(np.ones((1, self.ns)), self.mvalold)) 
        temp = np.cumsum(eg, 0)
        sum1 = temp[self.cdindex, :]
        sum2 = sum1
        sum2[1:sum2.shape[0], :] = np.diff(sum1.T).T
        denom1 = 1. / (1. + sum2)
        denom = denom1[np.asarray(self.cdid,dtype=int), :]
        
        return np.multiply(eg, denom)

    def mktsh(self,expmu):
        #compute the market share for each product
        temp = self.ind_sh(expmu).T
        f = (sum(temp) / float(self.ns)).T
        f = f.reshape(self.x1.shape[0],1)
        return f
        
        
    def meanval(self,theta2):
        #phased tolerance to speed up computation
#        if self.gmmdiff < 1e-15:
#            self.mtol = 1e-15
#        elif self.gmmdiff < 1e-3:
#            self.mtol = 1e-4
#        else:
#            self.mtol = 1e-2
        
        if np.ndarray.max(np.absolute(theta2-self.oldt2)) < 0.01: 
            tol = self.mtol
            flag=0
        else:
            tol = self.mtol #when theta2 (output of minimize) is still larger than 0.01, flag=1 => pass it to theta old2, that will be used in next iteration
            flag = 1
        norm = 1
        avgnorm = 1
        i = 0
        theta2w = np.zeros((self.K2,self.D+1)) 
        for ind in range(len(self.theti)): 
            theta2w[self.theti[ind], self.thetj[ind]] = theta2[ind] 
        expmu=np.exp(self.mufunc(theta2w))
       
        while (norm > self.mtol) & (i<self.niter): 
           
            pred_s_jt = self.mktsh(expmu) 
            self.mval = np.multiply(self.mvalold,self.s_jt) / pred_s_jt 
            t = np.abs(self.mval - self.mvalold)
            norm = np.max(t)
            avgnorm = np.mean(t)
            self.mvalold = self.mval
            i += 1
           
            if (norm > self.mtol) & (i > self.niter-1):
                print('Max number of ' + str(niter) + 'iterations reached')
    
        print(['# of iterations for delta convergence: ' , i])
	
        if (flag == 1) & (sum(np.isnan(self.mval)))==0: 
            self.mvalold = self.mval
            self.oldt2 = theta2
        return np.log(self.mval)
 
 
    #Calculates the jacobian of the 
    def jacob(self,theta2): 
        cdindex=np.asarray(self.cdindex,dtype=int)
        theta2w = np.zeros((self.K2, self.D+1))
        for ind in range(len(self.theti)):
            theta2w[self.theti[ind], self.thetj[ind]] = self.theta2[ind] #build theta2w (from array to ndarray) to plug in ind_sh
        expmu=np.exp(self.mufunc(theta2w)) 
        shares = self.ind_sh(expmu)
        f1 = np.zeros((np.asarray(self.cdid).shape[0] ,self.K2 * (self.D + 1)))
        # calculate derivative of shares with respect to the first column of theta2w (variable that are not interacted with demogr var, sigmas)
        for i in range(self.K2):
            xv = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)),self.v.loc[self.cdid, self.ns*i:self.ns * (i+1)-1])
            temp = np.cumsum(np.multiply(xv, shares), 0).values
            sum1 = temp[cdindex, :]
            sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
            f1[:,i] = np.mean((np.multiply(shares, xv - sum1[np.asarray(self.cdid,dtype=int),:])),1) #mean over columns
           
        for j in range(self.D):
            d = self.demogr.loc[self.cdid,self.ns*(j)+1:self.ns*(j+1)] 
            temp1 = np.zeros((np.asarray(self.cdid).shape[0],self.K2))
            for i in range(self.K2):
                xd = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)), d)
                temp = np.cumsum(np.multiply(xd, shares), 0).values
                sum1 = temp[cdindex, :]
                sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
                temp1[:, i] = np.mean((np.multiply(shares, xd-sum1[np.asarray(self.cdid,dtype=int), :])), 1)
            f1[:,self.K2 * (j + 1):self.K2 * (j + 2)] = temp1 

        self.rel = self.theti + self.thetj * (max(self.theti)+1) 
        f = np.zeros((np.shape(self.cdid)[0],self.rel.shape[0]))
        n = 0
        
        for i in range(np.shape(self.cdindex)[0]):
            temp = shares[n:(self.cdindex[i] + 1), :]
            H1 = temp @ temp.T
            H = (np.diag(np.array(sum(temp.T)).flatten())-H1) / self.ns
            f[n:(cdindex[i]+1),:] = np.linalg.inv(H) @ f1[n:(cdindex[i] + 1),self.rel]
            n = cdindex[i] + 1
        return f
       
    #Compute GMM objective function       
    def gmmobj(self,theta2):
        print(theta2)
        delta = self.meanval(theta2)
        self.theta2=theta2
        # the following deals with cases where the min algorithm drifts into region where the objective is not defined
        if max(np.isnan(delta)) == 1: 
            f = np.ndarray((1,1),buffer=np.array([1e+10,1e+10])) 
        else:
            temp1 = self.x1.T @ self.IV
            temp2 = delta.T@self.IV
            self.theta1 = np.linalg.inv(temp1@self.invA@temp1.T)@temp1@self.invA@temp2.T
            self.gmmresid = delta - self.x1@self.theta1
            temp1 = self.gmmresid.T@(self.IV) 
            f = temp1@self.invA@temp1.T
            f=f.values
            if np.shape(f) > (1,1):
                temp = self.jacob(theta2).T 
                df = 2*temp@self.IV@self.invA@self.IV.T@self.gmmresid 
        print('fval:', f[0,0]) #value of the gmm objective function
        
        #to be used in meanval to phase tolerance based on gmm value
        self.gmmvalnew = f[0,0]
        self.gmmdiff = np.abs(self.gmmvalold - self.gmmvalnew)
        self.gmmvalold = self.gmmvalnew
        
        return (f[0,0])
       
               

    #Calculates the gradient of the objective function based on jacobian
    def gradobj(self,theta2):
        temp = self.jacob(theta2).T 
        df = 2*temp@self.IV@self.invA@self.IV.T@self.gmmresid 
        df=df.values ##@@
        print('this is the gradient '+str(df))
    
        return df
    
  
    #WARNING!!!!!!!! In some versions of scipy there can be a problem with xatol in optimize.minimize_neldermead. IF so, change optimize.py codeline 569: replace 'and' to 'or'OR use modified script optimize2.py 
    
     
    #Maximizes the objective function
    def iterate_optimization(self,opt_func, param_vec,jac,options ): 
        res = minimize(opt_func, param_vec,method='nelder-mead',options=options) 
        ##res = opt._minimize_neldermead(opt_func, param_vec,disp=True,maxiter=100,fatol=0.0001,xatol=0.0001)
        #res = minimize(opt_func, param_vec, method='BFGS', bounds=None, callback=None, options=options)
    
        return res
            
    
    #Calculates the variance-covariance matrix of the estimates
    
    def varcov(self,theta2): 
        Z = self.IV.shape[1]
        temp = self.jacob(theta2)                                              
        a = np.concatenate((self.x1.values, temp), 1).T @ self.IV.values
        IVres = np.multiply(self.IV.values,self.gmmresid.values @ np.ones((1, Z)))
        b = IVres.T@(IVres)
        if np.linalg.det(a @ np.asarray(self.invA) @ a.T)!= 0:
            inv_aAa = np.linalg.inv(a @ np.asarray(self.invA) @ a.T)
        else:
            print('Error: singular matrix in covariate function ; forced result') #if jacobian has row of zeros
            inv_aAa = np.linalg.lstsq(a @ np.asarray(self.invA) @ a.T)
        f = inv_aAa @ a @ np.asarray(self.invA) @ b @ np.asarray(self.invA) @ a.T @ inv_aAa   
        return f    


    #Computes estimates of the coefficients and its standard errors; outputs a histogram and a csv file with estimates
    def results(self,theta2):
        self.theta1=self.theta1.values
        var = self.varcov(self.theta2)
        se = np.sqrt(var.diagonal())
        t = se.shape[0] - self.theta2.shape[0]
        
        print('Object vcov dimensions: ' + str(np.shape(var)) )
        print('Object se dimensions: ' + str(np.shape(se)))
        
        print('Object theta2w dimensions:     ' + str(np.shape(self.theta2)))
        print('Object t dimensions:     ' + str(np.shape(t)))
        

#Histogram of the coefficients
        alfa_i=[]
        alfa_i2=[]
        for i in range(0,self.T): 
            data_market=np.reshape(self.demogr.loc[i,0:self.ns*self.D].values,(self.ns,self.D))
            v_market=np.reshape(self.v.loc[i,0:self.ns-1].values,(self.ns,1)) # caution: v is created to have 1000 columns
            alfa_i2.extend(np.add(data_market@(self.theta2[1:3]).T, self.theta2[0]*v_market[:,0])) 
            alfa_i.extend(data_market@(self.theta2[1:3].T))
        #alfa_i=(self.theta1[1]+alfa_i2)/100 
        alfa_i=(self.theta1[1]+alfa_i2)/100
        h=plt.figure()
        plt.hist(alfa_i,bins=25,range=(np.min(alfa_i),np.max(alfa_i)))
        plt.grid(axis='y', alpha=0.75)
        plt.xlabel('Value')
        plt.ylabel('Frequency')
        plt.title('Distribution of the price coefficient -2007')
        h.savefig('elasticities.png')
        #compute the elasticities
        #reshape the alfas
        alfa_i_reshaped=np.reshape(alfa_i,(self.ns,len(self.cdindex))).T #changed from cdindex (136) to cdid (6024) to match matlab size
        alfa_i_reshaped=alfa_i_reshaped[np.asarray(self.cdid,dtype=int),:]
        
        #convert theta2 into ndarray to plug in ind_sh
        theta = np.zeros((self.K2, self.D+1))
        for ind in range(len(self.theti)):
            theta[self.theti[ind], self.thetj[ind]] = self.theta2[ind] 
       #######
        expmu=np.exp(self.mufunc(theta))
        f = self.ind_sh(expmu)
        mval=(self.x1@self.theta1)
     
        #from ind_sh function: here mvalold = gmmresid +mval
        eg = np.multiply(np.exp(self.mufunc(theta)), np.kron(np.ones((1, self.ns)), (mval+self.gmmresid))) 
        temp = np.cumsum(eg, 0)
        sum1 = temp[self.cdindex, :]
        sum2 = sum1
        sum2[1:sum2.shape[0], :] = np.diff(sum1.T).T
        denom1 = 1. / (1. + sum2)
        denom = denom1[np.asarray(self.cdid,dtype=int), :]
        f22= np.multiply(eg, denom)
        ######
        f2 = np.sum(f22.T,0)/self.ns
        f2 = f2.T
        error=self.s_jt-f2     

        #table with parameters + export to csv file
        
        self.theta1_results= pd.DataFrame({'Theta1':self.theta1.reshape(self.K1,),'Std.Error_theta1': se[0:-self.theta2.shape[0]]},columns=(['Theta1','Std.Error_theta1'])) 
        self.theta2_results= pd.DataFrame({'Theta2':self.theta2.reshape(self.theta2.shape[0],), 'Std.Error_theta2':se[-self.theta2.shape[0]:]},columns=(['Theta2','Std.Error_theta2']))
        self.theta1_results.to_csv(loc + "theta1.csv")
        self.theta2_results.to_csv(loc + "theta2.csv")
        
        return self.theta1_results, self.theta2_results, self.gmmvalnew
 
# =============================================================================
# Define parameters to input in the algorithm    
# =============================================================================


starttime = time.time()

#Maximum number of iterations for convergence of mval-mvalold contraction
niter = 2500

#Initial guess for coefficients
theta2w = np.array([0.50,-0.5,0.5])
#theta2w = np.array([0.20,-0.01,0.01,-0.5,0.05,0.05])

#Maximum tolerance 
mtol= 1e-5 

#Set optimization options
options={'disp': None,'maxiter': 100,'xatol':0.0001,'fatol':0.0001}

#Get output
blp = BLP(data,theta2w,mtol,niter)
init_theta = blp.init_theta(theta2w) 
res = blp.iterate_optimization(opt_func=blp.gmmobj,param_vec=init_theta,jac=blp.gradobj,options=options) 
theta1_results, theta2_results, gmmvalnew = blp.results(res.x)

endtime=time.time()
run = endtime-starttime
print('running time: ' + str(endtime-starttime))
a=time.time()

#Create a table with the results
results_table = pd.DataFrame({
    'Theta1_2': theta1_results['Theta1'],
    'Std.Error_theta1_2': theta1_results['Std.Error_theta1'],
    'Theta2_2': theta2_results['Theta2'],
    'Std.Error_theta2_2': theta2_results['Std.Error_theta2'],
    'Objective Value_2': [gmmvalnew] * len(theta1_results)
})

# Save results_table to a file
results_table.to_csv('results_table2.csv', index=False)


print(results_table)
# Out:
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   2.65 0.   ... 0.   3.1  0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[54.85 54.85 54.85 ... 31.42 38.84 38.84]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 9.59  9.59  9.59 ...  9.85 10.57 10.57]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.   0.   ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.   0.01 ... 0.   0.   0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.93 0.93 0.93 ... 0.99 0.99 0.99]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.05 0.04 0.04]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.72 0.72 0.72 ... 0.86 0.89 0.89]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.   0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2739890207.py:113: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.506 0.506 0.506 ... 0.108 0.12  0.12 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,in_area_flag_col]=data.loc[:,in_area_flag_col].div(1000)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# the number of characteristics in X1 is: 20
# the number of characteristics in X2 is: 1
# Object cdid dimensions: (6024,)
# The dimensions of object cdindex are      (136,)
# The number of instruments for the price is 28
# The dimensions of object IV are (6024, 28)
# size id_demo: (136,)
# size of cdid is (6024,)
# size of cdindex is (136,)
# size of cdid_demogr is (6024,)
# [ 0.5 -0.5  0.5]
# ['# of iterations for delta convergence: ', 78]
# fval: 8704.683615367425
# [ 0.525 -0.5    0.5  ]
# ['# of iterations for delta convergence: ', 4]
# fval: 8704.56679010112
# [ 0.5   -0.525  0.5  ]
# ['# of iterations for delta convergence: ', 45]
# fval: 9549.897312804636
# [ 0.5   -0.5    0.525]
# ['# of iterations for delta convergence: ', 45]
# fval: 8723.672477839682
# [ 0.51666667 -0.475       0.51666667]
# ['# of iterations for delta convergence: ', 43]
# fval: 7914.652504597823
# [ 0.525 -0.45   0.525]
# ['# of iterations for delta convergence: ', 43]
# fval: 7161.075052452153
# [ 0.53333333 -0.46666667  0.49166667]
# ['# of iterations for delta convergence: ', 41]
# fval: 7638.217205325788
# [ 0.55555556 -0.44444444  0.51111111]
# ['# of iterations for delta convergence: ', 42]
# fval: 6987.819143577544
# [ 0.58333333 -0.41666667  0.51666667]
# ['# of iterations for delta convergence: ', 43]
# fval: 6209.20523738335
# [ 0.56944444 -0.38888889  0.52222222]
# ['# of iterations for delta convergence: ', 42]
# fval: 5485.125642932321
# [ 0.59166667 -0.33333333  0.53333333]
# ['# of iterations for delta convergence: ', 45]
# fval: 4199.183950721141
# [ 0.6        -0.33333333  0.55833333]
# ['# of iterations for delta convergence: ', 24]
# fval: 4217.994542864506
# [ 0.65833333 -0.27222222  0.54722222]
# ['# of iterations for delta convergence: ', 43]
# fval: 3037.937459404236
# [ 0.725      -0.18333333  0.55833333]
# ['# of iterations for delta convergence: ', 39]
# fval: 1810.695784864323
# [ 0.69444444 -0.15        0.58333333]
# ['# of iterations for delta convergence: ', 32]
# fval: 1507.8494891495764
# [ 0.75       -0.01666667  0.61666667]
# ['# of iterations for delta convergence: ', 28]
# fval: 899.049095623108
# [ 0.77777778 -0.02222222  0.58055556]
# ['# of iterations for delta convergence: ', 16]
# fval: 880.8725277419226
# [0.86666667 0.13333333 0.59166667]
# ['# of iterations for delta convergence: ', 80]
# fval: 12767.42335541726
# [0.91018519 0.18518519 0.63703704]
# ['# of iterations for delta convergence: ', 55]
# fval: 31924.1536061412
# [ 0.6712963  -0.2037037   0.55925926]
# ['# of iterations for delta convergence: ', 49]
# fval: 2046.8781417492428
# [0.83055556 0.05555556 0.61111111]
# ['# of iterations for delta convergence: ', 34]
# fval: 1092.509427500218
# [0.84722222 0.19444444 0.64722222]
# ['# of iterations for delta convergence: ', 67]
# fval: 40244.89698730534
# [ 0.75555556 -0.08888889  0.58055556]
# ['# of iterations for delta convergence: ', 39]
# fval: 1094.2039865847275
# [0.81666667 0.1        0.625     ]
# ['# of iterations for delta convergence: ', 52]
# fval: 5353.472984440375
# [ 0.77083333 -0.04166667  0.59166667]
# ['# of iterations for delta convergence: ', 33]
# fval: 930.5763243803607
# [ 0.70185185 -0.10925926  0.58148148]
# ['# of iterations for delta convergence: ', 30]
# fval: 1206.7184852751177
# [0.79837963 0.01435185 0.6037037 ]
# ['# of iterations for delta convergence: ', 26]
# fval: 859.8764566218639
# [0.77993827 0.02530864 0.60895062]
# ['# of iterations for delta convergence: ', 16]
# fval: 877.6569354612841
# [0.82073045 0.02829218 0.57880658]
# ['# of iterations for delta convergence: ', 15]
# fval: 865.1971718231766
# [0.82158779 0.06752401 0.61375171]
# ['# of iterations for delta convergence: ', 44]
# fval: 1374.7223366609085
# [7.88730281e-01 2.14334705e-04 5.88854595e-01]
# ['# of iterations for delta convergence: ', 30]
# fval: 854.643020605245
# [0.82528864 0.0032636  0.5719593 ]
# ['# of iterations for delta convergence: ', 15]
# fval: 839.9143120065169
# [ 0.84796382 -0.00775892  0.55346365]
# ['# of iterations for delta convergence: ', 13]
# fval: 839.3930599154866
# [ 0.80265203 -0.023754    0.58520805]
# ['# of iterations for delta convergence: ', 21]
# fval: 887.2937805217928
# [0.81621085 0.01528064 0.58040695]
# ['# of iterations for delta convergence: ', 18]
# fval: 843.610078682434
# [ 0.83689034 -0.00919448  0.54477976]
# ['# of iterations for delta convergence: ', 15]
# fval: 835.2241234803383
# [ 0.85614569 -0.02096765  0.51531779]
# ['# of iterations for delta convergence: ', 16]
# fval: 832.7565065636519
# [ 0.89148329 -0.00917829  0.51060433]
# ['# of iterations for delta convergence: ', 17]
# fval: 812.8423391536637
# [ 0.9428598 -0.0138746  0.4714792]
# ['# of iterations for delta convergence: ', 15]
# fval: 795.0381406722836
# [ 0.94843536 -0.04368141  0.44643347]
# ['# of iterations for delta convergence: ', 20]
# fval: 833.8275567058749
# [ 0.98366341 -0.04459019  0.40202332]
# ['# of iterations for delta convergence: ', 15]
# fval: 810.0103137746842
# [ 0.90667724 -0.00927355  0.47944673]
# ['# of iterations for delta convergence: ', 19]
# fval: 793.6122427531684
# [0.88579818 0.00793038 0.49595336]
# ['# of iterations for delta convergence: ', 12]
# fval: 787.8960657423696
# [ 1.01873523 -0.01272196  0.3976528 ]
# ['# of iterations for delta convergence: ', 16]
# fval: 753.4234843039966
# [ 1.10003001 -0.00859911  0.3388203 ]
# ['# of iterations for delta convergence: ', 14]
# fval: 722.823965464591
# [0.96879525 0.03489464 0.46881192]
# ['# of iterations for delta convergence: ', 22]
# fval: 832.8084735700578
# [ 0.97994637 -0.02471898  0.41872047]
# ['# of iterations for delta convergence: ', 16]
# fval: 780.5615645078292
# [ 1.03432324 -0.00305054  0.36418356]
# ['# of iterations for delta convergence: ', 15]
# fval: 727.8562088900992
# [ 1.19040156 -0.03217614  0.25186286]
# ['# of iterations for delta convergence: ', 15]
# fval: 719.841665233357
# [ 1.34270325 -0.0522294   0.12981761]
# ['# of iterations for delta convergence: ', 17]
# fval: 726.5794972202024
# [ 1.23655684 -0.00449821  0.21785734]
# ['# of iterations for delta convergence: ', 16]
# fval: 681.4256028597435
# [1.36486207 0.00561218 0.11742578]
# ['# of iterations for delta convergence: ', 12]
# fval: 663.029816111044
# [ 1.40253919 -0.0203915   0.10788907]
# ['# of iterations for delta convergence: ', 12]
# fval: 674.4188419950214
# [ 1.53850521 -0.02270453 -0.02070183]
# ['# of iterations for delta convergence: ', 11]
# fval: 668.9275796692613
# [ 1.68020275  0.0071869  -0.11545418]
# ['# of iterations for delta convergence: ', 12]
# fval: 671.1981838541632
# [ 1.65317417  0.01378787 -0.12037588]
# ['# of iterations for delta convergence: ', 10]
# fval: 679.2692864955006
# [ 1.46519793 -0.01184666  0.05082283]
# ['# of iterations for delta convergence: ', 11]
# fval: 663.2885029636318
# [ 1.23217406 -0.02647957  0.2138187 ]
# ['# of iterations for delta convergence: ', 15]
# fval: 700.501580431989
# [ 1.56819558e+00 -1.22971692e-03 -3.31359577e-02]
# ['# of iterations for delta convergence: ', 13]
# fval: 659.8972769858447
# [1.39366518 0.0177284  0.11077693]
# ['# of iterations for delta convergence: ', 13]
# fval: 669.800420978529
# [ 1.5022952  -0.0125963   0.01216786]
# ['# of iterations for delta convergence: ', 11]
# fval: 662.2003773730247
# [1.49170397 0.00637077 0.01348229]
# ['# of iterations for delta convergence: ', 10]
# fval: 659.7049634639366
# [ 1.50495699  0.01547949 -0.00518798]
# ['# of iterations for delta convergence: ', 12]
# fval: 667.5517779828739
# [ 1.67660109 -0.01058234 -0.12241632]
# ['# of iterations for delta convergence: ', 12]
# fval: 667.9996823979108
# [1.44279683 0.00156355 0.05746526]
# ['# of iterations for delta convergence: ', 11]
# fval: 659.6775681045933
# [1.49950238 0.01706603 0.01303987]
# ['# of iterations for delta convergence: ', 13]
# fval: 669.9658024765049
# [ 1.501597   -0.00518071  0.01238586]
# ['# of iterations for delta convergence: ', 11]
# fval: 659.3088320196454
# [1.38920295 0.00306545 0.08869157]
# ['# of iterations for delta convergence: ', 9]
# fval: 660.9951027652291
# [ 1.52344742e+00 -1.55923964e-04 -2.67907655e-03]
# ['# of iterations for delta convergence: ', 9]
# fval: 659.0241234869685
# [ 1.48685686 -0.00888616  0.03129907]
# ['# of iterations for delta convergence: ', 8]
# fval: 661.0303465836126
# [1.49049219 0.00255654 0.01793649]
# ['# of iterations for delta convergence: ', 8]
# fval: 659.22136147826
# [ 1.56756091 -0.00341695 -0.03903641]
# ['# of iterations for delta convergence: ', 9]
# fval: 659.9940169345363
# [1.47398785e+00 3.18425062e-04 3.33398409e-02]
# ['# of iterations for delta convergence: ', 9]
# fval: 658.9993955023016
# [1.49035465 0.00699341 0.0200123 ]
# ['# of iterations for delta convergence: ', 8]
# fval: 659.6431566242105
# [ 1.49878641 -0.00213718  0.01429247]
# ['# of iterations for delta convergence: ', 8]
# fval: 658.8347651791356
# [ 1.50698893 -0.00387299  0.01203234]
# ['# of iterations for delta convergence: ', 6]
# fval: 659.1226392995594
# [ 1.50286474 -0.00226561  0.01350838]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.8874008629858
# [ 1.46031191 -0.00256699  0.04343954]
# ['# of iterations for delta convergence: ', 7]
# fval: 659.373133660331
# [ 1.50766354e+00 -7.58690257e-04  8.85057669e-03]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.8451161819734
# [ 1.53222195 -0.00375942 -0.00890556]
# ['# of iterations for delta convergence: ', 7]
# fval: 659.1915715302196
# [ 1.48854637e+00 -7.01034963e-04  2.27784914e-02]
# ['# of iterations for delta convergence: ', 8]
# fval: 658.8523302283633
# [ 1.49379948e+00 -1.32329279e-04  1.71059858e-02]
# ['# of iterations for delta convergence: ', 3]
# fval: 658.8163514427966
# [1.48926684e+00 9.34311284e-04 1.89047910e-02]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.8935511679305
# [ 1.51161991e+00 -1.31776760e-03  4.05419925e-03]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.8298998626196
# [ 1.49514032 -0.00163283  0.01478453]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.7629434761943
# [ 1.48887871 -0.0020699   0.01775151]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.7638846197088
# [1.50158673e+00 8.18993677e-05 9.67066914e-03]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.8210732910461
# [1.48206444e+00 1.95593969e-04 2.36532567e-02]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.8158176998654
# [ 1.47908276e+00 -1.12827659e-03  2.73585118e-02]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.8568283115754
# [ 1.49596074e+00 -2.20644623e-04  1.40926298e-02]
# ['# of iterations for delta convergence: ', 5]
# fval: 658.7843991328165
# [ 1.48831085e+00 -9.72924844e-04  1.79142912e-02]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.7195874320483
# [ 1.48556654e+00 -1.39322263e-03  1.83184440e-02]
# ['# of iterations for delta convergence: ', 3]
# fval: 658.6946234917323
# [ 1.50238063 -0.00236006  0.00781048]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.7774435723654
# [ 1.49276426 -0.0033701   0.013183  ]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.8504880147304
# [ 1.49516162e+00 -1.00800770e-03  1.38652235e-02]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.7338915216251
# [ 1.48153169e+00 -3.29314747e-04  2.35016525e-02]
# ['# of iterations for delta convergence: ', 5]
# fval: 658.7723664039306
# [ 1.48674392e+00 -8.37000849e-04  1.95788590e-02]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.7433129071314
# [ 1.48317440e+00 -5.25990251e-04  1.97238220e-02]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.6916406091868
# [1.47719144e+00 2.74298885e-05 2.21934684e-02]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.6885300731444
# [ 1.48520248e+00 -7.45532774e-04  1.66725650e-02]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.6535959620422
# [ 1.48443175e+00 -6.99798737e-04  1.52194180e-02]
# ['# of iterations for delta convergence: ', 2]
# fval: 658.6027353784659
# [ 1.46963154e+00 -3.69053286e-04  2.32889968e-02]
# ['# of iterations for delta convergence: ', 5]
# fval: 658.5842643963774
# [ 1.45686651e+00 -4.95760812e-05  2.80008834e-02]
# ['# of iterations for delta convergence: ', 5]
# fval: 658.543557136069
# [1.46009326e+00 9.11926007e-04 2.52907359e-02]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.5990182039446
# [1.45706957e+00 8.09375705e-05 2.34805564e-02]
# ['# of iterations for delta convergence: ', 5]
# fval: 658.425937475082
# [1.44700863e+00 1.07691412e-04 2.41241004e-02]
# ['# of iterations for delta convergence: ', 5]
# fval: 658.2932465037601
# [1.42488051e+00 1.34649296e-03 3.63910618e-02]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.4658521662346
# [1.42574384e+00 2.44795212e-05 3.37199612e-02]
# ['# of iterations for delta convergence: ', 4]
# fval: 658.2807384030183
# [ 1.40856913e+00 -4.19243721e-04  3.79345738e-02]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.1864080827148
# [1.39677234e+00 7.39536516e-04 3.76322740e-02]
# ['# of iterations for delta convergence: ', 6]
# fval: 658.0442777880552
# [1.36672526e+00 1.13409281e-03 4.24479692e-02]
# ['# of iterations for delta convergence: ', 6]
# fval: 657.8383748745998
# [ 1.38998817e+00 -7.98132625e-04  3.32800338e-02]
# ['# of iterations for delta convergence: ', 6]
# fval: 657.7529071886739
# [ 1.37254199 -0.00187045  0.03172452]
# ['# of iterations for delta convergence: ', 6]
# fval: 657.5095316774134
# [ 1.31821562e+00 -8.78088962e-04  5.06139415e-02]
# ['# of iterations for delta convergence: ', 7]
# fval: 657.5497390853453
# [ 1.29641946e+00 -6.57050657e-04  4.52563798e-02]
# ['# of iterations for delta convergence: ', 7]
# fval: 656.9885011787503
# [ 1.24034462e+00 -7.75954124e-04  4.89172828e-02]
# ['# of iterations for delta convergence: ', 8]
# fval: 656.4728091094041
# [ 1.25400957 -0.00348375  0.04505586]
# ['# of iterations for delta convergence: ', 6]
# fval: 656.8235860221384
# [ 1.25971516 -0.00320868  0.0331845 ]
# ['# of iterations for delta convergence: ', 6]
# fval: 656.2828135072963
# [ 1.23046493 -0.00437397  0.02446978]
# ['# of iterations for delta convergence: ', 7]
# fval: 655.8282885580156
# [ 1.11067075 -0.00388534  0.04723743]
# ['# of iterations for delta convergence: ', 9]
# fval: 655.4102337224808
# [ 0.97973513 -0.00489279  0.05499388]
# ['# of iterations for delta convergence: ', 9]
# fval: 654.8748435604724
# [ 1.04635356 -0.00321139  0.04053144]
# ['# of iterations for delta convergence: ', 7]
# fval: 654.3020494064771
# [ 0.94252555 -0.00307521  0.03826923]
# ['# of iterations for delta convergence: ', 8]
# fval: 653.2637562712292
# [ 0.86147246 -0.00745203  0.02957131]
# ['# of iterations for delta convergence: ', 8]
# fval: 653.4492833115133
# [ 0.62535716 -0.00590605  0.05741983]
# ['# of iterations for delta convergence: ', 10]
# fval: 653.0354884732228
# [ 0.32280327 -0.00667208  0.07389486]
# ['# of iterations for delta convergence: ', 10]
# fval: 653.6404342868185
# [ 0.63983498 -0.00606274  0.02851303]
# ['# of iterations for delta convergence: ', 10]
# fval: 651.7133294123643
# [ 0.4698849  -0.00664771  0.0152726 ]
# ['# of iterations for delta convergence: ', 9]
# fval: 650.8991942390719
# [ 0.49703929 -0.00296728  0.04440313]
# ['# of iterations for delta convergence: ', 7]
# fval: 651.0740421976502
# [ 0.11899535 -0.00727215  0.03979448]
# ['# of iterations for delta convergence: ', 10]
# fval: 651.8330618668591
# [ 0.0985892  -0.00535205  0.00889364]
# ['# of iterations for delta convergence: ', 7]
# fval: 650.2622544225665
# [-0.16479478 -0.00507505 -0.01536945]
# ['# of iterations for delta convergence: ', 10]
# fval: 650.8115692075702
# [ 0.59134691 -0.00270588  0.00591843]
# ['# of iterations for delta convergence: ', 11]
# fval: 650.2523462776744
# [ 8.27522693e-01 -4.22747131e-04 -1.10195923e-02]
# ['# of iterations for delta convergence: ', 10]
# fval: 651.3503137415247
# [ 0.27617472 -0.00683648 -0.02434668]
# ['# of iterations for delta convergence: ', 11]
# fval: 650.354601904682
# [ 0.17418899 -0.00328189 -0.021629  ]
# ['# of iterations for delta convergence: ', 8]
# fval: 649.666014818854
# [ 0.02634103 -0.00159898 -0.0400798 ]
# ['# of iterations for delta convergence: ', 9]
# fval: 650.1302017621906
# [ 0.29990867 -0.00072341  0.01980206]
# ['# of iterations for delta convergence: ', 10]
# fval: 649.620579203935
# [0.31177565 0.00233313 0.04187643]
# ['# of iterations for delta convergence: ', 6]
# fval: 650.1282248450416
# [ 0.61170718  0.00087793 -0.00616598]
# ['# of iterations for delta convergence: ', 10]
# fval: 650.295946945955
# [ 0.22686869 -0.00379455  0.00512874]
# ['# of iterations for delta convergence: ', 10]
# fval: 649.744708543076
# [-0.12403601 -0.00249402 -0.00371724]
# ['# of iterations for delta convergence: ', 10]
# fval: 650.1348372777028
# [ 0.05480972 -0.00254699 -0.00130832]
# ['# of iterations for delta convergence: ', 9]
# fval: 649.6596914171481
# [ 0.12573623 -0.00057364 -0.00721891]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.422901413236
# [ 0.07516999  0.00103682 -0.01339273]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.606250711038
# [0.1461141  0.00071921 0.02914556]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.727021731102
# [ 0.16717026 -0.00228162 -0.00893536]
# ['# of iterations for delta convergence: ', 5]
# fval: 649.4803176447203
# [3.40400387e-01 1.61212969e-04 3.74017744e-03]
# ['# of iterations for delta convergence: ', 9]
# fval: 649.4775863891535
# [ 0.12229591 -0.00107262 -0.02807812]
# ['# of iterations for delta convergence: ', 9]
# fval: 649.6798081705849
# [ 0.25550548 -0.00081071  0.00783201]
# ['# of iterations for delta convergence: ', 8]
# fval: 649.4304652451833
# [0.31392447 0.0014662  0.01183755]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.559765410628
# [ 0.20385881 -0.00134466 -0.00374213]
# ['# of iterations for delta convergence: ', 8]
# fval: 649.3930486260921
# [ 0.04966663 -0.00198055 -0.0058262 ]
# ['# of iterations for delta convergence: ', 9]
# fval: 649.5948558953261
# [ 0.26771695 -0.00037423  0.00134858]
# ['# of iterations for delta convergence: ', 9]
# fval: 649.3906052096626
# [ 0.14270251 -0.00071764 -0.01424032]
# ['# of iterations for delta convergence: ', 8]
# fval: 649.4563593133348
# [ 0.22730474 -0.00078744  0.00231393]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.3860319046487
# [ 0.34018411 -0.00109725  0.00716583]
# ['# of iterations for delta convergence: ', 8]
# fval: 649.507102117259
# [ 0.1793482  -0.00070454 -0.00362273]
# ['# of iterations for delta convergence: ', 9]
# fval: 649.3795040343326
# [2.45721108e-01 1.00522826e-04 3.76866034e-03]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.3938918175693
# [ 0.21432439 -0.00098337 -0.00186444]
# ['# of iterations for delta convergence: ', 6]
# fval: 649.3787025008503
# [ 0.14626794 -0.00127601 -0.00346407]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.4174549788398
# [ 2.37354694e-01 -5.99672971e-04  1.45420168e-04]
# ['# of iterations for delta convergence: ', 8]
# fval: 649.3767944639812
# [ 0.19338011 -0.00073761 -0.00587509]
# ['# of iterations for delta convergence: ', 6]
# fval: 649.3790326979404
# [ 0.25069127 -0.00084256 -0.00144001]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.3817611920933
# [ 0.19718396 -0.00073905 -0.00307705]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.37442524988
# [ 0.23919525 -0.00081045  0.00267772]
# ['# of iterations for delta convergence: ', 6]
# fval: 649.3905839542076
# [ 0.2048339  -0.00075582 -0.00373689]
# ['# of iterations for delta convergence: ', 6]
# fval: 649.373591342913
# [ 0.21192398 -0.00041299 -0.00258124]
# ['# of iterations for delta convergence: ', 3]
# fval: 649.3713810729178
# [ 2.10723781e-01 -1.27803158e-04 -2.93964473e-03]
# ['# of iterations for delta convergence: ', 2]
# fval: 649.3738717626379
# [ 0.17193987 -0.00067223 -0.00640887]
# ['# of iterations for delta convergence: ', 6]
# fval: 649.3877930765194
# [ 0.22100099 -0.00061781 -0.00149315]
# ['# of iterations for delta convergence: ', 7]
# fval: 649.3723413998398
# [ 0.22798861 -0.00045204 -0.00213048]
# ['# of iterations for delta convergence: ', 3]
# fval: 649.3727728027503
# [ 2.35775160e-01 -2.32740652e-04 -3.99690915e-04]
# ['# of iterations for delta convergence: ', 4]
# fval: 649.375923622119
# [ 0.21256921 -0.00062505 -0.00290259]
# ['# of iterations for delta convergence: ', 5]
# fval: 649.370787647429
# [ 0.20234084 -0.00065187 -0.00252085]
# ['# of iterations for delta convergence: ', 4]
# fval: 649.3718438125828
# Object vcov dimensions: (23, 23)
# Object se dimensions: (23,)
# Object theta2w dimensions:     (3,)
# Object t dimensions:     ()
# running time: 99.238037109375
#        Theta1_2  Std.Error_theta1_2  Theta2_2  Std.Error_theta2_2  \
# 0     29.724534            7.678997  0.202341            4.222767
# 1    -16.232345            2.085352 -0.000652            0.333252
# 2     -1.128596            0.129032 -0.002521           10.506884
# 3      0.364482            0.417513       NaN                 NaN
# 4    400.946410           57.757067       NaN                 NaN
# 5    -71.028750           20.590041       NaN                 NaN
# 6     -2.875333            1.181353       NaN                 NaN
# 7    -47.261282            7.817940       NaN                 NaN
# 8     -0.145954            0.029130       NaN                 NaN
# 9     68.672065            4.918218       NaN                 NaN
# 10     0.385927            0.091603       NaN                 NaN
# 11    88.751404           10.938622       NaN                 NaN
# 12   120.803347           13.875979       NaN                 NaN
# 13 -1088.383513          241.934596       NaN                 NaN
# 14  -361.799678           84.501980       NaN                 NaN
# 15   185.630290           18.064192       NaN                 NaN
# 16    73.074419           42.366369       NaN                 NaN
# 17   -82.432244           21.458634       NaN                 NaN
# 18   -42.219041           20.824246       NaN                 NaN
# 19   -35.785480           17.994990       NaN                 NaN
#
#     Objective Value_2
# 0          649.371844
# 1          649.371844
# 2          649.371844
# 3          649.371844
# 4          649.371844
# 5          649.371844
# 6          649.371844
# 7          649.371844
# 8          649.371844
# 9          649.371844
# 10         649.371844
# 11         649.371844
# 12         649.371844
# 13         649.371844
# 14         649.371844
# 15         649.371844
# 16         649.371844
# 17         649.371844
# 18         649.371844
# 19         649.371844

# %%
#POINT 2.3: We now try to change the set of isntruments by dropping some of them (IV1). 

#Loading and cleaning the data

loc = '/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/'

#filo loc = '/Users/filippomajocchi/Desktop/Empirical IO/PSs/EIO_PS/EIO_repository/Computational/Python_codes/'
#veri loc = '/Users/veronicaermini/Documents/ESS/2_1_Empirical IO and Market Design/PS/EIO_repository/Computational/Python_codes/'   
#cami
#leo
#madda loc ='/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/'

class data():        
        
#Data location
    loc1= loc + "data.csv"
    loc2= loc + "demogr.csv"
    loc3= loc + "demogr_means.csv"
    loc4= loc + "demogr_year_region_id.csv"
    loc5= loc + "demogr_iqr.csv"
    loc6= loc + "demogr_std.csv"

#Load data
    data = pd.read_csv(loc1, sep=',', names= list(range(1,189)), encoding='cp1252')
    demogr =  pd.read_csv(loc2, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_means = pd.read_csv(loc3, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_year_region_id = pd.read_csv(loc4, sep=',', names= list(range(1,3)), encoding='cp1252')
    demogr_iqr= pd.read_csv(loc5, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_std= pd.read_csv(loc6, sep=',', names= list(range(1,1001)), encoding='cp1252')

#Column names
    names =  ['id_colid_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_region_end','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','price_col','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','top_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','id_col','id_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','op_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','iv_start_col','iv_end_col','bid_col','gamma_col','true_weight_col','nat_weight_col','groupA_col','group_region_col','group_bid_test_col','ms_lischoosers_col','tot_lis_col','tot_lis_choosers_col','market_sizes_col','ms_lis_col','indicator_bench_col','contract_id_col','benefit_type_col','plan_name_col','lis_col'] 
    x1_names = ['id_colid_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_region_end','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','top_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','id_col','id_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','op_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col'] 
    x2_names = ['price_col']
    D_names = list(range(1,1001))
    IV_names = ['iv_start_col','iv_end_col','bid_col','gamma_col','true_weight_col','nat_weight_col','groupA_col','group_region_col','group_bid_test_col','ms_lischoosers_col','tot_lis_col','tot_lis_choosers_col','market_sizes_col','ms_lis_col','indicator_bench_col','contract_id_col','benefit_type_col','plan_name_col','lis_col']


    id_col=1 #id market plan
    id_market_col=2 #id market
    ms_col=3 #market shares
    dummy_firm_start=4 #first column of firm id's dummies
    dummy_firm_end=79 #last column of firm id's dummies
    dummy_year_start=80 #first column of year's dummies
    dummy_year_end=85 #last column of year's dummies
    dummy_region_start=86 #first column of region's dummies
    dummy_region_end=119 #last column of region's dummies
    dummy_firmname_start=120 #first column of firm name 
    dummy_firmname_end=140 #last column of firm name
    dummy_macroregion_start=141 #first column of firm name 
    dummy_macroregion_end=143 #last column of firm name
    price_col=144
    deductible_col=price_col+1
    n_medications_col=price_col+2 #col 146 - try adding this to x1
    drug_frf_col=price_col+3
    d_cov_gap_col=price_col+4
    d_enhance_col=price_col+5
    top_drug_col=price_col+6
    in_area_flag_col=price_col+7
    vintage_col=price_col+8
    tier_12_col=price_col+9
    d_below_lagged_col=price_col+10
    ms_lis_firm_col=price_col+11
    ms_lis_firm_lagged_col=price_col+12

#LIST OF IV'S
    iv_start_col=price_col+13
    iv_end_col=iv_start_col+12
    bid_col=iv_start_col+15
    gamma_col=iv_start_col+16
    true_weight_col=iv_start_col+17
    nat_weight_col=iv_start_col+18
    groupA_col=iv_start_col+19
    group_region_col=iv_start_col+20
    group_bid_test_col=iv_start_col+21
    ms_lischoosers_col=iv_start_col+22
    tot_lis_col=iv_start_col+23
    tot_lis_choosers_col=iv_start_col+24
    market_sizes_col=iv_start_col+25
    ms_lis_col=iv_start_col+26
    indicator_bench_col=iv_start_col+27 #=1 if below benchmark plan
    contract_id_col=iv_start_col+28
    benefit_type_col=iv_start_col+29
    plan_name_col=iv_start_col+30
    lis_col=iv_start_col+31
    
#Cleaning

#Drop missing iv, dates, no-pharmacy plans

#Missing IV
    data.loc[:,iv_start_col+3] = data.loc[:,iv_start_col+3].fillna(value=0)
    data.loc[:,iv_start_col+4]=data.loc[:,iv_start_col+4].fillna(value=0)
    data.loc[:,iv_start_col+5]=data.loc[:,iv_start_col+5].fillna(value=0)
    data.loc[:,iv_start_col+6]=data.loc[:,iv_start_col+6].fillna(value=0)
    data.loc[:,iv_start_col+11]=data.loc[:,iv_start_col+11].fillna(value=0)
    
#Drop dates
    index = (data.loc[:,1] < 11000000) & (data.loc[:,1]>7000000)
    data = data.loc[index,:]
    
#Drop plans with no pharmacy? check column 151 is this one
    index = (data.loc[:,in_area_flag_col]!= 0) & (data.loc[:,in_area_flag_col]<10000)
    data = data.loc[index,:]

#Re-scaling
    scale=100
    ns=500
    data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
    data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
    data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
    data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
    data.loc[:,in_area_flag_col]=data.loc[:,in_area_flag_col].div(1000)

    demogr.loc[:,1:500]=demogr.loc[:,1:500].div(1000)
    demogr_means.loc[:,1:ns] = demogr_means.loc[:,1:ns].div(1000)

#IV - matrix    
    
    IV= data[list(range(iv_start_col,iv_end_col+1)) + [deductible_col, d_cov_gap_col, d_enhance_col, tier_12_col, top_drug_col, in_area_flag_col ,vintage_col]+list(range(dummy_macroregion_start,dummy_macroregion_end))+list(range(dummy_year_start+1,dummy_year_end-2))+[dummy_firmname_start, dummy_firmname_start+10, dummy_firmname_start+13, dummy_firmname_start+16, dummy_firmname_end]]
    #these columns give non singuality: 6-10
    IV = IV.iloc[:,0:6].join(IV.iloc[:,11:29])
    

#Cleaning missing IV
    index = (np.sum(IV.T.isna()) == 0)
    data = data.loc[index,:]   
    IV = IV.loc[index,:] 
    
 #Reindexing IV 
    IV.index = pd.RangeIndex(len(IV.index))
    IV.columns= pd.RangeIndex(len(IV.columns))
        
         
#x1, x2
    constant=pd.Series(np.ones(np.shape(data[1])),index=data.index,name='constant') #add constant
    x11=data[[price_col, deductible_col, drug_frf_col, d_cov_gap_col, d_enhance_col, tier_12_col, top_drug_col, in_area_flag_col, vintage_col]+list(range(dummy_macroregion_start,dummy_macroregion_end))+list(range(dummy_year_start+1,dummy_year_end-2))+[dummy_firmname_start,dummy_firmname_start+10,dummy_firmname_start+13,dummy_firmname_start+15,dummy_firmname_start+16,dummy_firmname_end]]
 
    x1 = x11.join(constant)
    col=x1.columns.tolist()
    col= col[-1:] + col[:-1]
    x1=x1[col]
    
    
    x2 = data.loc[:,price_col].values.reshape(len(x1),1)

#Cleaning x1:eliminate dummies that are always 0 (companies that never offer a plan in 2006) 
    index= np.sum(x1)
    x1 = x1.loc[:,index!=0]

#Reindexing
    x1.index = pd.RangeIndex(len(x1.index))#reindex x1
    x1.columns= pd.RangeIndex(len(x1.columns))

#Indices
    id = data.loc[:,id_col] #id of each observation
    id_demo = data.loc[:,id_market_col].unique() #  number of markets 


#The  vector  below relates each observation to the market it is in / both for data and demographics
    
    cdid=list()
    cdindex=[-1]
    cdid_demogr=list()    

    for i in range(len(id_demo)):
        nbrand_market = np.sum(data.loc[:,id_market_col] == id_demo[i])
        cdid.extend(i*np.ones(nbrand_market)) 
        cdindex.append(cdindex[-1]+nbrand_market) 
        #create the cdid for the demographics
        index_market = data.loc[data[id_market_col]==id_demo[i]].index
        i_index_region= data.loc[index_market[0],dummy_region_start:dummy_region_end]==(1/scale) 
        index_region = np.where(i_index_region)[0] +1 # +1 since id_region [1,34]
        i_index_year= data.loc[index_market[0],dummy_year_start:dummy_year_end] == (1/scale)
        index_year = np.where(i_index_year)[0] + 2005 
        index_demogr = demogr_year_region_id.loc[demogr_year_region_id[1] == index_year[0]].index.intersection(demogr_year_region_id.loc[demogr_year_region_id[2] == index_region[0]].index)

        if np.isnan(index_demogr.values)== 1:
            print(['Demographics not found for region ' + np.array2string(index_region) + ' and year ' + np.array2string(index_year)])
        else:
            cdid_demogr.extend(index_demogr.values*np.ones(nbrand_market,int))## [0,135]
        
    cdindex=cdindex[1:137]
    cdindex=np.asarray(cdindex,dtype=int)

#Create instruments based on demographics
    mean_income= demogr_means.loc[cdid_demogr,1]
    mean_diffall= demogr_means.loc[cdid_demogr,ns+1] 
    std_income = demogr_std.loc[cdid_demogr,1]
    iqr_income=demogr_iqr.loc[cdid_demogr,1] 
    iqr_diffall=demogr_iqr.loc[cdid_demogr,ns+1]#
     
    #Try to run without IV
    #IV1 = pd.DataFrame(np.concatenate([np.array([IV.loc[:,13]])*np.array([mean_income]), np.array([IV.loc[:,13]])*np.array([mean_diffall]), np.array([IV.loc[:,13]])*np.array([iqr_income]), np.array([IV.loc[:,13]])*np.array([iqr_diffall])],axis=0).T, index=IV.index, columns=[24,25,26,27])
    #IV=IV.merge(IV1, right_index=True, left_index=True) #Try to run without these IV


#Other variables
    K1 = x1.shape[1] #number of product characteristics
    K2 = x2.shape[1] #
    s_jt=data.loc[:,ms_col]
    s_jt= np.reshape(s_jt.values, (np.shape(s_jt)[0],1))#observed market share for product j at time t
    nmkt = len(id_demo)
    r= '/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/v.csv'
    v=pd.read_csv(r,sep=',',names= list(range(1000)))

    #v = pd.DataFrame(np.random.randn(nmkt,demogr.shape[1]))


   
    def summary(self):
        print('the number of characteristics in X1 is: '+str(data.x1.shape[1]))
        print('the number of characteristics in X2 is: '+str(data.x2.shape[1]))
        print('Object cdid dimensions: ' +str(np.shape(data.cdid)) )
        print('The dimensions of object cdindex are      ' + str(np.shape(data.cdindex)))
        print('The number of instruments for the price is ' +  str(np.shape(data.IV)[1]))
        print('The dimensions of object IV are ' + str(np.shape(data.IV)))
        print('size id_demo: '+ str(np.shape(data.id_demo)) )
        print("size of cdid is " + str(np.shape((data.cdid))))
        print("size of cdindex is "+ str(np.shape((data.cdindex))))
        print("size of cdid_demogr is "+ str(np.shape((data.cdid_demogr))))



data.summary(data)

# =============================================================================
#
# BLP Algorithm
#
# =============================================================================

#from scipy.optimize import fmin
from scipy.optimize import minimize
import matplotlib.pyplot as plt    
import time
#import optimize2 as opt # import modified optimize.minimize_nelder-mead ; alternatively change line 569 from 'and' to 'or' on original optimize.py

    
class BLP:
    
    def __init__ (self,data,theta2w,mtol,niter): #define data instances
         
        self.niter = niter 
        self.mtol=mtol
        self.theta2w=theta2w 
        self.x1 = data.x1
        self.x2 = data.x2 
        self.s_jt = data.s_jt
        self.v = data.v
        self.cdindex = data.cdindex #consider asarray
        self.cdid = data.cdid
        self.cdid_demogr=data.cdid_demogr
        self.vfull = data.v.loc[self.cdid_demogr,:] 
        dfull = data.demogr.loc[self.cdid_demogr,:]
        dfull.columns= pd.RangeIndex(len(dfull.columns))
        dfull.index = pd.RangeIndex(len(dfull.index))
        self.dfull = dfull
        self.demogr= data.demogr
        self.IV = data.IV
        self.K1 = self.x1.shape[1]
        self.K2 = self.x2.shape[1]
        self.ns = data.ns          # number of simulated "indviduals" per market 
        self.D = int(self.dfull.shape[1]/self.ns)       # number of demographic variables
        self.T = np.asarray(self.cdindex).shape[0]      # number of markets = (# of cities)*(# of quarters)  
        self.TJ = self.x1.shape[0]      #number of observations
        self.J = int(self.TJ/self.T) #average number of observation per market
        
      
        
        self.invA = np.linalg.inv(self.IV.T@self.IV)
        
        
        #mid2 = np.mat(self.x1.T)*np.mat(self.IV)*self.invA*np.mat(self.IV.T)*np.mat(self.x1)
        #invmid2=np.linalg.inv(mid2)
        
        #Calculating s0 -outside good shares
        temp= self.s_jt.cumsum()
        sum1 = temp[self.cdindex] 
        sum1[1:np.shape(sum1)[0]] = np.diff(sum1) 
        outshr = (1 - sum1[np.asarray(self.cdid,dtype=int)]) 
        outshr= np.abs(outshr)
        outshr=np.reshape(outshr,(np.shape(outshr)[0],1))       

        #Find initial guess of coefficients by running simple logit regression
        y=np.log(self.s_jt)-np.log(outshr)
        mid = self.x1.T@self.IV@self.invA@self.IV.T
        t = np.linalg.inv(mid@self.x1)@mid@y 
        
        #Mean utility - initial
        self.mvalold = self.x1@(t) 
        self.mvalold = np.exp(self.mvalold).values.reshape(np.shape(self.mvalold)[0],1)
        self.oldt2 = np.zeros(np.shape(self.theta2w)) #initial old2
        self.gmmvalold = 0
        self.gmmdiff = 1
        self.gmmresid = np.ones((6024,1)) #@@@@@@ initialization
   
    #Transforms inputed guess of theta2w into an ndarray type
    def init_theta(self,theta2w):
        theta2w=theta2w.reshape(1,1+self.D) # #rows: # x2 variables
        self.theti, self.thetj = list(np.where(theta2w != 0))#columns: #demographic variables + 1 (constant)
        self.theta2 = theta2w[np.where(theta2w != 0)]
        return self.theta2
     
        
    #Mean utility function
    def mufunc(self,theta2w): 
        mu = np.zeros((self.TJ, self.ns))
        for i in range(self.ns):
            v_i = np.array(self.vfull.loc[:, np.arange(i, self.K2*self.ns, self.ns)])
            d_i = np.array(self.dfull.loc[:, np.arange(i, self.D*self.ns, self.ns)]) 
            temp = d_i @ theta2w[:, 1:(self.D+1)].T
            mu[:, i]=(np.multiply(self.x2, v_i) @ theta2w[:, 0]) + np.multiply(self.x2, temp) @ np.ones((self.K2))

        return mu
        
    def ind_sh(self,expmu): 
        eg = np.multiply(expmu, np.kron(np.ones((1, self.ns)), self.mvalold)) 
        temp = np.cumsum(eg, 0)
        sum1 = temp[self.cdindex, :]
        sum2 = sum1
        sum2[1:sum2.shape[0], :] = np.diff(sum1.T).T
        denom1 = 1. / (1. + sum2)
        denom = denom1[np.asarray(self.cdid,dtype=int), :]
        
        return np.multiply(eg, denom)

    def mktsh(self,expmu):
        # compute the market share for each product
        temp = self.ind_sh(expmu).T
        f = (sum(temp) / float(self.ns)).T
        f = f.reshape(self.x1.shape[0],1)
        return f
        
        
    def meanval(self,theta2):
        #phased tolerance to speed up computation
#        if self.gmmdiff < 1e-15:
#            self.mtol = 1e-15
#        elif self.gmmdiff < 1e-3:
#            self.mtol = 1e-4
#        else:
#            self.mtol = 1e-2
        
        if np.ndarray.max(np.absolute(theta2-self.oldt2)) < 0.01: 
            tol = self.mtol
            flag=0
        else:
            tol = self.mtol #when theta2 (output of minimize) is still larger than 0.01, flag=1 => pass it to theta old2, that will be used in next iteration
            flag = 1
        norm = 1
        avgnorm = 1
        i = 0
        theta2w = np.zeros((self.K2,self.D+1)) 
        for ind in range(len(self.theti)): 
            theta2w[self.theti[ind], self.thetj[ind]] = theta2[ind] 
        expmu=np.exp(self.mufunc(theta2w))
       
        while (norm > self.mtol) & (i<self.niter): 
           
            pred_s_jt = self.mktsh(expmu) 
            self.mval = np.multiply(self.mvalold,self.s_jt) / pred_s_jt 
            t = np.abs(self.mval - self.mvalold)
            norm = np.max(t)
            avgnorm = np.mean(t)
            self.mvalold = self.mval
            i += 1
           
            if (norm > self.mtol) & (i > self.niter-1):
                print('Max number of ' + str(niter) + 'iterations reached')
    
        print(['# of iterations for delta convergence: ' , i])
	
        if (flag == 1) & (sum(np.isnan(self.mval)))==0: 
            self.mvalold = self.mval
            self.oldt2 = theta2
        return np.log(self.mval)
 
 
    #Calculates the jacobian of the 
    def jacob(self,theta2): 
        cdindex=np.asarray(self.cdindex,dtype=int)
        theta2w = np.zeros((self.K2, self.D+1))
        for ind in range(len(self.theti)):
            theta2w[self.theti[ind], self.thetj[ind]] = self.theta2[ind] #build theta2w (from array to ndarray) to plug in ind_sh
        expmu=np.exp(self.mufunc(theta2w)) 
        shares = self.ind_sh(expmu)
        f1 = np.zeros((np.asarray(self.cdid).shape[0] ,self.K2 * (self.D + 1)))
        # calculate derivative of shares with respect to the first column of theta2w (variable that are not interacted with demogr var, sigmas)
        for i in range(self.K2):
            xv = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)),self.v.loc[self.cdid, self.ns*i:self.ns * (i+1)-1])
            temp = np.cumsum(np.multiply(xv, shares), 0).values
            sum1 = temp[cdindex, :]
            sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
            f1[:,i] = np.mean((np.multiply(shares, xv - sum1[np.asarray(self.cdid,dtype=int),:])),1) #mean over columns
           
        for j in range(self.D):
            d = self.demogr.loc[self.cdid,self.ns*(j)+1:self.ns*(j+1)] 
            temp1 = np.zeros((np.asarray(self.cdid).shape[0],self.K2))
            for i in range(self.K2):
                xd = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)), d)
                temp = np.cumsum(np.multiply(xd, shares), 0).values
                sum1 = temp[cdindex, :]
                sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
                temp1[:, i] = np.mean((np.multiply(shares, xd-sum1[np.asarray(self.cdid,dtype=int), :])), 1)
            f1[:,self.K2 * (j + 1):self.K2 * (j + 2)] = temp1 

        self.rel = self.theti + self.thetj * (max(self.theti)+1) 
        f = np.zeros((np.shape(self.cdid)[0],self.rel.shape[0]))
        n = 0
        
        for i in range(np.shape(self.cdindex)[0]):
            temp = shares[n:(self.cdindex[i] + 1), :]
            H1 = temp @ temp.T
            H = (np.diag(np.array(sum(temp.T)).flatten())-H1) / self.ns
            f[n:(cdindex[i]+1),:] = np.linalg.inv(H) @ f1[n:(cdindex[i] + 1),self.rel]
            n = cdindex[i] + 1
        return f
       
    #Compute GMM objective function       
    def gmmobj(self,theta2):
        print(theta2)
        delta = self.meanval(theta2)
        self.theta2=theta2
        #the following deals with cases where the min algorithm drifts into region where the objective is not defined
        if max(np.isnan(delta)) == 1: 
            f = np.ndarray((1,1),buffer=np.array([1e+10,1e+10])) 
        else:
            temp1 = self.x1.T @ self.IV
            temp2 = delta.T@self.IV
            self.theta1 = np.linalg.inv(temp1@self.invA@temp1.T)@temp1@self.invA@temp2.T
            self.gmmresid = delta - self.x1@self.theta1
            temp1 = self.gmmresid.T@(self.IV) 
            f = temp1@self.invA@temp1.T
            f=f.values
            if np.shape(f) > (1,1):
                temp = self.jacob(theta2).T 
                df = 2*temp@self.IV@self.invA@self.IV.T@self.gmmresid 
        print('fval:', f[0,0]) #value of the gmm objective function
        
        #to be used in meanval to phase tolerance based on gmm value
        self.gmmvalnew = f[0,0]
        self.gmmdiff = np.abs(self.gmmvalold - self.gmmvalnew)
        self.gmmvalold = self.gmmvalnew
        
        return (f[0,0])
       
               

    #Calculates the gradient of the objective function based on jacobian
    def gradobj(self,theta2):
        temp = self.jacob(theta2).T 
        df = 2*temp@self.IV@self.invA@self.IV.T@self.gmmresid 
        df=df.values ##@@
        print('this is the gradient '+str(df))
    
        return df
    
  
    #WARNING!!!!!!!! In some versions of scipy there can be a problem with xatol in optimize.minimize_neldermead. IF so, change optimize.py codeline 569: replace 'and' to 'or'OR use modified script optimize2.py 
    
     
    #Maximizes the objective function
    def iterate_optimization(self,opt_func, param_vec,jac,options ): 
        res = minimize(opt_func, param_vec,method='nelder-mead',options=options) 
        ##res = opt._minimize_neldermead(opt_func, param_vec,disp=True,maxiter=100,fatol=0.0001,xatol=0.0001)
        #res = minimize(opt_func, param_vec, method='BFGS', bounds=None, callback=None, options=options)
    
        return res
            
    
    #Calculates the variance-covariance matrix of the estimates
    
    def varcov(self,theta2): 
        Z = self.IV.shape[1]
        temp = self.jacob(theta2)                                              
        a = np.concatenate((self.x1.values, temp), 1).T @ self.IV.values
        IVres = np.multiply(self.IV.values,self.gmmresid.values @ np.ones((1, Z)))
        b = IVres.T@(IVres)
        if np.linalg.det(a @ np.asarray(self.invA) @ a.T)!= 0:
            inv_aAa = np.linalg.inv(a @ np.asarray(self.invA) @ a.T)
        else:
            print('Error: singular matrix in covariate function ; forced result') #if jacobian has row of zeros
            inv_aAa = np.linalg.lstsq(a @ np.asarray(self.invA) @ a.T)
        f = inv_aAa @ a @ np.asarray(self.invA) @ b @ np.asarray(self.invA) @ a.T @ inv_aAa   
        return f    


    #Computes estimates of the coefficients and its standard errors; outputs a histogram and a csv file with estimates
    def results(self,theta2):
        self.theta1=self.theta1.values
        var = self.varcov(self.theta2)
        se = np.sqrt(var.diagonal())
        t = se.shape[0] - self.theta2.shape[0]
        
        print('Object vcov dimensions: ' + str(np.shape(var)) )
        print('Object se dimensions: ' + str(np.shape(se)))
        
        print('Object theta2w dimensions:     ' + str(np.shape(self.theta2)))
        print('Object t dimensions:     ' + str(np.shape(t)))
        

#Histogram of the coefficients
        alfa_i=[]
        alfa_i2=[]
        for i in range(0,self.T): 
            data_market=np.reshape(self.demogr.loc[i,0:self.ns*self.D].values,(self.ns,self.D))
            v_market=np.reshape(self.v.loc[i,0:self.ns-1].values,(self.ns,1)) # caution: v is created to have 1000 columns
            alfa_i2.extend(np.add(data_market@(self.theta2[1:3]).T, self.theta2[0]*v_market[:,0])) 
            alfa_i.extend(data_market@(self.theta2[1:3].T))
        #alfa_i=(self.theta1[1]+alfa_i2)/100 
        alfa_i=(self.theta1[1]+alfa_i2)/100
        h=plt.figure()
        plt.hist(alfa_i,bins=25,range=(np.min(alfa_i),np.max(alfa_i)))
        plt.grid(axis='y', alpha=0.75)
        plt.xlabel('Value')
        plt.ylabel('Frequency')
        plt.title('Distribution of the price coefficient -2007')
        h.savefig('elasticities.png')
        #compute the elasticities
        #reshape the alfas
        alfa_i_reshaped=np.reshape(alfa_i,(self.ns,len(self.cdindex))).T #changed from cdindex (136) to cdid (6024) to match matlab size
        alfa_i_reshaped=alfa_i_reshaped[np.asarray(self.cdid,dtype=int),:]
        
        #Convert theta2 into ndarray to plug in ind_sh
        theta = np.zeros((self.K2, self.D+1))
        for ind in range(len(self.theti)):
            theta[self.theti[ind], self.thetj[ind]] = self.theta2[ind] 
       #######
        expmu=np.exp(self.mufunc(theta))
        f = self.ind_sh(expmu)
        mval=(self.x1@self.theta1)
     
        #From ind_sh function: here mvalold = gmmresid +mval
        eg = np.multiply(np.exp(self.mufunc(theta)), np.kron(np.ones((1, self.ns)), (mval+self.gmmresid))) 
        temp = np.cumsum(eg, 0)
        sum1 = temp[self.cdindex, :]
        sum2 = sum1
        sum2[1:sum2.shape[0], :] = np.diff(sum1.T).T
        denom1 = 1. / (1. + sum2)
        denom = denom1[np.asarray(self.cdid,dtype=int), :]
        f22= np.multiply(eg, denom)
        ######
        f2 = np.sum(f22.T,0)/self.ns
        f2 = f2.T
        error=self.s_jt-f2     

        #Table with parameters + export to csv file
        
        self.theta1_results= pd.DataFrame({'Theta1':self.theta1.reshape(self.K1,),'Std.Error_theta1': se[0:-self.theta2.shape[0]]},columns=(['Theta1','Std.Error_theta1'])) 
        self.theta2_results= pd.DataFrame({'Theta2':self.theta2.reshape(self.theta2.shape[0],), 'Std.Error_theta2':se[-self.theta2.shape[0]:]},columns=(['Theta2','Std.Error_theta2']))
        self.theta1_results.to_csv(loc + "theta1.csv")
        self.theta2_results.to_csv(loc + "theta2.csv")
        
        return self.theta1_results, self.theta2_results, self.gmmvalnew
 
# =============================================================================
# Define parameters to input in the algorithm    
# =============================================================================


starttime = time.time()

#Maximum number of iterations for convergence of mval-mvalold contraction
niter = 2500

#Initial guess for coefficients
theta2w = np.array([0.50,-0.5,0.5])
#theta2w = np.array([0.20,-0.01,0.01,-0.5,0.05,0.05])

#Maximum tolerance 
mtol= 1e-5 

#Set optimization options
options={'disp': None,'maxiter': 100,'xatol':0.0001,'fatol':0.0001}

#Get output
blp = BLP(data,theta2w,mtol,niter)
init_theta = blp.init_theta(theta2w) 
res = blp.iterate_optimization(opt_func=blp.gmmobj,param_vec=init_theta,jac=blp.gradobj,options=options) 
theta1_results, theta2_results, gmmvalnew = blp.results(res.x)

endtime=time.time()
run = endtime-starttime
print('running time: ' + str(endtime-starttime))
a=time.time()

#Create a table with the results
results_table = pd.DataFrame({
    'Theta1_3': theta1_results['Theta1'],
    'Std.Error_theta1_3': theta1_results['Std.Error_theta1'],
    'Theta2_3': theta2_results['Theta2'],
    'Std.Error_theta2_3': theta2_results['Std.Error_theta2'],
    'Objective Value_3': [gmmvalnew] * len(theta1_results)
})

# Save results_table to a file
results_table.to_csv('results_table3.csv', index=False)


print(results_table)
# Out:
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   2.65 0.   ... 0.   3.1  0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[54.85 54.85 54.85 ... 31.42 38.84 38.84]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 9.59  9.59  9.59 ...  9.85 10.57 10.57]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.   0.   ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.   0.01 ... 0.   0.   0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.93 0.93 0.93 ... 0.99 0.99 0.99]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.05 0.04 0.04]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.72 0.72 0.72 ... 0.86 0.89 0.89]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:111: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.   0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:112: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/1858762955.py:113: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.506 0.506 0.506 ... 0.108 0.12  0.12 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,in_area_flag_col]=data.loc[:,in_area_flag_col].div(1000)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# the number of characteristics in X1 is: 19
# the number of characteristics in X2 is: 1
# Object cdid dimensions: (6024,)
# The dimensions of object cdindex are      (136,)
# The number of instruments for the price is 24
# The dimensions of object IV are (6024, 24)
# size id_demo: (136,)
# size of cdid is (6024,)
# size of cdindex is (136,)
# size of cdid_demogr is (6024,)
# [ 0.5 -0.5  0.5]
# ['# of iterations for delta convergence: ', 76]
# fval: 1786.1288763227951
# [ 0.525 -0.5    0.5  ]
# ['# of iterations for delta convergence: ', 4]
# fval: 1786.7768070178738
# [ 0.5   -0.525  0.5  ]
# ['# of iterations for delta convergence: ', 45]
# fval: 1896.0725204763964
# [ 0.5   -0.5    0.525]
# ['# of iterations for delta convergence: ', 45]
# fval: 1792.7414887151183
# [ 0.51666667 -0.475       0.51666667]
# ['# of iterations for delta convergence: ', 43]
# fval: 1686.4599543500733
# [ 0.525 -0.45   0.525]
# ['# of iterations for delta convergence: ', 43]
# fval: 1589.805897334556
# [ 0.53333333 -0.46666667  0.49166667]
# ['# of iterations for delta convergence: ', 41]
# fval: 1646.8114291087716
# [ 0.51388889 -0.44444444  0.51111111]
# ['# of iterations for delta convergence: ', 42]
# fval: 1564.447295073568
# [ 0.50833333 -0.41666667  0.51666667]
# ['# of iterations for delta convergence: ', 43]
# fval: 1463.459544463115
# [ 0.54444444 -0.38888889  0.52222222]
# ['# of iterations for delta convergence: ', 42]
# fval: 1370.5915514005844
# [ 0.56666667 -0.33333333  0.53333333]
# ['# of iterations for delta convergence: ', 45]
# fval: 1204.689290018955
# [ 0.53333333 -0.33333333  0.55833333]
# ['# of iterations for delta convergence: ', 24]
# fval: 1211.4947511431901
# [ 0.54722222 -0.27222222  0.54722222]
# ['# of iterations for delta convergence: ', 42]
# fval: 1055.435534202745
# [ 0.55833333 -0.18333333  0.55833333]
# ['# of iterations for delta convergence: ', 39]
# fval: 899.326152051456
# [ 0.59722222 -0.15        0.58333333]
# ['# of iterations for delta convergence: ', 32]
# fval: 867.7282323782284
# [ 0.64166667 -0.01666667  0.61666667]
# ['# of iterations for delta convergence: ', 28]
# fval: 790.8073477383313
# [ 0.64444444 -0.02222222  0.58055556]
# ['# of iterations for delta convergence: ', 16]
# fval: 778.8595238677369
# [0.7        0.13333333 0.59166667]
# ['# of iterations for delta convergence: ', 81]
# fval: 5394.9673234118245
# [0.66296296 0.18518519 0.63703704]
# ['# of iterations for delta convergence: ', 55]
# fval: 20551.52382038115
# [ 0.59074074 -0.2037037   0.55925926]
# ['# of iterations for delta convergence: ', 49]
# fval: 930.4384153169026
# [0.63888889 0.05555556 0.61111111]
# ['# of iterations for delta convergence: ', 34]
# fval: 845.4165478689034
# [0.725      0.19444444 0.64722222]
# ['# of iterations for delta convergence: ', 67]
# fval: 27124.376980518908
# [ 0.6        -0.08888889  0.58055556]
# ['# of iterations for delta convergence: ', 39]
# fval: 813.4140059808615
# [ 0.61851852 -0.14074074  0.57407407]
# ['# of iterations for delta convergence: ', 33]
# fval: 854.5129265514206
# [0.6337963  0.00648148 0.60185185]
# ['# of iterations for delta convergence: ', 27]
# fval: 774.6436591017903
# [0.67993827 0.06728395 0.61882716]
# ['# of iterations for delta convergence: ', 50]
# fval: 979.8684498368091
# [ 0.61998457 -0.04984568  0.59012346]
# ['# of iterations for delta convergence: ', 32]
# fval: 795.009294726336
# [0.6599537  0.02824074 0.60925926]
# ['# of iterations for delta convergence: ', 23]
# fval: 782.5654620477945
# [0.65046296 0.025      0.57777778]
# ['# of iterations for delta convergence: ', 16]
# fval: 767.9503090815683
# [0.65486111 0.04583333 0.55833333]
# ['# of iterations for delta convergence: ', 25]
# fval: 795.5568439723229
# [ 0.62584877 -0.0220679   0.56419753]
# ['# of iterations for delta convergence: ', 18]
# fval: 772.3646456273791
# [0.62896091 0.02849794 0.58199588]
# ['# of iterations for delta convergence: ', 17]
# fval: 772.084940033078
# [0.63638546 0.01447188 0.54746228]
# ['# of iterations for delta convergence: ', 16]
# fval: 754.1551540372109
# [0.63768004 0.01846708 0.52026749]
# ['# of iterations for delta convergence: ', 14]
# fval: 745.294545652447
# [0.65222051 0.07004458 0.5558299 ]
# ['# of iterations for delta convergence: ', 52]
# fval: 948.0645474494745
# [0.6324417  0.00096022 0.56210562]
# ['# of iterations for delta convergence: ', 29]
# fval: 761.3527721364793
# [0.6514289  0.00112026 0.52477138]
# ['# of iterations for delta convergence: ', 15]
# fval: 748.3962413600275
# [ 0.6305708  -0.01130163  0.49365188]
# ['# of iterations for delta convergence: ', 14]
# fval: 743.3454456528015
# [ 0.62062471 -0.02945245  0.45158893]
# ['# of iterations for delta convergence: ', 17]
# fval: 737.7055237382491
# [ 0.64071407 -0.00753696  0.43564624]
# ['# of iterations for delta convergence: ', 17]
# fval: 724.869397287291
# [ 0.64485025 -0.01178555  0.37241655]
# ['# of iterations for delta convergence: ', 15]
# fval: 710.9709007842322
# [ 0.61734111 -0.01630087  0.37141061]
# ['# of iterations for delta convergence: ', 12]
# fval: 712.115180333254
# [ 0.61753067 -0.05682632  0.27667657]
# ['# of iterations for delta convergence: ', 19]
# fval: 709.0958714481351
# [ 0.60745599 -0.09447302  0.15488112]
# ['# of iterations for delta convergence: ', 22]
# fval: 713.9862672869538
# [ 0.63252331 -0.02715605  0.22874689]
# ['# of iterations for delta convergence: ', 18]
# fval: 691.6787059935494
# [ 0.6384726  -0.02600785  0.11732586]
# ['# of iterations for delta convergence: ', 13]
# fval: 682.5301819108973
# [ 0.64989458 -0.04677895  0.13953539]
# ['# of iterations for delta convergence: ', 15]
# fval: 689.5923979326019
# [ 0.62574832 -0.07462319 -0.01672467]
# ['# of iterations for delta convergence: ', 18]
# fval: 694.6135108405382
# [ 0.65854633 -0.041447   -0.11658552]
# ['# of iterations for delta convergence: ', 16]
# fval: 683.684346391189
# [ 0.67219402 -0.00153267  0.11024182]
# ['# of iterations for delta convergence: ', 14]
# fval: 677.9611290505774
# [0.69541687 0.03501259 0.17372507]
# ['# of iterations for delta convergence: ', 26]
# fval: 699.1621813259228
# [ 0.66291406  0.00078726 -0.06554727]
# ['# of iterations for delta convergence: ', 14]
# fval: 676.5025700206328
# [ 0.66942379  0.02457037 -0.1680886 ]
# ['# of iterations for delta convergence: ', 20]
# fval: 685.8680289483997
# [0.65717413 0.0236115  0.22459913]
# ['# of iterations for delta convergence: ', 13]
# fval: 683.2908807324917
# [0.65751718 0.00734687 0.13930297]
# ['# of iterations for delta convergence: ', 13]
# fval: 676.678587235226
# [0.68994423 0.03040882 0.00533915]
# ['# of iterations for delta convergence: ', 23]
# fval: 687.6017189288176
# [ 0.65134051 -0.01190368  0.08932919]
# ['# of iterations for delta convergence: ', 13]
# fval: 678.7455530645225
# [0.67707632 0.01630466 0.03333583]
# ['# of iterations for delta convergence: ', 13]
# fval: 670.6745637949922
# [0.68994423 0.03040882 0.00533915]
# ['# of iterations for delta convergence: ', 21]
# fval: 687.6085964811824
# [ 0.65947768  0.0178252  -0.03884748]
# ['# of iterations for delta convergence: ', 12]
# fval: 672.504015120338
# [ 0.67546153  0.01593121 -0.18667558]
# ['# of iterations for delta convergence: ', 13]
# fval: 679.4594704815877
# [0.66200326 0.00949296 0.05780833]
# ['# of iterations for delta convergence: ', 11]
# fval: 672.3359374559451
# [0.66945746 0.02829461 0.10041173]
# ['# of iterations for delta convergence: ', 21]
# fval: 683.4179035250872
# [ 0.66454991  0.0076641  -0.02405752]
# ['# of iterations for delta convergence: ', 13]
# fval: 673.6966584412794
# [0.66782161 0.02141777 0.05892198]
# ['# of iterations for delta convergence: ', 16]
# fval: 673.8611707234693
# [ 0.66536783  0.01110252 -0.00331265]
# ['# of iterations for delta convergence: ', 11]
# fval: 671.3367514736123
# [0.6768206  0.00677489 0.09740182]
# ['# of iterations for delta convergence: ', 9]
# fval: 675.5614220879218
# [ 0.66381341  0.01506262 -0.00478515]
# ['# of iterations for delta convergence: ', 11]
# fval: 670.7119389863159
# [ 0.67550178  0.01882024 -0.04098298]
# ['# of iterations for delta convergence: ', 11]
# fval: 673.2470897170967
# [0.66537789 0.01182478 0.0331105 ]
# ['# of iterations for delta convergence: ', 10]
# fval: 670.8391945470823
# [0.67214392 0.01769218 0.0444201 ]
# ['# of iterations for delta convergence: ', 12]
# fval: 671.1609834431332
# [0.6704499  0.01604477 0.03248691]
# ['# of iterations for delta convergence: ', 8]
# fval: 670.5926290693654
# [0.6755152  0.01978325 0.00758122]
# ['# of iterations for delta convergence: ', 12]
# fval: 672.8396630572423
# [0.66791222 0.0138144  0.02672818]
# ['# of iterations for delta convergence: ', 10]
# fval: 670.388092369174
# [0.67981222 0.01571326 0.06648577]
# ['# of iterations for delta convergence: ', 9]
# fval: 670.6610722893739
# [0.66837323 0.01407696 0.05046475]
# ['# of iterations for delta convergence: ', 8]
# fval: 670.3915855687593
# [0.65801135 0.01357749 0.00663413]
# ['# of iterations for delta convergence: ', 7]
# fval: 670.5028247184974
# [0.6590813  0.01160113 0.02339779]
# ['# of iterations for delta convergence: ', 7]
# fval: 670.9067826743388
# [0.66760775 0.01493386 0.03021463]
# ['# of iterations for delta convergence: ', 9]
# fval: 670.3644990425564
# [0.67791745 0.01497265 0.06497091]
# ['# of iterations for delta convergence: ', 8]
# fval: 670.5564929466655
# [0.66298788 0.01392628 0.02121832]
# ['# of iterations for delta convergence: ', 8]
# fval: 670.3801093165958
# [0.66396533 0.01437273 0.00164268]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.5602120382091
# [0.66727126 0.0141509  0.03825923]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.3479044919623
# [0.66399904 0.01485963 0.03306661]
# ['# of iterations for delta convergence: ', 7]
# fval: 670.3343989865699
# [0.66204244 0.01538225 0.03623582]
# ['# of iterations for delta convergence: ', 7]
# fval: 670.3778799096239
# [0.66959749 0.01536998 0.04647532]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.4303247160575
# [0.66464028 0.01428721 0.02753257]
# ['# of iterations for delta convergence: ', 7]
# fval: 670.3507223841565
# [0.6629993  0.0139313  0.03569098]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.3367502912392
# [0.66487278 0.01434068 0.04381197]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.3261235435166
# [0.66498903 0.01436742 0.05195167]
# ['# of iterations for delta convergence: ', 5]
# fval: 670.366093899265
# [0.66064282 0.01460351 0.03678714]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.2981514057326
# [0.6573286  0.01482981 0.03605109]
# ['# of iterations for delta convergence: ', 5]
# fval: 670.2891080835388
# [0.66113431 0.01542212 0.03959547]
# ['# of iterations for delta convergence: ', 7]
# fval: 670.3742978006484
# [0.66253305 0.01430401 0.0366671 ]
# ['# of iterations for delta convergence: ', 7]
# fval: 670.3200009637918
# [0.65915725 0.01412337 0.04462017]
# ['# of iterations for delta convergence: ', 5]
# fval: 670.3170207003096
# [0.65447316 0.01449744 0.0344136 ]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.263403919111
# [0.64927334 0.01457582 0.02971442]
# ['# of iterations for delta convergence: ', 4]
# fval: 670.2480815130965
# [0.64797308 0.01471533 0.03692336]
# ['# of iterations for delta convergence: ', 5]
# fval: 670.2364826170653
# [0.64069309 0.01492099 0.03705148]
# ['# of iterations for delta convergence: ', 5]
# fval: 670.2053105700583
# [0.63903944 0.01542771 0.0239245 ]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.3029653440951
# [0.64406889 0.01510163 0.02909842]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.2778854231825
# [0.63202828 0.01490248 0.02785845]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.1957256098026
# [0.61937813 0.01493881 0.02376213]
# ['# of iterations for delta convergence: ', 5]
# fval: 670.1483185198712
# [0.62882748 0.01452212 0.03125361]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.1503489978047
# [0.60999246 0.01501213 0.03166373]
# ['# of iterations for delta convergence: ', 6]
# fval: 670.0613787005344
# [0.59035202 0.01523029 0.03263838]
# ['# of iterations for delta convergence: ', 6]
# fval: 669.9878637823329
# [0.58501199 0.01487316 0.0213846 ]
# ['# of iterations for delta convergence: ', 6]
# fval: 669.9932023372904
# [0.56766727 0.01550605 0.02060314]
# ['# of iterations for delta convergence: ', 7]
# fval: 669.9814846166223
# [0.53708717 0.01599801 0.0152779 ]
# ['# of iterations for delta convergence: ', 7]
# fval: 669.9916535160185
# [0.54264273 0.01546751 0.02598861]
# ['# of iterations for delta convergence: ', 7]
# fval: 669.833751873613
# [0.50427503 0.01573186 0.02710185]
# ['# of iterations for delta convergence: ', 7]
# fval: 669.6876110971601
# [0.52318422 0.01610564 0.03217765]
# ['# of iterations for delta convergence: ', 7]
# fval: 669.8310160170834
# [0.47306567 0.01633208 0.02061671]
# ['# of iterations for delta convergence: ', 7]
# fval: 669.7479127215021
# [0.43268267 0.01660701 0.032661  ]
# ['# of iterations for delta convergence: ', 7]
# fval: 669.5808292204651
# [0.36519037 0.0171575  0.03868993]
# ['# of iterations for delta convergence: ', 8]
# fval: 669.4918708895511
# [0.37183649 0.01670865 0.02542802]
# ['# of iterations for delta convergence: ', 7]
# fval: 669.4386295512173
# [0.29616262 0.01701016 0.0220532 ]
# ['# of iterations for delta convergence: ', 8]
# fval: 669.3062812347633
# [0.30401968 0.01693426 0.03794662]
# ['# of iterations for delta convergence: ', 5]
# fval: 669.2152762492574
# [0.21949669 0.01723535 0.04661158]
# ['# of iterations for delta convergence: ', 8]
# fval: 669.0483779489263
# [0.0829581  0.01853681 0.04446795]
# ['# of iterations for delta convergence: ', 9]
# fval: 669.3671874064908
# [0.0338879  0.01803072 0.03673189]
# ['# of iterations for delta convergence: ', 7]
# fval: 669.0676215889594
# [0.28340672 0.01631401 0.02579649]
# ['# of iterations for delta convergence: ', 10]
# fval: 669.011444246307
# [0.38363103 0.01520261 0.01646075]
# ['# of iterations for delta convergence: ', 8]
# fval: 669.206893405935
# [0.06169825 0.01737656 0.05070676]
# ['# of iterations for delta convergence: ', 10]
# fval: 668.7549636847207
# [-0.05553393  0.01755976  0.06503355]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.7520140661122
# [0.26435841 0.01604204 0.05489585]
# ['# of iterations for delta convergence: ', 10]
# fval: 668.8381888417223
# [0.10865744 0.01604185 0.05053902]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.4417652427268
# [0.05323781 0.0154451  0.05250274]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.2671193817762
# [-0.10869852  0.01638392  0.08915827]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.6672933735198
# [-0.33835484  0.01688383  0.08290051]
# ['# of iterations for delta convergence: ', 10]
# fval: 668.767120885481
# [-0.18767653  0.01667338  0.07589935]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.5105137842546
# [-0.10655756  0.01477517  0.08000669]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.387154255167
# [-0.05196566  0.01487851  0.04978091]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.1039052814375
# [-0.02359923  0.01412581  0.03009224]
# ['# of iterations for delta convergence: ', 7]
# fval: 668.1758425891212
# [0.11748625 0.01339248 0.04562754]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.4826027014399
# [0.04119556 0.0142127  0.0531955 ]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.2525782403427
# [0.13486936 0.01491571 0.02364607]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.4143664393717
# [-0.04620083  0.01481031  0.06591654]
# ['# of iterations for delta convergence: ', 10]
# fval: 668.2214931584278
# [-0.09121843  0.01382258  0.06009256]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.2476528608245
# [-0.16745218  0.01479489  0.06399785]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.1520565832224
# [-0.08586068  0.01583323  0.0597043 ]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.1940030851052
# [-0.15731818  0.01552745  0.04973884]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.0952897338852
# [-0.21287686  0.01588602  0.04164999]
# ['# of iterations for delta convergence: ', 7]
# fval: 668.1346335660746
# [-0.16529667  0.01430067  0.04930743]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.0951843006915
# [-0.20501467  0.0135344   0.04410899]
# ['# of iterations for delta convergence: ', 7]
# fval: 668.211200247768
# [-0.08226817  0.01500953  0.03522028]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.0781031671602
# [-0.03967616  0.01511685  0.02083149]
# ['# of iterations for delta convergence: ', 7]
# fval: 668.1967990442539
# [-0.21795635  0.01501326  0.03973012]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.0584775371542
# [-0.30095169  0.01508063  0.03470472]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.1198938490904
# [-0.15302928  0.01402153  0.03309971]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.1133148711697
# [-0.15624596  0.01515097  0.04557906]
# ['# of iterations for delta convergence: ', 7]
# fval: 668.0452225302284
# [-0.13901698  0.01581516  0.03104554]
# ['# of iterations for delta convergence: ', 7]
# fval: 668.1483398220431
# [-0.15872675  0.0146793   0.04474196]
# ['# of iterations for delta convergence: ', 7]
# fval: 668.0614090653909
# [-0.27301787  0.01488615  0.05148048]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.1068456723567
# [-0.12995559  0.01497869  0.03928533]
# ['# of iterations for delta convergence: ', 9]
# fval: 668.0537225806564
# [-0.17737852  0.01541598  0.03832104]
# ['# of iterations for delta convergence: ', 7]
# fval: 668.071704595709
# [-0.16338969  0.01486347  0.04313673]
# ['# of iterations for delta convergence: ', 6]
# fval: 668.0568200529794
# [-0.08177114  0.01498216  0.04560396]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.0756291433792
# [-0.18391005  0.01500548  0.04119858]
# ['# of iterations for delta convergence: ', 8]
# fval: 668.0493980046217
# [-0.15001804  0.01522662  0.04090525]
# ['# of iterations for delta convergence: ', 7]
# fval: 668.0573457320172
# [-0.16004678  0.01495426  0.04257886]
# ['# of iterations for delta convergence: ', 5]
# fval: 668.0577888645014
# [-0.170078    0.01507823  0.04338882]
# ['# of iterations for delta convergence: ', 4]
# fval: 668.0443159898864
# [-0.14310078  0.01506483  0.04243219]
# ['# of iterations for delta convergence: ', 6]
# fval: 668.0523847306656
# [-0.15981782  0.01500722  0.04435789]
# ['# of iterations for delta convergence: ', 5]
# fval: 668.0532443403008
# [-0.153132    0.0151888   0.04324215]
# ['# of iterations for delta convergence: ', 5]
# fval: 668.049689458379
# [-0.17653653  0.01521383  0.04570782]
# ['# of iterations for delta convergence: ', 6]
# fval: 668.0598576692787
# [-0.15145971  0.01510208  0.0432511 ]
# ['# of iterations for delta convergence: ', 6]
# fval: 668.0546557315519
# [-0.16316198  0.0151146   0.04448394]
# ['# of iterations for delta convergence: ', 4]
# fval: 668.0543486400736
# [-0.161605    0.01513351  0.04331548]
# ['# of iterations for delta convergence: ', 2]
# fval: 668.0446783501768
# [-0.15658939  0.01507153  0.0429105 ]
# ['# of iterations for delta convergence: ', 3]
# fval: 668.0577712840152
# [-0.17330727  0.01514603  0.04454832]
# ['# of iterations for delta convergence: ', 5]
# fval: 668.0534151599566
# [-0.1734982   0.01512391  0.04301781]
# ['# of iterations for delta convergence: ', 3]
# fval: 668.053755253945
# [-0.17091415  0.01512158  0.04338434]
# ['# of iterations for delta convergence: ', 2]
# fval: 668.054223163954
# [-0.1658415   0.01510587  0.04335215]
# ['# of iterations for delta convergence: ', 3]
# fval: 668.054045118285
# [-0.17169263  0.01511213  0.04396857]
# ['# of iterations for delta convergence: ', 3]
# fval: 668.0539898953086
# [-0.16661999  0.01509641  0.04393638]
# ['# of iterations for delta convergence: ', 2]
# fval: 668.0556573400081
# [-0.1717881   0.01510107  0.04320331]
# ['# of iterations for delta convergence: ', 2]
# fval: 668.050941515312
# [-0.17653099  0.01508841  0.04368832]
# ['# of iterations for delta convergence: ', 3]
# fval: 668.0550082222449
# [-0.16851387  0.0151015   0.04343619]
# ['# of iterations for delta convergence: ', 4]
# fval: 668.0507724138977
# Object vcov dimensions: (22, 22)
# Object se dimensions: (22,)
# Object theta2w dimensions:     (3,)
# Object t dimensions:     ()
# running time: 101.21951270103455
#       Theta1_3  Std.Error_theta1_3  Theta2_3  Std.Error_theta2_3  \
# 0    -1.302118            2.574980 -0.168514            9.625228
# 1   -12.871083            1.779383  0.015102            0.014071
# 2    -0.689525            0.052023  0.043436            1.693562
# 3     1.492009            0.270049       NaN                 NaN
# 4   259.915571           34.494266       NaN                 NaN
# 5     4.243252           10.486061       NaN                 NaN
# 6     1.423288            0.822147       NaN                 NaN
# 7   -18.540979            4.538570       NaN                 NaN
# 8    -0.146889            0.032732       NaN                 NaN
# 9    72.476326            5.346287       NaN                 NaN
# 10   91.460369           13.461047       NaN                 NaN
# 11  127.800860           17.879174       NaN                 NaN
# 12  -73.009673           47.286733       NaN                 NaN
# 13  -21.280911           11.854805       NaN                 NaN
# 14  187.141899           19.246631       NaN                 NaN
# 15  151.008119           26.007694       NaN                 NaN
# 16  -56.773866           15.962810       NaN                 NaN
# 17  -70.322906           17.865422       NaN                 NaN
# 18   26.087593           13.921786       NaN                 NaN
#
#     Objective Value_3
# 0          668.050772
# 1          668.050772
# 2          668.050772
# 3          668.050772
# 4          668.050772
# 5          668.050772
# 6          668.050772
# 7          668.050772
# 8          668.050772
# 9          668.050772
# 10         668.050772
# 11         668.050772
# 12         668.050772
# 13         668.050772
# 14         668.050772
# 15         668.050772
# 16         668.050772
# 17         668.050772
# 18         668.050772

# %%
#POINT 2.4: We now try to add one additional characteristic to X2, that is, "deductible_col". 

#Loading and cleaning the data

loc = '/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/'
#loc = '/Users/filippomajocchi/Desktop/Empirical IO/PSs/EIO_PS/EIO_repository/Computational/Python_codes/'
#veri loc = '/Users/veronicaermini/Documents/ESS/2_1_Empirical IO and Market Design/PS/EIO_repository/Computational/Python_codes/'   
#cami
#leo
#madda loc = '/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/'

class data():        
        
#Data location
    loc1= loc + "data.csv"
    loc2= loc + "demogr.csv"
    loc3= loc + "demogr_means.csv"
    loc4= loc + "demogr_year_region_id.csv"
    loc5= loc + "demogr_iqr.csv"
    loc6= loc + "demogr_std.csv"

#Load data
    data = pd.read_csv(loc1, sep=',', names= list(range(1,189)), encoding='cp1252')
    demogr =  pd.read_csv(loc2, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_means = pd.read_csv(loc3, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_year_region_id = pd.read_csv(loc4, sep=',', names= list(range(1,3)), encoding='cp1252')
    demogr_iqr= pd.read_csv(loc5, sep=',', names= list(range(1,1001)), encoding='cp1252')
    demogr_std= pd.read_csv(loc6, sep=',', names= list(range(1,1001)), encoding='cp1252')

#Column names
    names =  ['id_colid_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_region_end','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','price_col','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','top_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','id_col','id_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','op_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','iv_start_col','iv_end_col','bid_col','gamma_col','true_weight_col','nat_weight_col','groupA_col','group_region_col','group_bid_test_col','ms_lischoosers_col','tot_lis_col','tot_lis_choosers_col','market_sizes_col','ms_lis_col','indicator_bench_col','contract_id_col','benefit_type_col','plan_name_col','lis_col'] 
    x1_names = ['id_colid_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_region_end','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','top_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col','id_col','id_market_col','ms_col','dummy_firm_start','dummy_firm_end','dummy_year_start','dummy_year_end','dummy_region_start','dummy_firmname_start','dummy_firmname_end','dummy_macroregion_start','dummy_macroregion_end','deductible_col','n_medications_col','drug_frf_col','d_cov_gap_col','d_enhance_col','op_drug_col','in_area_flag_col','vintage_col','tier_12_col','d_below_lagged_col','ms_lis_firm_col','ms_lis_firm_lagged_col'] 
    x2_names = ['price_col']
    D_names = list(range(1,1001))
    IV_names = ['iv_start_col','iv_end_col','bid_col','gamma_col','true_weight_col','nat_weight_col','groupA_col','group_region_col','group_bid_test_col','ms_lischoosers_col','tot_lis_col','tot_lis_choosers_col','market_sizes_col','ms_lis_col','indicator_bench_col','contract_id_col','benefit_type_col','plan_name_col','lis_col']


    id_col=1 #id market plan
    id_market_col=2 #id market
    ms_col=3 #market shares
    dummy_firm_start=4 #first column of firm id's dummies
    dummy_firm_end=79 #last column of firm id's dummies
    dummy_year_start=80 #first column of year's dummies
    dummy_year_end=85 #last column of year's dummies
    dummy_region_start=86 #first column of region's dummies
    dummy_region_end=119 #last column of region's dummies
    dummy_firmname_start=120 #first column of firm name 
    dummy_firmname_end=140 #last column of firm name
    dummy_macroregion_start=141 #first column of firm name 
    dummy_macroregion_end=143 #last column of firm name
    price_col=144
    deductible_col=price_col+1
    n_medications_col=price_col+2 #col 146 - try adding this to x1
    drug_frf_col=price_col+3
    d_cov_gap_col=price_col+4
    d_enhance_col=price_col+5
    top_drug_col=price_col+6
    in_area_flag_col=price_col+7
    vintage_col=price_col+8
    tier_12_col=price_col+9
    d_below_lagged_col=price_col+10
    ms_lis_firm_col=price_col+11
    ms_lis_firm_lagged_col=price_col+12

#LIST OF IV'S
    iv_start_col=price_col+13
    iv_end_col=iv_start_col+12
    bid_col=iv_start_col+15
    gamma_col=iv_start_col+16
    true_weight_col=iv_start_col+17
    nat_weight_col=iv_start_col+18
    groupA_col=iv_start_col+19
    group_region_col=iv_start_col+20
    group_bid_test_col=iv_start_col+21
    ms_lischoosers_col=iv_start_col+22
    tot_lis_col=iv_start_col+233
    tot_lis_choosers_col=iv_start_col+24
    market_sizes_col=iv_start_col+25
    ms_lis_col=iv_start_col+26
    indicator_bench_col=iv_start_col+27 #=1 if below benchmark plan
    contract_id_col=iv_start_col+28
    benefit_type_col=iv_start_col+29
    plan_name_col=iv_start_col+30
    lis_col=iv_start_col+31
    
#Cleaning

#Drop missing iv, dates, no-pharmacy plans

#Missing IV
    data.loc[:,iv_start_col+3] = data.loc[:,iv_start_col+3].fillna(value=0)
    data.loc[:,iv_start_col+4]=data.loc[:,iv_start_col+4].fillna(value=0)
    data.loc[:,iv_start_col+5]=data.loc[:,iv_start_col+5].fillna(value=0)
    data.loc[:,iv_start_col+6]=data.loc[:,iv_start_col+6].fillna(value=0)
    data.loc[:,iv_start_col+11]=data.loc[:,iv_start_col+11].fillna(value=0)
#Drop dates
    index = (data.loc[:,1] < 11000000) & (data.loc[:,1]>7000000)
    data = data.loc[index,:]
#Drop plans with no pharmacy? check column 151 is this one
    index = (data.loc[:,in_area_flag_col]!= 0) & (data.loc[:,in_area_flag_col]<10000)
    data = data.loc[index,:]

#Re-scaling
    scale=100
    ns=500
    data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
    data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
    data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
    data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
    data.loc[:,in_area_flag_col]=data.loc[:,in_area_flag_col].div(1000)

    demogr.loc[:,1:500]=demogr.loc[:,1:500].div(1000)
    demogr_means.loc[:,1:ns] = demogr_means.loc[:,1:ns].div(1000)

#IV - matrix    
    
    IV= data[list(range(iv_start_col,iv_end_col+1)) + [deductible_col, d_cov_gap_col, d_enhance_col, tier_12_col, top_drug_col, in_area_flag_col ,vintage_col]+list(range(dummy_macroregion_start,dummy_macroregion_end))+list(range(dummy_year_start+1,dummy_year_end-2))+[dummy_firmname_start, dummy_firmname_start+10, dummy_firmname_start+13, dummy_firmname_start+16, dummy_firmname_end]]
    #these columns give non singuality: 6-10
    IV = IV.iloc[:,0:6].join(IV.iloc[:,11:29])
    

#Cleaning missing IV
    index = (np.sum(IV.T.isna()) == 0)
    data = data.loc[index,:]   
    IV = IV.loc[index,:] 
    
 #Reindexing IV 
    IV.index = pd.RangeIndex(len(IV.index))
    IV.columns= pd.RangeIndex(len(IV.columns))
        
         
#x1, x2
    constant=pd.Series(np.ones(np.shape(data[1])),index=data.index,name='constant') #add constant
    x11=data[[price_col, deductible_col, drug_frf_col, d_cov_gap_col, d_enhance_col, tier_12_col, top_drug_col, in_area_flag_col, vintage_col]+list(range(dummy_macroregion_start,dummy_macroregion_end))+list(range(dummy_year_start+1,dummy_year_end-2))+[dummy_firmname_start,dummy_firmname_start+10,dummy_firmname_start+13,dummy_firmname_start+15,dummy_firmname_start+16,dummy_firmname_end]]
    
    x1 = x11.join(constant)
    col=x1.columns.tolist()
    col= col[-1:] + col[:-1]
    x1=x1[col]
    
    

    x2 = data.loc[:,[price_col, deductible_col]].values.reshape(len(x1),2) #try to add another variable to x2

#Cleaning x1:eliminate dummies that are always 0 (companies that never offer a plan in 2006) 
    index= np.sum(x1)
    x1 = x1.loc[:,index!=0]

#Reindexing
    x1.index = pd.RangeIndex(len(x1.index))#reindex x1
    x1.columns= pd.RangeIndex(len(x1.columns))

#Indices
    id = data.loc[:,id_col] #id of each observation
    id_demo = data.loc[:,id_market_col].unique() #  number of markets 


#The  vector  below relates each observation to the market it is in / both for data and demographics
    
    cdid=list()
    cdindex=[-1]
    cdid_demogr=list()    

    for i in range(len(id_demo)):
        nbrand_market = np.sum(data.loc[:,id_market_col] == id_demo[i])
        cdid.extend(i*np.ones(nbrand_market)) 
        cdindex.append(cdindex[-1]+nbrand_market) 
        #create the cdid for the demographics
        index_market = data.loc[data[id_market_col]==id_demo[i]].index
        i_index_region= data.loc[index_market[0],dummy_region_start:dummy_region_end]==(1/scale) 
        index_region = np.where(i_index_region)[0] +1 # +1 since id_region [1,34]
        i_index_year= data.loc[index_market[0],dummy_year_start:dummy_year_end] == (1/scale)
        index_year = np.where(i_index_year)[0] + 2005 
        index_demogr = demogr_year_region_id.loc[demogr_year_region_id[1] == index_year[0]].index.intersection(demogr_year_region_id.loc[demogr_year_region_id[2] == index_region[0]].index)

        if np.isnan(index_demogr.values)== 1:
            print(['Demographics not found for region ' + np.array2string(index_region) + ' and year ' + np.array2string(index_year)])
        else:
            cdid_demogr.extend(index_demogr.values*np.ones(nbrand_market,int))## [0,135]
        
    cdindex=cdindex[1:137]
    cdindex=np.asarray(cdindex,dtype=int)

#Create instruments based on demographics
    mean_income= demogr_means.loc[cdid_demogr,1]
    mean_diffall= demogr_means.loc[cdid_demogr,ns+1] 
    std_income = demogr_std.loc[cdid_demogr,1]
    iqr_income=demogr_iqr.loc[cdid_demogr,1] 
    iqr_diffall=demogr_iqr.loc[cdid_demogr,ns+1]#

    IV1 = pd.DataFrame(np.concatenate([np.array([IV.loc[:,13]])*np.array([mean_income]), np.array([IV.loc[:,13]])*np.array([mean_diffall]), np.array([IV.loc[:,13]])*np.array([iqr_income]), np.array([IV.loc[:,13]])*np.array([iqr_diffall])],axis=0).T, index=IV.index, columns=[24,25,26,27])
    IV=IV.merge(IV1, right_index=True, left_index=True)


#Other variables
    K1 = x1.shape[1] #number of product characteristics
    K2 = x2.shape[1] #
    s_jt=data.loc[:,ms_col]
    s_jt= np.reshape(s_jt.values, (np.shape(s_jt)[0],1))#observed market share for product j at time t
    nmkt = len(id_demo)
    r='/Users/maddalenagrassi/Desktop/EIO/PSs/EIO_repository/Computational/Python_codes/v.csv'
    v=pd.read_csv(r,sep=',',names= list(range(1000)))

    #v = pd.DataFrame(np.random.randn(nmkt,demogr.shape[1]))


   
    def summary(self):
        print('the number of characteristics in X1 is: '+str(data.x1.shape[1]))
        print('the number of characteristics in X2 is: '+str(data.x2.shape[1]))
        print('Object cdid dimensions: ' +str(np.shape(data.cdid)) )
        print('The dimensions of object cdindex are      ' + str(np.shape(data.cdindex)))
        print('The number of instruments for the price is ' +  str(np.shape(data.IV)[1]))
        print('The dimensions of object IV are ' + str(np.shape(data.IV)))
        print('size id_demo: '+ str(np.shape(data.id_demo)) )
        print("size of cdid is " + str(np.shape((data.cdid))))
        print("size of cdindex is "+ str(np.shape((data.cdindex))))
        print("size of cdid_demogr is "+ str(np.shape((data.cdid_demogr))))



data.summary(data)

# =============================================================================
#
# BLP Algorithm
#
# =============================================================================

#from scipy.optimize import fmin
from scipy.optimize import minimize
import matplotlib.pyplot as plt    
import time
#import optimize2 as opt # import modified optimize.minimize_nelder-mead ; alternatively change line 569 from 'and' to 'or' on original optimize.py

    
class BLP:
    
    def __init__ (self,data,theta2w,mtol,niter): #define data instances
         
        self.niter = niter 
        self.mtol=mtol
        self.theta2w=theta2w 
        self.x1 = data.x1
        self.x2 = data.x2 
        self.s_jt = data.s_jt
        self.v = data.v
        self.cdindex = data.cdindex #consider asarray
        self.cdid = data.cdid
        self.cdid_demogr=data.cdid_demogr
        self.vfull = data.v.loc[self.cdid_demogr,:] 
        dfull = data.demogr.loc[self.cdid_demogr,:]
        dfull.columns= pd.RangeIndex(len(dfull.columns))
        dfull.index = pd.RangeIndex(len(dfull.index))
        self.dfull = dfull
        self.demogr= data.demogr
        self.IV = data.IV
        self.K1 = self.x1.shape[1]
        self.K2 = self.x2.shape[1]
        self.ns = data.ns          # number of simulated "indviduals" per market 
        self.D = int(self.dfull.shape[1]/self.ns)       # number of demographic variables
        self.T = np.asarray(self.cdindex).shape[0]      # number of markets = (# of cities)*(# of quarters)  
        self.TJ = self.x1.shape[0]      #number of observations
        self.J = int(self.TJ/self.T) #average number of observation per market
        
      
        
        self.invA = np.linalg.inv(self.IV.T@self.IV)
        
        
        #mid2 = np.mat(self.x1.T)*np.mat(self.IV)*self.invA*np.mat(self.IV.T)*np.mat(self.x1)
        #invmid2=np.linalg.inv(mid2)
        
        #Calculating s0 -outside good shares
        temp= self.s_jt.cumsum()
        sum1 = temp[self.cdindex] 
        sum1[1:np.shape(sum1)[0]] = np.diff(sum1) 
        outshr = (1 - sum1[np.asarray(self.cdid,dtype=int)]) 
        outshr= np.abs(outshr)
        outshr=np.reshape(outshr,(np.shape(outshr)[0],1))       

        #Find initial guess of coefficients by running simple logit regression
        y=np.log(self.s_jt)-np.log(outshr)
        mid = self.x1.T@self.IV@self.invA@self.IV.T
        t = np.linalg.inv(mid@self.x1)@mid@y 
        
        #Mean utility - initial
        self.mvalold = self.x1@(t) 
        self.mvalold = np.exp(self.mvalold).values.reshape(np.shape(self.mvalold)[0],1)
        self.oldt2 = np.zeros(np.shape(self.theta2w)) #initial old2
        self.gmmvalold = 0
        self.gmmdiff = 1
        self.gmmresid = np.ones((6024,1)) #@@@@@@ initialization
   
    #Transforms inputed guess of theta2w into an ndarray type
    def init_theta(self,theta2w):
        theta2w=theta2w.reshape(self.K2,1+self.D) # #rows: # x2 variables
        self.theti, self.thetj = list(np.where(theta2w != 0))#columns: #demographic variables + 1 (constant)
        self.theta2 = theta2w[np.where(theta2w != 0)]
        return self.theta2
     
        
    #Mean utility function
    def mufunc(self,theta2w): 
        mu = np.zeros((self.TJ, self.ns))
        for i in range(self.ns):
            v_i = np.array(self.vfull.loc[:, np.arange(i, self.K2*self.ns, self.ns)])
            d_i = np.array(self.dfull.loc[:, np.arange(i, self.D*self.ns, self.ns)]) 
            temp = d_i @ theta2w[:, 1:(self.D+1)].T
            mu[:, i]=(np.multiply(self.x2, v_i) @ theta2w[:, 0]) + np.multiply(self.x2, temp) @ np.ones((self.K2))

        return mu
        
    def ind_sh(self,expmu): 
        eg = np.multiply(expmu, np.kron(np.ones((1, self.ns)), self.mvalold)) 
        temp = np.cumsum(eg, 0)
        sum1 = temp[self.cdindex, :]
        sum2 = sum1
        sum2[1:sum2.shape[0], :] = np.diff(sum1.T).T
        denom1 = 1. / (1. + sum2)
        denom = denom1[np.asarray(self.cdid,dtype=int), :]
        
        return np.multiply(eg, denom)

    def mktsh(self,expmu):
        #compute the market share for each product
        temp = self.ind_sh(expmu).T
        f = (sum(temp) / float(self.ns)).T
        f = f.reshape(self.x1.shape[0],1)
        return f
        
        
    def meanval(self,theta2):
        #phased tolerance to speed up computation
#        if self.gmmdiff < 1e-15:
#            self.mtol = 1e-15
#        elif self.gmmdiff < 1e-3:
#            self.mtol = 1e-4
#        else:
#            self.mtol = 1e-2
        
        if np.ndarray.max(np.absolute(theta2-self.oldt2)) < 0.01: 
            tol = self.mtol
            flag=0
        else:
            tol = self.mtol #when theta2 (output of minimize) is still larger than 0.01, flag=1 => pass it to theta old2, that will be used in next iteration
            flag = 1
        norm = 1
        avgnorm = 1
        i = 0
        theta2w = np.zeros((self.K2,self.D+1)) 
        for ind in range(len(self.theti)): 
            theta2w[self.theti[ind], self.thetj[ind]] = theta2[ind] 
        expmu=np.exp(self.mufunc(theta2w))
       
        while (norm > self.mtol) & (i<self.niter): 
           
            pred_s_jt = self.mktsh(expmu) 
            self.mval = np.multiply(self.mvalold,self.s_jt) / pred_s_jt 
            t = np.abs(self.mval - self.mvalold)
            norm = np.max(t)
            avgnorm = np.mean(t)
            self.mvalold = self.mval
            i += 1
           
            if (norm > self.mtol) & (i > self.niter-1):
                print('Max number of ' + str(niter) + 'iterations reached')
    
        print(['# of iterations for delta convergence: ' , i])
	
        if (flag == 1) & (sum(np.isnan(self.mval)))==0: 
            self.mvalold = self.mval
            self.oldt2 = theta2
        return np.log(self.mval)
 
 
    #Calculates the jacobian 
    def jacob(self,theta2): 
        cdindex=np.asarray(self.cdindex,dtype=int)
        theta2w = np.zeros((self.K2, self.D+1))
        for ind in range(len(self.theti)):
            theta2w[self.theti[ind], self.thetj[ind]] = self.theta2[ind] #build theta2w (from array to ndarray) to plug in ind_sh
        expmu=np.exp(self.mufunc(theta2w)) 
        shares = self.ind_sh(expmu)
        f1 = np.zeros((np.asarray(self.cdid).shape[0] ,self.K2 * (self.D + 1)))
        #calculate derivative of shares with respect to the first column of theta2w (variable that are not interacted with demogr var, sigmas)
        for i in range(self.K2):
            xv = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)),self.v.loc[self.cdid, self.ns*i:self.ns * (i+1)-1])
            temp = np.cumsum(np.multiply(xv, shares), 0).values
            sum1 = temp[cdindex, :]
            sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
            f1[:,i] = np.mean((np.multiply(shares, xv - sum1[np.asarray(self.cdid,dtype=int),:])),1) #mean over columns
           
        for j in range(self.D):
            d = self.demogr.loc[self.cdid,self.ns*(j)+1:self.ns*(j+1)] 
            temp1 = np.zeros((np.asarray(self.cdid).shape[0],self.K2))
            for i in range(self.K2):
                xd = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)), d)
                temp = np.cumsum(np.multiply(xd, shares), 0).values
                sum1 = temp[cdindex, :]
                sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
                temp1[:, i] = np.mean((np.multiply(shares, xd-sum1[np.asarray(self.cdid,dtype=int), :])), 1)
            f1[:,self.K2 * (j + 1):self.K2 * (j + 2)] = temp1 

        self.rel = self.theti + self.thetj * (max(self.theti)+1) 
        f = np.zeros((np.shape(self.cdid)[0],self.rel.shape[0]))
        n = 0
        
        for i in range(np.shape(self.cdindex)[0]):
            temp = shares[n:(self.cdindex[i] + 1), :]
            H1 = temp @ temp.T
            H = (np.diag(np.array(sum(temp.T)).flatten())-H1) / self.ns
            f[n:(cdindex[i]+1),:] = np.linalg.inv(H) @ f1[n:(cdindex[i] + 1),self.rel]
            n = cdindex[i] + 1
        return f
       
    #Compute GMM objective function       
    def gmmobj(self,theta2):
        print(theta2)
        delta = self.meanval(theta2)
        self.theta2=theta2
        #the following deals with cases where the min algorithm drifts into region where the objective is not defined
        if max(np.isnan(delta)) == 1: 
            f = np.ndarray((1,1),buffer=np.array([1e+10,1e+10])) 
        else:
            temp1 = self.x1.T @ self.IV
            temp2 = delta.T@self.IV
            self.theta1 = np.linalg.inv(temp1@self.invA@temp1.T)@temp1@self.invA@temp2.T
            self.gmmresid = delta - self.x1@self.theta1
            temp1 = self.gmmresid.T@(self.IV) 
            f = temp1@self.invA@temp1.T
            f=f.values
            if np.shape(f) > (1,1):
                temp = self.jacob(theta2).T 
                df = 2*temp@self.IV@self.invA@self.IV.T@self.gmmresid 
        print('fval:', f[0,0]) #value of the gmm objective function
        
        #to be used in meanval to phase tolerance based on gmm value
        self.gmmvalnew = f[0,0]
        self.gmmdiff = np.abs(self.gmmvalold - self.gmmvalnew)
        self.gmmvalold = self.gmmvalnew
        
        return (f[0,0])
       
               

    #Calculates the gradient of the objective function based on jacobian
    def gradobj(self,theta2):
        temp = self.jacob(theta2).T 
        df = 2*temp@self.IV@self.invA@self.IV.T@self.gmmresid 
        df=df.values ##@@
        print('this is the gradient '+str(df))
    
        return df
    
  
    #WARNING!!!!!!!! In some versions of scipy there can be a problem with xatol in optimize.minimize_neldermead. IF so, change optimize.py codeline 569: replace 'and' to 'or'OR use modified script optimize2.py 
    
     
    #Maximizes the objective function
    def iterate_optimization(self,opt_func, param_vec,jac,options ): 
        res = minimize(opt_func, param_vec,method='nelder-mead',options=options) 
        ##res = opt._minimize_neldermead(opt_func, param_vec,disp=True,maxiter=100,fatol=0.0001,xatol=0.0001)
        #res = minimize(opt_func, param_vec, method='BFGS', bounds=None, callback=None, options=options)
    
        return res
            
    
    #Calculates the variance-covariance matrix of the estimates
    
    def varcov(self,theta2): 
        Z = self.IV.shape[1]
        temp = self.jacob(theta2)                                              
        a = np.concatenate((self.x1.values, temp), 1).T @ self.IV.values
        IVres = np.multiply(self.IV.values,self.gmmresid.values @ np.ones((1, Z)))
        b = IVres.T@(IVres)
        if np.linalg.det(a @ np.asarray(self.invA) @ a.T)!= 0:
            inv_aAa = np.linalg.inv(a @ np.asarray(self.invA) @ a.T)
        else:
            print('Error: singular matrix in covariate function ; forced result') #if jacobian has row of zeros
            inv_aAa = np.linalg.lstsq(a @ np.asarray(self.invA) @ a.T)
        f = inv_aAa @ a @ np.asarray(self.invA) @ b @ np.asarray(self.invA) @ a.T @ inv_aAa   
        return f    


    #Computes estimates of the coefficients and its standard errors; outputs a histogram and a csv file with estimates
    def results(self,theta2):
        self.theta1=self.theta1.values
        var = self.varcov(self.theta2)
        se = np.sqrt(var.diagonal())
        t = se.shape[0] - self.theta2.shape[0]
        
        print('Object vcov dimensions: ' + str(np.shape(var)) )
        print('Object se dimensions: ' + str(np.shape(se)))
        
        print('Object theta2w dimensions:     ' + str(np.shape(self.theta2)))
        print('Object t dimensions:     ' + str(np.shape(t)))
        

#Histogram of the coefficients
        alfa_i=[]
        alfa_i2=[]
        for i in range(0,self.T): 
            data_market=np.reshape(self.demogr.loc[i,0:self.ns*self.D].values,(self.ns,self.D))
            v_market=np.reshape(self.v.loc[i,0:self.ns-1].values,(self.ns,1)) # caution: v is created to have 1000 columns
            alfa_i2.extend(np.add(data_market@(self.theta2[1:3]).T, self.theta2[0]*v_market[:,0])) 
            alfa_i.extend(data_market@(self.theta2[1:3].T))
        #alfa_i=(self.theta1[1]+alfa_i2)/100 
        alfa_i=(self.theta1[1]+alfa_i2)/100
        h=plt.figure()
        plt.hist(alfa_i,bins=25,range=(np.min(alfa_i),np.max(alfa_i)))
        plt.grid(axis='y', alpha=0.75)
        plt.xlabel('Value')
        plt.ylabel('Frequency')
        plt.title('Distribution of the price coefficient -2007')
        h.savefig('elasticities.png')
        #Compute the elasticities
        #Reshape the alfas
        alfa_i_reshaped=np.reshape(alfa_i,(self.ns,len(self.cdindex))).T #changed from cdindex (136) to cdid (6024) to match matlab size
        alfa_i_reshaped=alfa_i_reshaped[np.asarray(self.cdid,dtype=int),:]
        
        #Convert theta2 into ndarray to plug in ind_sh
        theta = np.zeros((self.K2, self.D+1))
        for ind in range(len(self.theti)):
            theta[self.theti[ind], self.thetj[ind]] = self.theta2[ind] 
       #######
        expmu=np.exp(self.mufunc(theta))
        f = self.ind_sh(expmu)
        mval=(self.x1@self.theta1)
     
        #From ind_sh function: here mvalold = gmmresid +mval
        eg = np.multiply(np.exp(self.mufunc(theta)), np.kron(np.ones((1, self.ns)), (mval+self.gmmresid))) 
        temp = np.cumsum(eg, 0)
        sum1 = temp[self.cdindex, :]
        sum2 = sum1
        sum2[1:sum2.shape[0], :] = np.diff(sum1.T).T
        denom1 = 1. / (1. + sum2)
        denom = denom1[np.asarray(self.cdid,dtype=int), :]
        f22= np.multiply(eg, denom)
        ######
        f2 = np.sum(f22.T,0)/self.ns
        f2 = f2.T
        error=self.s_jt-f2     

        #Table with parameters + export to csv file
        
        self.theta1_results= pd.DataFrame({'Theta1':self.theta1.reshape(self.K1,),'Std.Error_theta1': se[0:-self.theta2.shape[0]]},columns=(['Theta1','Std.Error_theta1'])) 
        self.theta2_results= pd.DataFrame({'Theta2':self.theta2.reshape(self.theta2.shape[0],), 'Std.Error_theta2':se[-self.theta2.shape[0]:]},columns=(['Theta2','Std.Error_theta2']))
        self.theta1_results.to_csv(loc + "theta1.csv")
        self.theta2_results.to_csv(loc + "theta2.csv")
        
        return self.theta1_results, self.theta2_results, self.gmmvalnew
 
# =============================================================================
# Define parameters to input in the algorithm    
# =============================================================================


starttime = time.time()

#Maximum number of iterations for convergence of mval-mvalold contraction
niter = 2500

#Initial guess for coefficients
theta2w = np.array([0.20,-0.01,0.01,-0.5,0.05,0.05])

#Maximum tolerance 
mtol= 1e-5 

#Set optimization options
options={'disp': None,'maxiter': 100,'xatol':0.0001,'fatol':0.0001}

#Get output
blp = BLP(data,theta2w,mtol,niter)
init_theta = blp.init_theta(theta2w) 
res = blp.iterate_optimization(opt_func=blp.gmmobj,param_vec=init_theta,jac=blp.gradobj,options=options) 
theta1_results, theta2_results, gmmvalnew = blp.results(res.x)

endtime=time.time()
run = endtime-starttime
print('running time: ' + str(endtime-starttime))
a=time.time()

#Create a table with the results
results_table = pd.DataFrame({
    'Theta1_4': theta1_results['Theta1'],
    'Std.Error_theta1_4': theta1_results['Std.Error_theta1'],
    'Theta2_4': theta2_results['Theta2'],
    'Std.Error_theta2_4': theta2_results['Std.Error_theta2'],
    'Objective Value_4': [gmmvalnew] * len(theta1_results)
})

# Save results_table to a file
results_table.to_csv('results_table_4.csv', index=False)


print(results_table)
# Out:
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   2.65 0.   ... 0.   3.1  0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[54.85 54.85 54.85 ... 31.42 38.84 38.84]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 9.59  9.59  9.59 ...  9.85 10.57 10.57]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.   0.   ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.   0.01 ... 0.   0.   0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.93 0.93 0.93 ... 0.99 0.99 0.99]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.05 0.04 0.04]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.72 0.72 0.72 ... 0.86 0.89 0.89]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:106: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]]=data.loc[:,[price_col, deductible_col, n_medications_col, drug_frf_col, d_cov_gap_col, d_enhance_col, top_drug_col, vintage_col, tier_12_col,dummy_macroregion_start,142,dummy_macroregion_end]].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:107: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:107: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:107: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:107: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_year_start:dummy_year_end]=data.loc[:,dummy_year_start:dummy_year_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:108: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_region_start:dummy_region_end]=data.loc[:,dummy_region_start:dummy_region_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.01 0.01 0.01 ... 0.   0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.01 0.   0.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.   0.   0.   ... 0.   0.01 0.01]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:109: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0. 0. 0. ... 0. 0. 0.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,dummy_firmname_start:dummy_firmname_end]=data.loc[:,dummy_firmname_start:dummy_firmname_end].div(scale)
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/3784099313.py:110: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.506 0.506 0.506 ... 0.108 0.12  0.12 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[:,in_area_flag_col]=data.loc[:,in_area_flag_col].div(1000)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# the number of characteristics in X1 is: 19
# the number of characteristics in X2 is: 2
# Object cdid dimensions: (6024,)
# The dimensions of object cdindex are      (136,)
# The number of instruments for the price is 28
# The dimensions of object IV are (6024, 28)
# size id_demo: (136,)
# size of cdid is (6024,)
# size of cdindex is (136,)
# size of cdid_demogr is (6024,)
# [ 0.2  -0.01  0.01 -0.5   0.05  0.05]
# ['# of iterations for delta convergence: ', 46]
# fval: 12643.846537118854
# [ 0.21 -0.01  0.01 -0.5   0.05  0.05]
# ['# of iterations for delta convergence: ', 5]
# fval: 12609.784415984383
# [ 0.2    -0.0105  0.01   -0.5     0.05    0.05  ]
# ['# of iterations for delta convergence: ', 5]
# fval: 12543.791188357169
# [ 0.2    -0.01    0.0105 -0.5     0.05    0.05  ]
# ['# of iterations for delta convergence: ', 7]
# fval: 12544.063057625672
# [ 0.2   -0.01   0.01  -0.525  0.05   0.05 ]
# ['# of iterations for delta convergence: ', 14]
# fval: 12470.391107230711
# [ 0.2    -0.01    0.01   -0.5     0.0525  0.05  ]
# ['# of iterations for delta convergence: ', 21]
# fval: 13535.929946624348
# [ 0.2    -0.01    0.01   -0.5     0.05    0.0525]
# ['# of iterations for delta convergence: ', 26]
# fval: 12225.982172694576
# [ 0.20333333 -0.01016667  0.01016667 -0.50833333  0.0475      0.05083333]
# ['# of iterations for delta convergence: ', 31]
# fval: 10997.785653796387
# [ 0.205   -0.01025  0.01025 -0.5125   0.045    0.05125]
# ['# of iterations for delta convergence: ', 38]
# fval: 8925.03302222124
# [ 0.205      -0.01025     0.01025    -0.5125      0.04833333  0.05125   ]
# ['# of iterations for delta convergence: ', 23]
# fval: 10375.425235029303
# [ 0.19333333 -0.01033333  0.01033333 -0.51666667  0.04777778  0.05166667]
# ['# of iterations for delta convergence: ', 19]
# fval: 10161.216194685088
# [ 0.20111111 -0.01044444  0.00977778 -0.52222222  0.04703704  0.05222222]
# ['# of iterations for delta convergence: ', 16]
# fval: 9837.03538690549
# [ 0.20148148 -0.00992593  0.0102037  -0.52962963  0.04604938  0.05296296]
# ['# of iterations for delta convergence: ', 16]
# fval: 9459.322472421793
# [ 0.20197531 -0.01040123  0.0102716  -0.50617284  0.04473251  0.05395062]
# ['# of iterations for delta convergence: ', 25]
# fval: 8846.204028820139
# [ 0.20296296 -0.01060185  0.01040741 -0.49675926  0.04209877  0.05592593]
# ['# of iterations for delta convergence: ', 40]
# fval: 7195.726066422853
# [ 0.20296296 -0.01060185  0.01040741 -0.53009259  0.04209877  0.05259259]
# ['# of iterations for delta convergence: ', 9]
# fval: 7176.517514623108
# [ 0.20444444 -0.01090278  0.01061111 -0.54513889  0.03814815  0.05263889]
# ['# of iterations for delta convergence: ', 35]
# fval: 7549.0973243681165
# [ 0.19728395 -0.01046914  0.01020988 -0.52345679  0.04168724  0.05429012]
# ['# of iterations for delta convergence: ', 29]
# fval: 8112.5643530830275
# [ 0.21026749 -0.01043107  0.01008539 -0.5215535   0.04021262  0.05474794]
# ['# of iterations for delta convergence: ', 18]
# fval: 7649.88287753649
# [ 0.20554184 -0.0103155   0.01074348 -0.51577503  0.03867856  0.05503429]
# ['# of iterations for delta convergence: ', 19]
# fval: 7112.182190142343
# [ 0.2077572  -0.01025103  0.01122634 -0.51255144  0.03449931  0.05644033]
# ['# of iterations for delta convergence: ', 33]
# fval: 5831.627977010271
# [ 0.20726337 -0.01094239  0.01065844 -0.5026749   0.03581619  0.05545267]
# ['# of iterations for delta convergence: ', 17]
# fval: 6316.258784860708
# [ 0.20449931 -0.01084911  0.01074829 -0.51652949  0.0338043   0.05856653]
# ['# of iterations for delta convergence: ', 25]
# fval: 5956.677380618351
# [ 0.21462048 -0.01075663  0.01096788 -0.5032636   0.03448941  0.05695187]
# ['# of iterations for delta convergence: ', 13]
# fval: 6214.527031343474
# [ 0.20308794 -0.01090322  0.01138653 -0.49907026  0.03405629  0.0572287 ]
# ['# of iterations for delta convergence: ', 12]
# fval: 6060.379340746692
# [ 0.21043413 -0.01083289  0.01139088 -0.52463484  0.02948932  0.05648497]
# ['# of iterations for delta convergence: ', 42]
# fval: 4892.669516150394
# [ 0.21416971 -0.01094841  0.01188262 -0.53857263  0.0231846   0.0567645 ]
# ['# of iterations for delta convergence: ', 38]
# fval: 3784.544566641165
# [ 0.21416971 -0.01094841  0.01188262 -0.49412818  0.0231846   0.06120894]
# ['# of iterations for delta convergence: ', 13]
# fval: 3738.1571899970068
# [ 0.21977309 -0.01112168  0.01262023 -0.47614598  0.01372752  0.06551712]
# ['# of iterations for delta convergence: ', 28]
# fval: 1152.6416237116373
# [ 0.21403921 -0.01066764  0.01228552 -0.5127029   0.02210429  0.06170368]
# ['# of iterations for delta convergence: ', 38]
# fval: 3680.677805434809
# [ 0.20648834 -0.01082373  0.01241529 -0.51526063  0.0193027   0.06178841]
# ['# of iterations for delta convergence: ', 31]
# fval: 2828.8044557838384
# [ 0.21915435 -0.01065065  0.01233957 -0.52485076  0.01481795  0.06303149]
# ['# of iterations for delta convergence: ', 25]
# fval: 1881.6643147026502
# [ 0.22262799 -0.01063861  0.01350824 -0.51016529  0.00874116  0.06318198]
# ['# of iterations for delta convergence: ', 17]
# fval: 887.27695483273
# [ 0.23169232 -0.01053335  0.01488822 -0.50698318 -0.00379041  0.0654897 ]
# ['# of iterations for delta convergence: ', 14]
# fval: 817.8283589157804
# [ 0.22734847 -0.01133079  0.01425081 -0.51228725 -0.0047171   0.06832463]
# ['# of iterations for delta convergence: ', 13]
# fval: 825.6083710241278
# [ 0.22532888 -0.01076088  0.01438393 -0.47750428 -0.00270295  0.07185384]
# ['# of iterations for delta convergence: ', 13]
# fval: 818.016578073963
# [ 0.22922261 -0.01107272  0.01468049 -0.49164112 -0.00989172  0.07029805]
# ['# of iterations for delta convergence: ', 16]
# fval: 851.550284498232
# [ 0.24435157 -0.01099963  0.01530579 -0.48121023 -0.0168216   0.07304987]
# ['# of iterations for delta convergence: ', 18]
# fval: 908.6466285787988
# [ 0.24008463 -0.01128904  0.01637025 -0.45707325 -0.02288337  0.07514625]
# ['# of iterations for delta convergence: ', 18]
# fval: 981.1971291914424
# [ 0.2462364  -0.01087379  0.0173396  -0.49942046 -0.03399657  0.07587033]
# ['# of iterations for delta convergence: ', 22]
# fval: 1172.507246143403
# [ 0.22638892 -0.01105971  0.01380007 -0.4819646   0.0017965   0.06810542]
# ['# of iterations for delta convergence: ', 19]
# fval: 803.786613096123
# [ 0.22135962 -0.01062999  0.01273285 -0.5267903   0.01084094  0.06389425]
# ['# of iterations for delta convergence: ', 20]
# fval: 970.987916855295
# [ 0.22604088 -0.01079475  0.0136422  -0.50936104  0.00240986  0.06670725]
# ['# of iterations for delta convergence: ', 15]
# fval: 805.0150187712658
# [ 0.21098913 -0.01085111  0.01324279 -0.51203693  0.01118966  0.06387643]
# ['# of iterations for delta convergence: ', 21]
# fval: 987.6667437191898
# [ 0.23601096 -0.0109625   0.01479004 -0.4889169  -0.00981879  0.07075651]
# ['# of iterations for delta convergence: ', 16]
# fval: 851.1951245205222
# [ 0.22838087 -0.01074127  0.01390459 -0.50069796  0.00428409  0.06678107]
# ['# of iterations for delta convergence: ', 16]
# fval: 811.6175791539888
# [ 0.21904916 -0.01077775  0.0134999  -0.5073492   0.00891212  0.06499746]
# ['# of iterations for delta convergence: ', 15]
# fval: 892.6827166055837
# [ 0.23177051 -0.01091631  0.0144675  -0.49352498 -0.00513606  0.06931675]
# ['# of iterations for delta convergence: ', 14]
# fval: 826.2315995001945
# [ 0.22328961 -0.01082394  0.01382244 -0.50274113  0.00422939  0.06643722]
# ['# of iterations for delta convergence: ', 13]
# fval: 811.1001394789637
# [ 0.22635868 -0.01024051  0.01389634 -0.48079681  0.00679259  0.0668002 ]
# ['# of iterations for delta convergence: ', 13]
# fval: 841.3304696261071
# [ 0.22710103 -0.01105822  0.01416219 -0.50441464 -0.00183968  0.06794353]
# ['# of iterations for delta convergence: ', 14]
# fval: 813.5587959947294
# [ 0.22896899 -0.01090954  0.01368931 -0.52454991  0.0050662   0.06196755]
# ['# of iterations for delta convergence: ', 13]
# fval: 816.8034873991097
# [ 0.22169777 -0.01126246  0.01278539 -0.50092657  0.00910587  0.06715765]
# ['# of iterations for delta convergence: ', 15]
# fval: 897.8464657433203
# [ 0.22919369 -0.01071563  0.01436251 -0.50546903 -0.00056634  0.06590669]
# ['# of iterations for delta convergence: ', 15]
# fval: 807.5085310911096
# [ 0.224496   -0.01082164  0.01420869 -0.47699956 -0.00162826  0.07199284]
# ['# of iterations for delta convergence: ', 12]
# fval: 814.536071146319
# [ 2.25614248e-01 -1.08436115e-02  1.40788461e-02 -4.88887146e-01
#   4.53536761e-05  6.94865168e-02]
# ['# of iterations for delta convergence: ', 12]
# fval: 808.1007751840999
# [ 0.22586837 -0.01060142  0.01370803 -0.49195899  0.00590596  0.0665312 ]
# ['# of iterations for delta convergence: ', 14]
# fval: 827.4428106046245
# [ 2.26792863e-01 -1.09440206e-02  1.40486517e-02 -5.01300729e-01
#   9.67327265e-05  6.75904433e-02]
# ['# of iterations for delta convergence: ', 14]
# fval: 807.2067134815131
# [ 0.2240592  -0.01098595  0.01401364 -0.4958766  -0.00161359  0.06796345]
# ['# of iterations for delta convergence: ', 11]
# fval: 812.0365298416433
# [ 0.22730045 -0.01080244  0.01393186 -0.49949262  0.00280967  0.06707666]
# ['# of iterations for delta convergence: ', 11]
# fval: 805.0760725600195
# [ 0.23048741 -0.01089612  0.01413227 -0.49275059 -0.00203213  0.06852044]
# ['# of iterations for delta convergence: ', 12]
# fval: 813.6343118070656
# [ 0.22508906 -0.01084198  0.0138999  -0.50024349  0.00266401  0.06695803]
# ['# of iterations for delta convergence: ', 11]
# fval: 804.7890370648771
# [ 0.2279877  -0.0108759   0.01381622 -0.51039002  0.00302479  0.06462831]
# ['# of iterations for delta convergence: ', 8]
# fval: 804.4399841928789
# [ 0.22400627 -0.01105731  0.01335046 -0.49544847  0.00483353  0.06778202]
# ['# of iterations for delta convergence: ', 13]
# fval: 816.1132521365419
# [ 0.22789683 -0.01080105  0.0141095  -0.50296389  0.00078363  0.06637552]
# ['# of iterations for delta convergence: ', 14]
# fval: 804.7669279511865
# [ 0.22677508 -0.01078126  0.01368459 -0.50017116  0.00439942  0.06569329]
# ['# of iterations for delta convergence: ', 13]
# fval: 811.4679938822
# [ 0.22678842 -0.01090333  0.01395764 -0.50101834  0.0011724   0.06711615]
# ['# of iterations for delta convergence: ', 13]
# fval: 804.8365997342
# [ 0.22609682 -0.01095647  0.01380998 -0.50248784  0.00114073  0.06622024]
# ['# of iterations for delta convergence: ', 8]
# fval: 804.1618776992183
# [ 0.22737504 -0.01101806  0.01415556 -0.49032836  0.00111749  0.0664273 ]
# ['# of iterations for delta convergence: ', 10]
# fval: 803.4504664047479
# [ 2.28042121e-01 -1.11297150e-02  1.44122469e-02 -4.80812015e-01
#   4.71300762e-04  6.62873296e-02]
# ['# of iterations for delta convergence: ', 10]
# fval: 803.7031242553243
# [ 0.22682304 -0.01094773  0.0139061  -0.49510773  0.00233664  0.06578879]
# ['# of iterations for delta convergence: ', 11]
# fval: 802.9429185295352
# [ 0.22684035 -0.01096993  0.01388034 -0.49215243  0.00291876  0.0651251 ]
# ['# of iterations for delta convergence: ', 8]
# fval: 802.9656188302304
# [ 0.22910039 -0.01104432  0.01396591 -0.49417065  0.00073591  0.06555717]
# ['# of iterations for delta convergence: ', 11]
# fval: 803.4715653996464
# [ 0.2266938  -0.01116635  0.01370846 -0.48851918  0.00260039  0.06586689]
# ['# of iterations for delta convergence: ', 10]
# fval: 802.7411655905903
# [ 0.22609229 -0.011349    0.01350794 -0.48129682  0.00350877  0.06561257]
# ['# of iterations for delta convergence: ', 10]
# fval: 804.2990035029167
# [ 2.26171635e-01 -1.11883116e-02  1.39658152e-02 -4.73802761e-01
#   2.17761083e-04  6.80269535e-02]
# ['# of iterations for delta convergence: ', 12]
# fval: 805.3313131163359
# [ 0.22753369 -0.010954    0.01385362 -0.50124321  0.00232303  0.06547797]
# ['# of iterations for delta convergence: ', 11]
# fval: 803.2017295940274
# [ 0.22854148 -0.01110692  0.01398659 -0.48129007  0.00249593  0.06618761]
# ['# of iterations for delta convergence: ', 10]
# fval: 802.2980856809593
# [ 0.2297638  -0.01118215  0.0140749  -0.47069118  0.00317353  0.0661713 ]
# ['# of iterations for delta convergence: ', 8]
# fval: 802.7380426724748
# [ 0.22896689 -0.01101942  0.01405868 -0.50158847  0.0020733   0.06366316]
# ['# of iterations for delta convergence: ', 9]
# fval: 801.5521649119855
# [ 0.23025588 -0.01099927  0.01418798 -0.5114004   0.0022117   0.06144202]
# ['# of iterations for delta convergence: ', 8]
# fval: 800.6463477696411
# [ 0.22664058 -0.01101979  0.01396686 -0.49512566  0.00362582  0.0648397 ]
# ['# of iterations for delta convergence: ', 12]
# fval: 805.5142083069437
# [ 0.22848544 -0.01103819  0.01396615 -0.4944094   0.00145839  0.0653778 ]
# ['# of iterations for delta convergence: ', 12]
# fval: 802.5020820543604
# [ 0.22873607 -0.01105276  0.01371407 -0.50032831  0.00335787  0.06361972]
# ['# of iterations for delta convergence: ', 12]
# fval: 803.7629903821647
# [ 0.2277153  -0.01102674  0.01404519 -0.49282834  0.00167758  0.06572541]
# ['# of iterations for delta convergence: ', 12]
# fval: 802.5895246087708
# [ 0.22863796 -0.01114106  0.01407988 -0.4866085   0.00193718  0.06465153]
# ['# of iterations for delta convergence: ', 10]
# fval: 801.1105189168077
# [ 0.22995358 -0.01121178  0.01408531 -0.4899109   0.00179042  0.06396164]
# ['# of iterations for delta convergence: ', 7]
# fval: 800.8217480024613
# [ 0.2311694  -0.01100831  0.01440858 -0.49696336  0.00125668  0.06324845]
# ['# of iterations for delta convergence: ', 7]
# fval: 801.0168009369495
# [ 0.23129928 -0.01114178  0.01419297 -0.49403253  0.00203918  0.06256427]
# ['# of iterations for delta convergence: ', 8]
# fval: 799.9779325455024
# [ 0.23309128 -0.0111993   0.01426687 -0.49463463  0.00221998  0.06098371]
# ['# of iterations for delta convergence: ', 9]
# fval: 798.8149066043139
# [ 0.23206442 -0.01118402  0.01437225 -0.49252655  0.00251224  0.06144719]
# ['# of iterations for delta convergence: ', 9]
# fval: 799.3108854302872
# [ 0.2331827  -0.01114099  0.01448036 -0.50939138  0.00148014  0.05905723]
# ['# of iterations for delta convergence: ', 10]
# fval: 798.4482202191659
# [ 0.23550331 -0.01115803  0.01472725 -0.52344204  0.00097224  0.05549204]
# ['# of iterations for delta convergence: ', 10]
# fval: 797.2187306381245
# [ 0.23537466 -0.01111251  0.01460287 -0.51635079  0.00171724  0.05754015]
# ['# of iterations for delta convergence: ', 10]
# fval: 797.8183862051817
# [ 0.23424497 -0.01128     0.01433893 -0.51245841  0.00255126  0.05704047]
# ['# of iterations for delta convergence: ', 9]
# fval: 797.6744415581381
# [ 0.23689126 -0.01109926  0.01474674 -0.5270267   0.00227114  0.05402022]
# ['# of iterations for delta convergence: ', 9]
# fval: 796.4343492947436
# [ 0.2403601  -0.011043    0.01507745 -0.54558461  0.0025115   0.04904952]
# ['# of iterations for delta convergence: ', 8]
# fval: 795.1575917658477
# [ 0.23995703 -0.01132634  0.01494056 -0.51693194  0.00194978  0.052409  ]
# ['# of iterations for delta convergence: ', 11]
# fval: 794.1063795413062
# [ 0.24480761 -0.01148988  0.01531684 -0.51969771  0.00181882  0.04789249]
# ['# of iterations for delta convergence: ', 11]
# fval: 791.2000959187886
# [ 0.24239622 -0.01124354  0.01507115 -0.54486285  0.00141811  0.0478856 ]
# ['# of iterations for delta convergence: ', 11]
# fval: 793.4836838349878
# [ 0.24447101 -0.01124302  0.01544463 -0.5594975   0.00144308  0.04398305]
# ['# of iterations for delta convergence: ', 8]
# fval: 792.4498351365378
# [ 0.24521974 -0.01137331  0.01538922 -0.55216358  0.00185443  0.04290757]
# ['# of iterations for delta convergence: ', 9]
# fval: 791.2155857260421
# [ 0.25000769 -0.01123693  0.01600325 -0.56929102  0.00078813  0.03869629]
# ['# of iterations for delta convergence: ', 9]
# fval: 790.5864790531373
# [ 2.57889054e-01 -1.12153943e-02  1.68354101e-02 -5.97707325e-01
#  -9.34354233e-05  2.95242011e-02]
# ['# of iterations for delta convergence: ', 9]
# fval: 790.3122927434017
# [ 0.25621127 -0.01137802  0.01631765 -0.58306249  0.00201193  0.03158877]
# ['# of iterations for delta convergence: ', 9]
# fval: 788.7843947842076
# [ 0.26656525 -0.01148802  0.01711286 -0.61287271  0.00253177  0.01963713]
# ['# of iterations for delta convergence: ', 11]
# fval: 789.1093359981984
# [ 2.56638207e-01 -1.16047257e-02  1.63808513e-02 -5.73412542e-01
#   3.06147286e-04  3.22110432e-02]
# ['# of iterations for delta convergence: ', 12]
# fval: 788.4340178730871
# [ 0.26477726 -0.01188559  0.01703255 -0.58732651 -0.00079653  0.02379181]
# ['# of iterations for delta convergence: ', 9]
# fval: 789.0376643882864
# [ 0.25934941 -0.01152457  0.01682372 -0.58365087  0.00102888  0.0281501 ]
# ['# of iterations for delta convergence: ', 8]
# fval: 786.9015396088361
# [ 0.267826   -0.01166509  0.0177     -0.60304488  0.00083427  0.01828235]
# ['# of iterations for delta convergence: ', 10]
# fval: 785.703350639783
# [ 0.26505962 -0.01166579  0.01720203 -0.583532    0.00080097  0.02348576]
# ['# of iterations for delta convergence: ', 11]
# fval: 785.2522147936056
# [ 2.75353918e-01 -1.18771721e-02  1.80807235e-02 -5.95549254e-01
#   4.79921419e-04  1.32371159e-02]
# ['# of iterations for delta convergence: ', 9]
# fval: 783.9925185007374
# [ 2.74355612e-01 -1.17034490e-02  1.81546128e-02 -6.05327821e-01
#  -6.85477210e-05  1.46710833e-02]
# ['# of iterations for delta convergence: ', 10]
# fval: 786.2563872077241
# [ 2.84617081e-01 -1.16580737e-02  1.91729066e-02 -6.66337060e-01
#  -6.62061863e-04 -1.38763248e-03]
# ['# of iterations for delta convergence: ', 14]
# fval: 792.1915994887258
# [ 0.25475998 -0.01153193  0.01628086 -0.55635755  0.0011986   0.03557246]
# ['# of iterations for delta convergence: ', 14]
# fval: 787.4386474203432
# [ 0.27049261 -0.01203807  0.01746949 -0.57454418  0.00168088  0.01899674]
# ['# of iterations for delta convergence: ', 11]
# fval: 782.9036115754806
# [ 0.27679438 -0.0124494   0.01778653 -0.56296261  0.00256803  0.01373301]
# ['# of iterations for delta convergence: ', 9]
# fval: 782.1606446333645
# [ 2.79031430e-01 -1.22325685e-02  1.84768741e-02 -5.82489066e-01
#  -2.39119317e-04  1.09802536e-02]
# ['# of iterations for delta convergence: ', 9]
# fval: 783.610914087056
# [ 0.2860689  -0.01221514  0.01911235 -0.59516452  0.00128491  0.00328105]
# ['# of iterations for delta convergence: ', 11]
# fval: 781.9691165322035
# [ 0.30078425 -0.01252035  0.0204781  -0.60604051  0.00177428 -0.01118395]
# ['# of iterations for delta convergence: ', 13]
# fval: 783.7372894070106
# [ 2.98383441e-01 -1.25156835e-02  2.01561719e-02 -6.25155171e-01
#   4.21218858e-04 -1.08441700e-02]
# ['# of iterations for delta convergence: ', 10]
# fval: 785.9853771216299
# [ 0.28679708 -0.01261491  0.01894961 -0.58279401  0.00185162  0.00155212]
# ['# of iterations for delta convergence: ', 13]
# fval: 781.053673844057
# [ 0.29301781 -0.01307063  0.0193471  -0.57152711  0.00281171 -0.00500736]
# ['# of iterations for delta convergence: ', 9]
# fval: 782.7397655639625
# [ 0.25890713 -0.01183575  0.01654586 -0.54884628  0.00183866  0.03119947]
# ['# of iterations for delta convergence: ', 12]
# fval: 784.8011833586953
# [ 0.28649161 -0.01274322  0.01861731 -0.55289037  0.0017604   0.00637865]
# ['# of iterations for delta convergence: ', 12]
# fval: 778.1379805858857
# [ 2.95824416e-01 -1.32822880e-02  1.90759659e-02 -5.27813113e-01
#   2.22346970e-03  4.26799360e-04]
# ['# of iterations for delta convergence: ', 11]
# fval: 775.9596189346227
# [ 0.30771624 -0.01305475  0.02061483 -0.60007792  0.00088429 -0.01679602]
# ['# of iterations for delta convergence: ', 15]
# fval: 783.6687052031803
# [ 0.3020569  -0.01340585  0.01992466 -0.55488449  0.00237781 -0.00884471]
# ['# of iterations for delta convergence: ', 13]
# fval: 779.5186731776761
# [ 0.26780813 -0.0123453   0.0171605  -0.53529136  0.00247129  0.02383886]
# ['# of iterations for delta convergence: ', 12]
# fval: 781.5991499187637
# [ 2.92751840e-01 -1.32050635e-02  1.88596657e-02 -5.37147637e-01
#   4.49816300e-03  3.48786386e-04]
# ['# of iterations for delta convergence: ', 12]
# fval: 790.7761018774338
# [ 0.28246153 -0.01247569  0.01857257 -0.57115371  0.0009452   0.00832239]
# ['# of iterations for delta convergence: ', 11]
# fval: 780.175800906944
# [ 0.29687793 -0.01299699  0.01981202 -0.55940445  0.00115007 -0.00420751]
# ['# of iterations for delta convergence: ', 10]
# fval: 778.0515635470388
# [ 0.29120643 -0.01349186  0.01871943 -0.51528253  0.00238825  0.00374827]
# ['# of iterations for delta convergence: ', 12]
# fval: 775.3068168652201
# [ 0.29377519 -0.01413022  0.01852296 -0.47534153  0.00293992  0.00398188]
# ['# of iterations for delta convergence: ', 12]
# fval: 773.3936156480304
# [ 0.31812289 -0.01395668  0.02112543 -0.55517241  0.00135808 -0.02342854]
# ['# of iterations for delta convergence: ', 15]
# fval: 780.5290848535615
# [ 0.30957588 -0.01413433  0.0200616  -0.49846256  0.00181322 -0.00946869]
# ['# of iterations for delta convergence: ', 14]
# fval: 772.8056524171402
# [ 0.32096527 -0.01489405  0.02061759 -0.45629683  0.00179403 -0.01497909]
# ['# of iterations for delta convergence: ', 12]
# fval: 769.8922353861851
# [ 0.27919752 -0.01310502  0.0177165  -0.49312563  0.00245209  0.01832846]
# ['# of iterations for delta convergence: ', 13]
# fval: 775.6924796806701
# [ 0.31377088 -0.01479578  0.019984   -0.45113498  0.00336726 -0.01008711]
# ['# of iterations for delta convergence: ', 11]
# fval: 774.1673495749601
# [ 0.29808017 -0.01432894  0.01865169 -0.43282102  0.00226447  0.00666585]
# ['# of iterations for delta convergence: ', 13]
# fval: 767.6585932687368
# [ 0.29609181 -0.01479048  0.0180152  -0.37178928  0.0022078   0.01442114]
# ['# of iterations for delta convergence: ', 12]
# fval: 764.087082905017
# [ 0.3029971  -0.01533562  0.01816538 -0.36576267  0.00384478  0.0082382 ]
# ['# of iterations for delta convergence: ', 11]
# fval: 769.2456413158022
# [ 0.30644151 -0.01573477  0.01859791 -0.34333719  0.00331182  0.00620769]
# ['# of iterations for delta convergence: ', 11]
# fval: 764.3734206715515
# [ 0.33214973 -0.01678862  0.02025118 -0.3280952   0.00336978 -0.01573422]
# ['# of iterations for delta convergence: ', 11]
# fval: 765.580775472391
# [ 0.30370266 -0.01576214  0.01807275 -0.32907259  0.00245545  0.01079898]
# ['# of iterations for delta convergence: ', 12]
# fval: 760.9688424495547
# [ 0.29866854 -0.01624532  0.01711712 -0.2680414   0.00199954  0.02124202]
# ['# of iterations for delta convergence: ', 12]
# fval: 759.9019174868367
# [ 0.32532946 -0.01713273  0.01906517 -0.23576599  0.00256933  0.00248337]
# ['# of iterations for delta convergence: ', 11]
# fval: 755.287925460666
# [ 0.3411066  -0.01863398  0.01933627 -0.11597822  0.00238403  0.00173412]
# ['# of iterations for delta convergence: ', 12]
# fval: 751.2366129578668
# [ 0.30485316 -0.01761555  0.01654343 -0.14137116  0.00391189  0.0270154 ]
# ['# of iterations for delta convergence: ', 13]
# fval: 761.7191294168092
# [ 0.32344002 -0.01793395  0.01845499 -0.15710815  0.0018835   0.01005719]
# ['# of iterations for delta convergence: ', 13]
# fval: 753.157996176772
# [ 0.29138415 -0.01686273  0.01577046 -0.13777994  0.00186308  0.04262674]
# ['# of iterations for delta convergence: ', 14]
# fval: 766.9281481575858
# [ 0.32195834 -0.01680715  0.019131   -0.28051638  0.00299311 -0.00114398]
# ['# of iterations for delta convergence: ', 10]
# fval: 758.8415859023086
# [ 0.32226464 -0.01827404  0.01760143 -0.10159767  0.0018148   0.01823427]
# ['# of iterations for delta convergence: ', 13]
# fval: 754.3259697558931
# [ 0.34133862 -0.02037952  0.01804622  0.01691829  0.00278783  0.01129187]
# ['# of iterations for delta convergence: ', 10]
# fval: 752.1059316156915
# Object vcov dimensions: (25, 25)
# Object se dimensions: (25,)
# Object theta2w dimensions:     (6,)
# Object t dimensions:     ()
# running time: 89.97566485404968
#       Theta1_4  Std.Error_theta1_4  Theta2_4  Std.Error_theta2_4  \
# 0     0.182977            2.407080  0.341339            3.387360
# 1   -12.204379            2.344543 -0.020380            0.091185
# 2    -0.696111            0.402905  0.018046            1.645208
# 3     1.640358            0.242163  0.016918            2.446374
# 4   249.662775           47.607996  0.002788            0.017790
# 5    -0.227656            9.735213  0.011292            0.383131
# 6     0.872612            0.935971       NaN                 NaN
# 7   -21.258445            4.097608       NaN                 NaN
# 8    -0.137904            0.028679       NaN                 NaN
# 9    69.447958            4.028088       NaN                 NaN
# 10   87.005665           14.381902       NaN                 NaN
# 11  121.433481           21.234201       NaN                 NaN
# 12  -99.470665           42.868774       NaN                 NaN
# 13  -21.487952           11.466134       NaN                 NaN
# 14  192.278429           15.736271       NaN                 NaN
# 15  143.283778           25.295218       NaN                 NaN
# 16  -65.380759           32.718253       NaN                 NaN
# 17  -78.453820           17.471174       NaN                 NaN
# 18   20.726867           11.801377       NaN                 NaN
#
#     Objective Value_4
# 0          752.105932
# 1          752.105932
# 2          752.105932
# 3          752.105932
# 4          752.105932
# 5          752.105932
# 6          752.105932
# 7          752.105932
# 8          752.105932
# 9          752.105932
# 10         752.105932
# 11         752.105932
# 12         752.105932
# 13         752.105932
# 14         752.105932
# 15         752.105932
# 16         752.105932
# 17         752.105932
# 18         752.105932

# %%
#BONUS POINT!

#3.1 initial code using L-BFGS-B

from scipy.optimize import minimize
import numpy as np
import pandas as pd

class BLP:
    def __init__(self, data, theta2w, mtol, niter):

        if np.any(np.isnan(data.x1)) or np.any(np.isinf(data.x1)):
            print("NaN or Inf detected in x1.")
        if np.any(np.isnan(data.x2)) or np.any(np.isinf(data.x2)):
            print("NaN or Inf detected in x2.")

        self.niter = niter 
        self.mtol = mtol
        self.theta2w = theta2w
        self.x1 = data.x1
        self.x2 = data.x2
        self.s_jt = data.s_jt
        self.v = data.v
        self.cdindex = data.cdindex
        self.cdid = data.cdid
        self.cdid_demogr = data.cdid_demogr
        self.vfull = data.v.loc[self.cdid_demogr,:]
        dfull = data.demogr.loc[self.cdid_demogr,:]
        dfull.columns = pd.RangeIndex(len(dfull.columns))
        dfull.index = pd.RangeIndex(len(dfull.index))
        self.dfull = dfull
        self.demogr = data.demogr
        self.IV = data.IV
        self.K1 = self.x1.shape[1]
        self.K2 = self.x2.shape[1]
        self.ns = data.ns
        self.D = int(self.dfull.shape[1] / self.ns)
        self.T = np.asarray(self.cdindex).shape[0]
        self.TJ = self.x1.shape[0]
        self.J = int(self.TJ / self.T)

        self.invA = np.linalg.inv(self.IV.T @ self.IV)
    
    #mid2 = np.mat(self.x1.T)*np.mat(self.IV)*self.invA*np.mat(self.IV.T)*np.mat(self.x1)
        #invmid2=np.linalg.inv(mid2)
        
        #Calculating s0 -outside good shares
        temp= self.s_jt.cumsum()
        sum1 = temp[self.cdindex] 
        sum1[1:np.shape(sum1)[0]] = np.diff(sum1) 
        outshr = (1 - sum1[np.asarray(self.cdid,dtype=int)]) 
        outshr= np.abs(outshr)
        outshr=np.reshape(outshr,(np.shape(outshr)[0],1))    

        # Initialize necessary variables for calculations
        self.mvalold = np.zeros((self.TJ, 1))
        self.oldt2 = np.zeros(np.shape(self.theta2w))
        self.gmmvalold = 0
        self.gmmdiff = 1
        self.gmmresid = np.ones((6024, 1))

         #Find initial guess of coefficients by running simple logit regression
        y=np.log(self.s_jt)-np.log(outshr)
        mid = self.x1.T@self.IV@self.invA@self.IV.T
        t = np.linalg.inv(mid@self.x1)@mid@y 

         #Mean utility - initial
        self.mvalold = self.x1@(t) 
        self.mvalold = np.exp(self.mvalold).values.reshape(np.shape(self.mvalold)[0],1)
        self.oldt2 = np.zeros(np.shape(self.theta2w)) #initial old2
        self.gmmvalold = 0
        self.gmmdiff = 1
        self.gmmresid = np.ones((6024,1)) #@@@@@@ initialization

    def init_theta(self, theta2w):
        theta2w = theta2w.reshape(self.K2, 1 + self.D)
        self.theti, self.thetj = list(np.where(theta2w != 0))
        self.theta2 = theta2w[np.where(theta2w != 0)]
        return self.theta2

    def mufunc(self, theta2w):
        mu = np.zeros((self.TJ, self.ns))
        for i in range(self.ns):
            v_i = np.array(self.vfull.loc[:, np.arange(i, self.K2 * self.ns, self.ns)])
            d_i = np.array(self.dfull.loc[:, np.arange(i, self.D * self.ns, self.ns)])
            temp = d_i @ theta2w[:, 1:(self.D + 1)].T
            mu[:, i] = (np.multiply(self.x2, v_i) @ theta2w[:, 0]) + np.multiply(self.x2, temp) @ np.ones((self.K2))
        return mu

    def ind_sh(self, expmu):
        eg = np.multiply(expmu, np.kron(np.ones((1, self.ns)), self.mvalold))
        temp = np.cumsum(eg, 0)
        sum1 = temp[self.cdindex, :]
        sum2 = sum1
        sum2[1:sum2.shape[0], :] = np.diff(sum1.T).T
        denom1 = 1. / (1 + sum2)
        denom = denom1[np.asarray(self.cdid, dtype=int), :]
        return np.multiply(eg, denom)

    def mktsh(self, expmu):
        temp = self.ind_sh(expmu).T
        f = (sum(temp) / float(self.ns)).T
        f = f.reshape(self.x1.shape[0], 1)
        return f

    def meanval(self, theta2):
        if np.ndarray.max(np.absolute(theta2 - self.oldt2)) < 0.01:
            tol = self.mtol
            flag = 0
        else:
            tol = self.mtol
            flag = 1
        norm = 1
        avgnorm = 1
        i = 0
        theta2w = np.zeros((self.K2, self.D + 1))
        for ind in range(len(self.theti)):
            theta2w[self.theti[ind], self.thetj[ind]] = theta2[ind]
        expmu = np.exp(self.mufunc(theta2w))

        while (norm > self.mtol) & (i < self.niter):
            pred_s_jt = self.mktsh(expmu)
            self.mval = np.multiply(self.mvalold, self.s_jt) / pred_s_jt
            t = np.abs(self.mval - self.mvalold)
            norm = np.max(t)
            avgnorm = np.mean(t)
            self.mvalold = self.mval
            i += 1

            if (norm > self.mtol) & (i > self.niter - 1):
                print('Max number of ' + str(self.niter) + ' iterations reached')

        print(['# of iterations for delta convergence:', i])

        if (flag == 1) & (sum(np.isnan(self.mval))) == 0:
            self.mvalold = self.mval
            self.oldt2 = theta2
        return np.log(self.mval)

    #Calculates the jacobian
    def jacob(self,theta2): 
        cdindex=np.asarray(self.cdindex,dtype=int)
        theta2w = np.zeros((self.K2, self.D+1))
        for ind in range(len(self.theti)):
            theta2w[self.theti[ind], self.thetj[ind]] = self.theta2[ind] #build theta2w (from array to ndarray) to plug in ind_sh
        expmu=np.exp(self.mufunc(theta2w)) 
        shares = self.ind_sh(expmu)
        f1 = np.zeros((np.asarray(self.cdid).shape[0] ,self.K2 * (self.D + 1)))
    # calculate derivative of shares with respect to the first column of theta2w (variable that are not interacted with demogr var, sigmas)
        for i in range(self.K2):
            xv = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)),self.v.loc[self.cdid, self.ns*i:self.ns * (i+1)-1])
            temp = np.cumsum(np.multiply(xv, shares), 0).values
            sum1 = temp[cdindex, :]
            sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
            f1[:,i] = np.mean((np.multiply(shares, xv - sum1[np.asarray(self.cdid,dtype=int),:])),1) #mean over columns
           
        for j in range(self.D):
            d = self.demogr.loc[self.cdid,self.ns*(j)+1:self.ns*(j+1)] 
            temp1 = np.zeros((np.asarray(self.cdid).shape[0],self.K2))
            for i in range(self.K2):
                xd = np.multiply(self.x2[:, i].reshape(self.TJ, 1) @ np.ones((1,self.ns)), d)
                temp = np.cumsum(np.multiply(xd, shares), 0).values
                sum1 = temp[cdindex, :]
                sum1[1:sum1.shape[0], :] = np.diff(sum1.T).T
                temp1[:, i] = np.mean((np.multiply(shares, xd-sum1[np.asarray(self.cdid,dtype=int), :])), 1)
            f1[:,self.K2 * (j + 1):self.K2 * (j + 2)] = temp1 

        self.rel = self.theti + self.thetj * (max(self.theti)+1) 
        f = np.zeros((np.shape(self.cdid)[0],self.rel.shape[0]))
        n = 0
        
        for i in range(np.shape(self.cdindex)[0]):
            temp = shares[n:(self.cdindex[i] + 1), :]
            H1 = temp @ temp.T
            H = (np.diag(np.array(sum(temp.T)).flatten())-H1) / self.ns
            f[n:(cdindex[i]+1),:] = np.linalg.inv(H) @ f1[n:(cdindex[i] + 1),self.rel]
            n = cdindex[i] + 1
        return f
    #Compute GMM objective function  
    def gmmobj(self, theta2):
        delta = self.meanval(theta2)
        self.theta2 = theta2
        if max(np.isnan(delta)) == 1:
            f = np.ndarray((1, 1), buffer=np.array([1e+10, 1e+10]))
        else:
            temp1 = self.x1.T @ self.IV
            temp2 = delta.T @ self.IV
            self.theta1 = np.linalg.inv(temp1 @ self.invA @ temp1.T) @ temp1 @ self.invA @ temp2.T
            self.gmmresid = delta - self.x1 @ self.theta1
            temp1 = self.gmmresid.T @ self.IV
            f = temp1 @ self.invA @ temp1.T
            f = f.values
            if np.shape(f) > (1,1):
                temp = self.jacob(theta2).T 
                df = 2*temp@self.IV@self.invA@self.IV.T@self.gmmresid 
        print('fval:', f[0, 0]) #value of the gmm objective function
        
        #to be used in meanval to phase tolerance based on gmm value

        self.gmmvalnew = f[0, 0]
        self.gmmdiff = np.abs(self.gmmvalold - self.gmmvalnew)
        self.gmmvalold = self.gmmvalnew

        return (f[0, 0])

    def gradobj(self, theta2):
        temp = self.jacob(theta2).T
        df = 2 * temp @ self.IV @ self.invA @ self.IV.T @ self.gmmresid
        df = df.values
        print('this is the gradient ' + str(df))
        return df

    def iterate_optimization(self, opt_func, param_vec, jac, options):
         
options = {'gtol': gtol,
            'norm': norm,
            'eps': epsilon,
            'disp': disp,
            'maxiter': maxiter,
            'return_all': retall}

    res = _minimize_bfgs(f, x0, fprime, callback=None, options)

    if full_output:
        retlist = (res['x'], res['fun'], res['jac'], res['hess_inv'],
                   res['nfev'], res['njev'], res['status'])
        if retall:
            retlist += (res['allvecs'], )
        return retlist
    else:
        if retall:
            return res['x'], res['allvecs']
        else:
            return res['x']


def _minimize_bfgs(opt_func, x0, jac=None, callback=None,
                   gtol=1e-5, norm=Inf, maxiter=None,
                   disp=False, return_all=False,
                   options):
#res = minimize(opt_func, param_vec, method='BFGS', bounds=None, callback=None, options=options)
    

options = {'disp': True, 'maxiter': 100, 'tol': 0.0001}

blp = BLP(data, theta2w, mtol, niter)
init_theta = blp.init_theta(theta2w)

# Run optimization using L-BFGS-B
res = blp.iterate_optimization(opt_func=blp.gmmobj, param_vec=init_theta, jac=blp.gradobj, options=options)

#3.2 5 different initial values

# Define five different initial guesses for theta2
initial_guesses = [
    blp.init_theta(theta2w),                     # Use the default initial guess
    blp.init_theta(theta2w) * 1.1,              # Slightly scaled-up version
    blp.init_theta(theta2w) * 0.9,              # Slightly scaled-down version
    blp.init_theta(theta2w) + np.random.randn(len(blp.init_theta(theta2w))) * 0.1,  # Add random noise
    np.zeros_like(blp.init_theta(theta2w)),     # Start with all zeros
]

# Dictionary to store results
results = {}

# Iterate over the initial guesses
for i, init_theta in enumerate(initial_guesses):
    print(f"\nStarting optimization with initial guess #{i+1}")
    res = blp.iterate_optimization(
        opt_func=blp.gmmobj,
        param_vec=init_theta,
        jac=blp.gradobj,
        options=options
    )
    # Store the results
    results[f"Guess {i+1}"] = res

    # Print summary of the result
    print(f"Optimization result for Guess {i+1}:")
    print(f"  Success: {res.success}")
    print(f"  Final Objective Value: {res.fun}")
    print(f"  Optimized Parameters: {res.x}")



#3.3 increased tolerance

# Define tolerances to test
tolerances = [1e-16, 1e-14]

# Dictionary to store results for each tolerance level
results_with_tolerance = {}

# Loop over the tolerances
for tol in tolerances:
    print(f"\nStarting optimization with tolerance {tol}")
    
    # Update the blp instance with the current tolerance
    blp.mtol = tol

    # Use the original initial guess
    original_guess = blp.init_theta(theta2w)

    # Perform optimization
    res = blp.iterate_optimization(
        opt_func=blp.gmmobj,
        param_vec=original_guess,
        jac=blp.gradobj,
        options=options
    )
    
    # Store results
    results_with_tolerance[f"Tolerance {tol}"] = res

    # Print summary of the result
    print(f"Optimization result for Tolerance {tol}:")
    print(f"  Success: {res.success}")
    print(f"  Final Objective Value: {res.fun}")
    print(f"  Optimized Parameters: {res.x}")

#3.4 table with gradient of the objective function for each case above
# Out:
# /var/folders/y2/qlk0n6jn0p74r1t6k3d3r_pw0000gn/T/ipykernel_23996/2128119067.py:214: OptimizeWarning: Unknown solver options: tol
#   res = minimize(opt_func, param_vec, method='L-BFGS-B', bounds=None, callback=None, options=options)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 226
#     223 init_theta = blp.init_theta(theta2w)
#     225 # Run optimization using L-BFGS-B
# --> 226 res = blp.iterate_optimization(opt_func=blp.gmmobj, param_vec=init_theta, jac=blp.gradobj, options=options)
#     228 #3.2 5 different initial values
#     229
#     230 # Define five different initial guesses for theta2
#     231 initial_guesses = [
#     232     blp.init_theta(theta2w),                     # Use the default initial guess
#     233     blp.init_theta(theta2w) * 1.1,              # Slightly scaled-up version
#    (...)
#     236     np.zeros_like(blp.init_theta(theta2w)),     # Start with all zeros
#     237 ]
#
# Cell In[57], line 214, in BLP.iterate_optimization(self, opt_func, param_vec, jac, options)
#     213 def iterate_optimization(self, opt_func, param_vec, jac, options):
# --> 214      res = minimize(opt_func, param_vec, method='L-BFGS-B', bounds=None, callback=None, options=options)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:347, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     344         iprint = disp
#     346 # _prepare_scalar_function can use bounds=None to represent no bounds
# --> 347 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     348                               bounds=bounds,
#     349                               finite_diff_rel_step=finite_diff_rel_step)
#     351 func_and_grad = sf.fun_and_grad
#     353 fortran_int = _lbfgsb.types.intvar.dtype
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:288, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     284     bounds = (-np.inf, np.inf)
#     286 # ScalarFunction caches. Reuse of fun(x) during grad
#     287 # calculation reduces overall function evaluations.
# --> 288 sf = ScalarFunction(fun, x0, args, grad, hess,
#     289                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     291 return sf
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:222, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     219     finite_diff_options["as_linear_operator"] = True
#     221 # Initial function evaluation
# --> 222 self._update_fun()
#     224 # Initial gradient evaluation
#     225 self._wrapped_grad, self._ngev = _wrapper_grad(
#     226     grad,
#     227     fun=self._wrapped_fun,
#     228     args=args,
#     229     finite_diff_options=finite_diff_options
#     230 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:294, in ScalarFunction._update_fun(self)
#     292 def _update_fun(self):
#     293     if not self.f_updated:
# --> 294         fx = self._wrapped_fun(self.x)
#     295         if fx < self._lowest_f:
#     296             self._lowest_x = self.x
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# Cell In[57], line 181, in BLP.gmmobj(self, theta2)
#     180 def gmmobj(self, theta2):
# --> 181     delta = self.meanval(theta2)
#     182     self.theta2 = theta2
#     183     if max(np.isnan(delta)) == 1:
#
# Cell In[57], line 122, in BLP.meanval(self, theta2)
#     119 expmu = np.exp(self.mufunc(theta2w))
#     121 while (norm > self.mtol) & (i < self.niter):
# --> 122     pred_s_jt = self.mktsh(expmu)
#     123     self.mval = np.multiply(self.mvalold, self.s_jt) / pred_s_jt
#     124     t = np.abs(self.mval - self.mvalold)
#
# Cell In[57], line 101, in BLP.mktsh(self, expmu)
#     100 def mktsh(self, expmu):
# --> 101     temp = self.ind_sh(expmu).T
#     102     f = (sum(temp) / float(self.ns)).T
#     103     f = f.reshape(self.x1.shape[0], 1)
#
# File ~/Library/Python/3.12/lib/python/site-packages/debugpy/_vendored/pydevd/_pydevd_sys_monitoring/_pydevd_sys_monitoring.py:1459, in _line_event(code, line)
#    1455 # pydev_log.debug('_line_event', code.co_name, line)
#    1456
#    1457 # We know the frame depth.
#    1458 frame = _getframe(1)
# -> 1459 return _internal_line_event(func_code_info, frame, line)
#
# File ~/Library/Python/3.12/lib/python/site-packages/debugpy/_vendored/pydevd/_pydevd_sys_monitoring/_pydevd_sys_monitoring.py:1501, in _internal_line_event(func_code_info, frame, line)
#    1498         stop = True
#    1500     if bp:
# -> 1501         if _stop_on_breakpoint(py_db, thread_info, stop_reason, bp, frame, new_frame, stop, stop_on_plugin_breakpoint, "python-line"):
#    1502             return
#    1504 if func_code_info.plugin_line_breakpoint_found:
#
# File ~/Library/Python/3.12/lib/python/site-packages/debugpy/_vendored/pydevd/_pydevd_sys_monitoring/_pydevd_sys_monitoring.py:1302, in _stop_on_breakpoint(py_db, thread_info, stop_reason, bp, frame, new_frame, stop, stop_on_plugin_breakpoint, bp_type)
#    1296     py_db.set_suspend(
#    1297         thread_info.thread,
#    1298         stop_reason,
#    1299         suspend_other_threads=bp and bp.suspend_policy == "ALL",
#    1300     )
#    1301     # print('suspend on breakpoint...')
# -> 1302     _do_wait_suspend(py_db, thread_info, frame, "line", None)
#    1303     return True
#    1305 elif stop_on_plugin_breakpoint:
#
# File ~/Library/Python/3.12/lib/python/site-packages/debugpy/_vendored/pydevd/_pydevd_sys_monitoring/_pydevd_sys_monitoring.py:1939, in _do_wait_suspend(py_db, thread_info, frame, event, arg)
#    1935 def _do_wait_suspend(py_db, thread_info, frame, event, arg):
#    1936 # ENDIF
#    1937 # fmt: on
#    1938     thread_info.additional_info.trace_suspend_type = "sys_monitor"
# -> 1939     py_db.do_wait_suspend(thread_info.thread, frame, event, arg)
#
# File ~/Library/Python/3.12/lib/python/site-packages/debugpy/_vendored/pydevd/pydevd.py:2185, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2182             from_this_thread.append(frame_custom_thread_id)
#    2184     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2185         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2187 frames_list = None
#    2189 if keep_suspended:
#    2190     # This means that we should pause again after a set next statement.
#
# File ~/Library/Python/3.12/lib/python/site-packages/debugpy/_vendored/pydevd/pydevd.py:2254, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2251                 queue.put(internal_cmd)
#    2252                 wait_timeout = TIMEOUT_FAST
# -> 2254         notify_event.wait(wait_timeout)
#    2255         notify_event.clear()
#    2257 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
